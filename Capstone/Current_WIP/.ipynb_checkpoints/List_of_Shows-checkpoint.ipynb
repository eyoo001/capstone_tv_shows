# %%
import pickle
import json
import requests
import re
import pandas as pd
import numpy as np 
import pprint

pp = pprint.PrettyPrinter(indent=2)

# %% [markdown]
# # Loading in the list and cleaning the show names

# %%
with open ('../Data/new_show_list', 'rb') as fp:
    show_names = pickle.load(fp)
    
with open ('../Data/abc_names.json', 'rb') as fp:
    abc_names = json.load(fp)

with open ('../abc_links.pickle', 'rb') as fp:
    abc_links = pickle.load(fp)

# %%
abc_names = abc_names[77:]
abc_names = abc_names[:1159]
len(abc_names)
# Out:
# 1159

# %%
pattern = re.compile('https://en.wikipedia.org/wiki/(.*)')

# %%
abc_links_cleaned = [re.findall(pattern, x)[0] for x in abc_links if re.findall(pattern, x)]

# %%
#flat_list = [item for sublist in abc_names for item in sublist]
flat_list = [re.sub('_', ' ', i) for i in abc_links_cleaned]
flat_list = [re.sub('%27', '\'', i) for i in flat_list]
flat_list = [re.sub(' \(([^)]+)\)', '', i) for i in flat_list]
flat_list = [re.sub('%26', '&', i) for i in flat_list]
flat_list = [re.sub('#', '', i) for i in flat_list]
flat_list = [re.sub('%3F', '?', i) for i in flat_list]

# %%
flat_list = flat_list[:1215]

# %%
flat_list
# Out:
# ["Grey's Anatomy",
#  'Agents of S.H.I.E.L.D.',
#  'How to Get Away with Murder',
#  'The Good Doctor',
#  'For the People',
#  'Station 19',
#  'Take Two',
#  'A Million Little Things',
#  'Modern Family',
#  'The Goldbergs',
#  'Black-ish',
#  'Fresh Off the Boat',
#  'Speechless',
#  'American Housewife',
#  'Splitting Up Together',
#  'Single Parents',
#  "America's Funniest Home Videos",
#  'The Bachelor',
#  'The Bachelorette',
#  'Dancing with the Stars',
#  'Shark Tank',
#  'The Great Christmas Light Fight',
#  'Bachelor in Paradise',
#  'The Great American Baking Show',
#  'The Bachelor Winter Games',
#  'American Idol',
#  'The Last Defense',
#  'The Proposal',
#  'Castaways',
#  "Santa Claus Is Comin' to Town",
#  "Dick Clark's New Year's Rockin' Eve",
#  "Rudolph's Shiny New Year",
#  'Disney Parks Christmas Day Parade',
#  'Peanuts',
#  'Shrek the Halls',
#  'Prep & Landing',
#  'Country Music Association',
#  'Prep & Landing: Naughty vs. Nice',
#  'Toy Story of Terror!',
#  'Toy Story That Time Forgot',
#  "Olaf's Frozen Adventure",
#  'Celebrity Family Feud',
#  'To Tell the Truth',
#  'Pyramid',
#  'Match Game',
#  'The Gong Show',
#  'Child Support',
#  'General Hospital',
#  'American Music Awards',
#  'Academy Awards',
#  'Country Music Association Awards',
#  'Miss America',
#  'The View',
#  'Jimmy Kimmel Live!',
#  'The Alec Baldwin Show',
#  'GMA Day',
#  'ABC World News Tonight',
#  'Good Morning America',
#  '20/20',
#  'Nightline',
#  'This Week',
#  'America This Morning',
#  'World News Now',
#  'What Would You Do%3F',
#  'People',
#  'Jack Hanna',
#  'Sea Rescue',
#  'The Wildlife Docs',
#  'Outback Adventures with Tim Faulkner',
#  'Ocean Treks with Jeff Corwin',
#  'The Ten Commandments',
#  'The Sound of Music',
#  'ABC Saturday Movie of the Week',
#  'Mary Poppins',
#  'Beauty and the Beast',
#  'Frozen',
#  'Flushed Away',
#  'National Football League',
#  'NFL Playoffs',
#  'ESPN',
#  'Pro Bowl',
#  'National Football League draft',
#  'NFL Playoffs',
#  'ESPN',
#  'Pro Bowl',
#  'National Football League draft',
#  'National Basketball Association',
#  'NBA Countdown',
#  'National Basketball Association Christmas games',
#  'NBA Saturday Primetime',
#  'NBA Sunday Showcase',
#  'NBA playoffs',
#  'NBA Finals',
#  'NBA Countdown',
#  'National Basketball Association Christmas games',
#  'NBA Saturday Primetime',
#  'NBA Sunday Showcase',
#  'NBA playoffs',
#  'NBA Finals',
#  "Women's National Basketball Association",
#  'ESPN College Football on ABC',
#  'Saturday Night Football',
#  'Atlantic Coast Conference',
#  'Big Ten Conference',
#  'Big 12 Conference',
#  'Pac-12 Conference',
#  'Saturday Night Football',
#  'Atlantic Coast Conference',
#  'Big Ten Conference',
#  'Big 12 Conference',
#  'Pac-12 Conference',
#  'Wimbledon Championships',
#  'Formula 1',
#  'X Games',
#  'Little League World Series',
#  'The Fix',
#  'Grand Hotel',
#  'Reef Break',
#  'The Rookie',
#  'Whiskey Cavalier',
#  'The Conners',
#  'The Kids Are Alright',
#  'Schooled',
#  'Dancing with the Stars: Juniors',
#  'Gabriel Iglesias',
#  'Ryan Seacrest',
#  'Kenya Barris',
#  'Alec Baldwin',
#  'The Middle',
#  'Adventures in Paradise',
#  'Alias',
#  'Batman',
#  'Birdland',
#  'Blue Thunder',
#  'Chopper One',
#  'Combat Hospital',
#  'Firehouse',
#  'Last Resort',
#  'Lois & Clark: The New Adventures of Superman',
#  'MacGyver',
#  'Agent Carter',
#  'Inhumans',
#  'Once a Hero',
#  'Sable',
#  'Tales of the Gold Monkey',
#  'The Fall Guy',
#  'The Green Hornet',
#  'The Persuaders!',
#  'The Quest',
#  'The River',
#  'The Swiss Family Robinson',
#  'The Young Indiana Jones Chronicles',
#  'The Young Rebels',
#  'Wonder Woman',
#  'Zorro',
#  'Arresting Behavior',
#  'Cupid',
#  'Cupid',
#  'Desperate Housewives',
#  'Doogie Howser, M.D.',
#  'Eight Is Enough',
#  'Eli Stone',
#  'GCB',
#  'Hooperman',
#  'Kevin Saves the World',
#  'Me and Mom',
#  'Moonlighting',
#  'Pushing Daisies',
#  'Room 222',
#  'Snoops',
#  'The Commish',
#  'The Greatest American Hero',
#  'The Love Boat',
#  'The Wonder Years',
#  'Ugly Betty',
#  '10-8: Officers on Duty',
#  '77 Sunset Strip',
#  '240-Robert',
#  '666 Park Avenue',
#  'A Fine Romance',
#  'American Crime',
#  'B.A.D. Cats',
#  'B.L. Stryker',
#  'Barbary Coast',
#  'Baretta',
#  'Ben Casey',
#  "Bert D'Angelo/Superstar",
#  'Betrayal',
#  'Big Shots',
#  'Black Box',
#  'Blind Justice',
#  'Blood & Oil',
#  'Blue Light',
#  'Body of Proof',
#  'Boston Legal',
#  'Bourbon Street Beat',
#  'Brothers & Sisters',
#  'Buck James',
#  "Burke's Law",
#  'Bus Stop',
#  'Call to Glory',
#  'Capital News',
#  'Caribe',
#  'Cashmere Mafia',
#  'Castle',
#  'Charlie Grace',
#  "Charlie's Angels",
#  "Charlie's Angels",
#  'China Beach',
#  'Civil Wars',
#  'Code Red',
#  'Combat!',
#  'Commander in Chief',
#  'Conviction',
#  'Cop Rock',
#  'Court Martial',
#  'Covington Cross',
#  'Crime with Father',
#  'Crossroads',
#  'Dan August',
#  'Dangerous Minds',
#  'Darkroom',
#  'Day Break',
#  'Deception',
#  'Designated Survivor',
#  'Detroit 1-8-7',
#  'Dirty Sexy Money',
#  'Doc Elliot',
#  'Dynasty',
#  'Eastwick',
#  'Elvis',
#  'Equal Justice',
#  'Eyes',
#  'Family',
#  'Fantasy Island',
#  'Fantasy Island',
#  'FBI: The Untold Stories',
#  'Felony Squad',
#  'Finder of Lost Loves',
#  'FlashForward',
#  'Follow the Sun',
#  'Forever',
#  "Gabriel's Fire",
#  'Get Christie Love!',
#  "Gideon's Crossing",
#  'Glitter',
#  'Griff',
#  'Happy Town',
#  'Hardcastle and McCormick',
#  'Hart to Hart',
#  'Hawaiian Eye',
#  'Hawaiian Heat',
#  'Heart of the City',
#  'HeartBeat',
#  'High Incident',
#  'Hollywood Beat',
#  'Homefront',
#  'Honey West',
#  'Hotel',
#  'Hothouse',
#  'How the West Was Won',
#  'Human Target',
#  'In Justice',
#  'It Takes a Thief',
#  'Jack and Mike',
#  "Jack's Place",
#  'Karen Sisco',
#  'Killer Women',
#  "King's Crossing",
#  'Kingdom Hospital',
#  'Knightwatch',
#  'L.A. Dragnet',
#  'Lady Blue',
#  'Life as We Know It',
#  'Life Goes On',
#  'Life on Mars',
#  'Line of Fire',
#  'Lottery!',
#  'Lucan',
#  'Lucky 7',
#  'MacGruder & Loud',
#  'Marcus Welby, M.D.',
#  'Masquerade',
#  'Matlock',
#  'Matt Helm',
#  'Matt Houston',
#  'Matt Lincoln',
#  'McKenna',
#  'MDs',
#  'Men in Trees',
#  'Mind Games',
#  'Miracles',
#  'Missing',
#  'Missing Persons',
#  'Mission: Impossible',
#  'Mistresses',
#  'Mobile One',
#  'Moon Over Miami',
#  'Most Wanted',
#  'Motive',
#  'Murder One',
#  "Murphy's Law",
#  'My Generation',
#  'My Life and Times',
#  'My So-Called Life',
#  'N.Y.P.D.',
#  'Nakia',
#  'Nashville',
#  'Notorious',
#  'NYPD Blue',
#  'October Road',
#  'Of Kings and Prophets',
#  'Off the Map',
#  'Ohara',
#  'Once and Again',
#  'Once Upon a Time',
#  'Once Upon a Time in Wonderland',
#  'Our Family Honor',
#  'Owen Marshall: Counselor at Law',
#  'Pan Am',
#  'Paper Dolls',
#  'Peyton Place',
#  'Philly',
#  'Private Practice',
#  'Probe',
#  'Pros and Cons',
#  'Push, Nevada',
#  'Quantico',
#  'Red Widow',
#  'Relativity',
#  'Revenge',
#  'Rookie Blue',
#  'S.W.A.T.',
#  'Scandal',
#  'Scoundrels',
#  'Second Noah',
#  'Secrets and Lies',
#  'Shadow Chasers',
#  'Sidekicks',
#  'Six Degrees',
#  'Somewhere Between',
#  'Spenser: For Hire',
#  'Spy Game',
#  'Stand By for Crime',
#  'Starsky and Hutch',
#  'Stone',
#  'Strike Force',
#  'Still Star-Crossed',
#  'Studio 5-B',
#  'Supercarrier',
#  'Surfside 6',
#  'T.J. Hooker',
#  'Ten Days in the Valley',
#  'Tenspeed and Brown Shoe',
#  'That Was Then',
#  'The Asphalt Jungle',
#  'The Avengers',
#  'The Byrds of Paradise',
#  'The Catch',
#  'The Colbys',
#  'The Court',
#  'The Days',
#  'The Deep End',
#  'The Evidence',
#  'The F.B.I.',
#  'The Family',
#  'The Feather and Father Gang',
#  'The Forgotten',
#  'The Fugitive',
#  'The Gates',
#  'The Hardy Boys/Nancy Drew Mysteries',
#  'The Immortal',
#  'The Insiders',
#  'The Mod Squad',
#  'The Most Deadly Game',
#  'The Nine',
#  'The Practice',
#  'The Rat Patrol',
#  'The Renegades',
#  'The Rookies',
#  'The Sixth Sense',
#  'The Strauss Family',
#  'The Streets of San Francisco',
#  'The Untouchables',
#  'The Unusuals',
#  'The Whole Truth',
#  'The Young Lawyers',
#  'Thirtysomething',
#  'Threat Matrix',
#  "Today's FBI",
#  'Toma',
#  'Trauma Center',
#  'Traveler',
#  "Twelve O'Clock High",
#  'Twin Peaks',
#  'Under Cover',
#  'Vega$',
#  'Vengeance Unlimited',
#  'Wasteland',
#  'What About Brian',
#  'Wicked City',
#  "Women's Murder Club",
#  'Wonderland',
#  'Zero Hour',
#  'Automan',
#  'Battlestar Galactica',
#  'Defying Gravity',
#  'FlashForward',
#  'Galactica 1980',
#  'Invasion',
#  'Kolchak: The Night Stalker',
#  'Land of the Giants',
#  'Lost',
#  'Masters of Science Fiction',
#  'Max Headroom',
#  'Night Stalker',
#  'No Ordinary Family',
#  'Resurrection',
#  'Starman',
#  'Strange World',
#  'Tales of Tomorrow',
#  'The Bionic Woman',
#  'The Crossing',
#  'The Neighbors',
#  'The Outer Limits',
#  'The Phoenix',
#  'The Six Million Dollar Man',
#  'The Whispers',
#  'The Time Tunnel',
#  'Time After Time',
#  'V',
#  'Veritas: The Quest',
#  'Voyage to the Bottom of the Sea',
#  'A Man Called Shenandoah',
#  'Alias Smith and Jones',
#  'Bronco',
#  'Cheyenne',
#  'Custer',
#  'Kung Fu',
#  'Lash of the West',
#  'Maverick',
#  'The Big Valley',
#  'The Cowboys',
#  'The Guns of Will Sonnett',
#  'The Legend of Jesse James',
#  'The Lone Ranger',
#  'The Monroes',
#  'The Outcasts',
#  'The Rifleman',
#  'The Young Riders',
#  'Wagon Train',
#  'Wildside',
#  'Zorro',
#  '101 Ways to Leave a Game Show',
#  '500 Questions',
#  'All-Star Blitz',
#  'Bargain Hunters',
#  'Bet on Your Baby',
#  'Big Fan',
#  'Blankety Blanks',
#  'Break the Bank',
#  "Bruce Forsyth's Hot Streak",
#  'Camouflage',
#  'Crash Course',
#  'Dance Machine',
#  'Downfall',
#  'Dream House',
#  'Duel',
#  "Everybody's Talking",
#  'Family Feud',
#  'Fun and Fortune',
#  'Funny You Should Ask',
#  'Get the Message',
#  'Hot Seat',
#  "How's Your Mother-in-Law%3F",
#  'I Survived a Japanese Game Show',
#  "Let's Make a Deal",
#  'Master of Champions',
#  'Missing Links',
#  'Monopoly',
#  'National Bingo Night',
#  'Number Please',
#  'Opportunity Knocks',
#  'Password',
#  'Rhyme and Reason',
#  'Second Chance',
#  'Set for Life',
#  'Seven Keys',
#  'Shenanigans',
#  'Show Me the Money',
#  'Showoffs',
#  'Split Second',
#  'Supermarket Sweep',
#  'Temptation',
#  'Pyramid',
#  'Pyramid',
#  'The Better Sex',
#  'The Big Showdown',
#  'The Chair',
#  'The Dating Game',
#  'The Family Game',
#  'The Money Maze',
#  'The Neighbors',
#  'The Newlywed Game',
#  'The Object Is',
#  'The Price Is Right',
#  'The Reel Game',
#  'Trivia Trap',
#  'Wanna Bet%3F',
#  'Who Do You Trust%3F',
#  'Who Wants to Be a Millionaire',
#  'Wipeout',
#  'You Deserve It',
#  "You Don't Know Jack",
#  "You Don't Say!",
#  'Yours for a Song',
#  'Rich Man, Poor Man',
#  'Rich Man, Poor Man Book II',
#  'Roots',
#  'The Thorn Birds',
#  'The Winds of War',
#  'Lace',
#  'North and South',
#  'The Kennedys of Massachusetts',
#  'The Jacksons: An American Dream',
#  'Wild Palms',
#  'Anne Frank: The Whole Story',
#  'The Astronaut Wives Club',
#  'Madoff',
#  'When We Rise',
#  '20/2020/20 Downtown',
#  'Day One',
#  'Our World',
#  'Primetime',
#  '20/2020/20 Downtown',
#  'Turning Point',
#  'The Bugs Bunny Show',
#  'Capitol Critters',
#  'The Jetsons',
#  'Jonny Quest',
#  'Star Wars Rebels',
#  'Top Cat',
#  'Clerks',
#  'The Critic',
#  'The Flintstones',
#  'The Goode Family',
#  "Dr. Seuss' How the Grinch Stole Christmas",
#  'Those Amazing Animals',
#  "That's Incredible!",
#  'Fame, Fortune and Romance',
#  "Tim Conway's Funny America",
#  "America's Funniest People",
#  'Making the Band',
#  'MTV',
#  'The Mole',
#  'Houston Medical',
#  'Extreme Makeover',
#  'All American Girl',
#  'Are You Hot%3F',
#  'Extreme Makeover: Home Edition',
#  "I'm a Celebrity... Get Me Out of Here!",
#  'The Family',
#  'The Real Roseanne Show',
#  'The Benefactor',
#  'Wife Swap',
#  'Brat Camp',
#  'My Kind of Town',
#  'The Scholar',
#  'Supernanny',
#  'Miracle Workers',
#  'The One: Making a Music Star',
#  'One Ocean View',
#  'American Inventor',
#  'The Ex-Wives Club',
#  'Fast Cars and Superstars: The Gillette Young Guns Celebrity Race',
#  'Fat March',
#  'The Great American Dream Vote',
#  'The Next Best Thing',
#  "Shaq's Big Challenge",
#  'Just for Laughs',
#  'Dance War: Bruno vs. Carrie Ann',
#  'High School Musical: Get in the Picture',
#  'Hopkins',
#  "Oprah's Big Give",
#  'Here Come the Newlyweds',
#  'Find My Family',
#  'Homeland Security USA',
#  'The Superstars',
#  'Dating in the Dark',
#  'Shaq Vs.',
#  'True Beauty',
#  'Bachelor Pad',
#  'Boston Med',
#  "Jamie Oliver's Food Revolution",
#  'Skating with the Stars',
#  'Expedition Impossible',
#  'Take the Money and Run',
#  'Secret Millionaire',
#  'Extreme Weight Loss',
#  'Ball Boys',
#  'Final Witness',
#  'The Glass House',
#  'Duets',
#  'NY Med',
#  'Wife Swap',
#  'Splash',
#  'Whodunnit%3F',
#  'The Taste',
#  'Rising Star',
#  'Sing Your Face Off',
#  'The Quest',
#  'Repeat After Me',
#  'Save My Life: Boston Trauma',
#  'BattleBots',
#  'Beyond the Tank',
#  'Boston EMS',
#  'Greatest Hits',
#  'My Diet Is Better Than Yours',
#  'Boy Band',
#  'Battle of the Network Stars',
#  'People Icons',
#  "Steve Harvey's Funderdome",
#  'The Toy Box',
#  '101 Dalmatians: The Series',
#  'ABC Weekend Specials',
#  'Acrobat Ranch',
#  'Adventures of Sonic the Hedgehog',
#  'Adventures of the Gummi Bears',
#  'Aliens in the Family',
#  'Scooby-Doo',
#  'The Scooby-Doo/Dynomutt Hour',
#  'A Pup Named Scooby-Doo',
#  'Beany and Cecil',
#  'Beetlejuice',
#  'Bone Chillers',
#  'Buffalo Bill, Jr.',
#  'Born to Explore with Richard Wiese',
#  'Bump in the Night',
#  'Buzz Lightyear of Star Command',
#  'Captain Caveman and the Teen Angels',
#  'Cro',
#  'Darkwing Duck',
#  'Devlin',
#  'Doug',
#  'DuckTales',
#  'Dudley Do-Right',
#  'Dumb and Dumber',
#  'Even Stevens',
#  'Fangface',
#  'Fantastic Four',
#  'Fantastic Voyage',
#  'Fillmore!',
#  'Flash Forward',
#  'Fonz and the Happy Days Gang',
#  'Free Willy',
#  'Fudge',
#  'Gargoyles',
#  'George of the Jungle',
#  'Goldie Gold and Action Jack',
#  'Goober and the Ghost Chasers',
#  'Goof Troop',
#  'Hammerman',
#  'Hannah Montana',
#  'Heathcliff',
#  'Heathcliff',
#  'Hercules',
#  'Here Come the Double Deckers',
#  'Hong Kong Phooey',
#  'Hoppity Hooper',
#  'Hot Wheels',
#  "Disney's House of Mouse",
#  'Jabberjaw',
#  'Jonny Quest',
#  'Journey to the Center of the Earth',
#  'Jungle Cubs',
#  'Almost Anything Goes',
#  'Kid Power',
#  'Kim Possible',
#  'Krofft Supershow',
#  'Land of the Lost',
#  "Lassie's Rescue Rangers",
#  'Laverne & Shirley in the Army',
#  'Lidsville',
#  'Lilo & Stitch: The Series',
#  'Linus the Lionhearted',
#  'Little Clowns of Happytown',
#  'Little Rosie',
#  'Lizzie McGuire',
#  'Lloyd in Space',
#  'Madeline',
#  'Mary-Kate and Ashley in Action!',
#  "Matty's Funday Funnies",
#  'Menudo',
#  'Mickey Mouse Works',
#  'Mighty Ducks',
#  'Mighty Morphin Power Rangers',
#  'Mighty Orbots',
#  'Milton the Monster',
#  'Mission: Magic!',
#  'Monchichis',
#  'Mork & Mindy/Laverne & Shirley/Fonz Hour',
#  'My Pet Monster',
#  'NBA Inside Stuff',
#  'New Kids on the Block',
#  'Nightmare Ned',
#  'Ocean Mysteries with Jeff Corwin',
#  'Ocean Treks with Jeff Corwin',
#  'ABC Kids',
#  'Pac-Man',
#  'Pepper Ann',
#  'Peter Potamus',
#  'Phil of the Future',
#  'Pound Puppies',
#  'Power Rangers',
#  'Power Rangers Wild Force',
#  'Power Rangers Ninja Storm',
#  'Power Rangers Dino Thunder',
#  'Power Rangers S.P.D.',
#  'Power Rangers Mystic Force',
#  'Power Rangers Operation Overdrive',
#  'Power Rangers Jungle Fury',
#  'Power Rangers RPM',
#  'Quack Pack',
#  'ReBoot',
#  'Recess',
#  'Recipe Rehab',
#  'Richie Rich',
#  'The Rocky and Bullwinkle Show',
#  'Rubik, the Amazing Cube',
#  'Sabrina: The Animated Series',
#  'Schoolhouse Rock',
#  'Science Court',
#  'Skyhawks',
#  'Sonic the Hedgehog',
#  'Spider-Man',
#  'Spider-Woman',
#  'Squigglevision',
#  'Star Wars: Droids',
#  'Star Wars: Ewoks',
#  'Super Friends',
#  'Tales from the Cryptkeeper',
#  "Teacher's Pet",
#  'Teamo Supremo',
#  'Tennessee Tuxedo and His Tales',
#  "That's So Raven",
#  'The 13 Ghosts of Scooby-Doo',
#  'The ABC Saturday Superstar Movie',
#  'The Addams Family',
#  'The Adventures of Gulliver',
#  'The All-New Pink Panther Show',
#  'The Beatles',
#  'The Brady Kids',
#  'The Bugs Bunny Show',
#  'The Buzz on Maggie',
#  'The Care Bears',
#  'The Cattanooga Cats',
#  "The Emperor's New School",
#  'The Flintstone Kids',
#  'The Funky Phantom',
#  'The Great Grape Ape Show',
#  'The Groovie Goolies',
#  'The Hardy Boys',
#  'The Jackson 5ive',
#  'The Jetsons',
#  'The King Kong Show',
#  'The Legend of Tarzan',
#  'The Littles',
#  'The Lost Saucer',
#  'The Mickey Mouse Club',
#  'The Monkees',
#  'The Mumbly Cartoon Show',
#  'The New Adventures of Gilligan',
#  'The New Adventures of Winnie the Pooh',
#  'The New Casper Cartoon Show',
#  'The Oddball Couple',
#  'The Osmonds',
#  'The Pirates of Dark Water',
#  'The Plastic Man Comedy/Adventure Show',
#  'The Proud Family',
#  "The Puppy's Further Adventures",
#  'The Real Ghostbusters',
#  'The Replacements',
#  'The Suite Life of Zack & Cody',
#  'The Tom and Jerry Show',
#  'The Weekenders',
#  'The Wizard of Oz',
#  'The Wuzzles',
#  'These Are the Days',
#  'Thundarr the Barbarian',
#  'Top Cat',
#  'Turbo Teen',
#  "Uncle Croc's Block",
#  'W.I.T.C.H.',
#  'What-a-Mess',
#  'Wild West C.O.W.-Boys of Moo Mesa',
#  'Will the Real Jerry Lewis Please Sit Down',
#  'Wolf Rock TV',
#  "Yogi's Gang",
#  '8 Simple Rules',
#  '9 to 5',
#  'A New Kind of Family',
#  'A Touch of Grace',
#  'A Whole New Ballgame',
#  'A.E.S. Hudson Street',
#  'A.k.a. Pablo',
#  'According to Jim',
#  "Adam's Rib",
#  'Aliens in the Family',
#  'All American Girl',
#  'Alex, Inc.',
#  'Aloha Paradise',
#  "Amanda's",
#  'Angie',
#  'Anything But Love',
#  'Apple Pie',
#  'Arsenio',
#  'At Ease',
#  'Baby Makes Five',
#  'Baby Talk',
#  'Back in the Game',
#  'Barefoot in the Park',
#  'Barney Miller',
#  'Benson',
#  'Best of the West',
#  'Better Off Ted',
#  'Better with You',
#  'Bewitched',
#  'Big Day',
#  'Billy',
#  "Blansky's Beauties",
#  'Blue Skies',
#  'Bob & Carol & Ted & Alice',
#  'Bob Patterson',
#  'Bosom Buddies',
#  'Boy Meets World',
#  "Brother's Keeper",
#  'Buddies',
#  'Camp Wilder',
#  'Carpoolers',
#  'Carter Country',
#  'Cavemen',
#  'Chicken Soup',
#  'Clueless',
#  'Coach',
#  'Common Law',
#  'Complete Savages',
#  'Condo',
#  'Cougar Town',
#  'Cristela',
#  'Crumbs',
#  'Cupid',
#  'Cupid',
#  'Dads',
#  'Davis Rules',
#  'Delta',
#  'Delta House',
#  'Detective School',
#  'Dharma & Greg',
#  "Diff'rent Strokes",
#  'Dinosaurs',
#  "Don't Trust the B---- in Apartment 23",
#  'Downward Dog',
#  'Dr. Ken',
#  'Ellen',
#  "Emily's Reasons Why Not",
#  'F Troop',
#  'Family Matters',
#  'Family Tools',
#  'Fish',
#  'Freddie',
#  'Free Spirit',
#  'Full House',
#  'Galavant',
#  'George',
#  'George Lopez',
#  'Getting By',
#  'Getting Together',
#  'Gidget',
#  'Going Places',
#  'Good & Evil',
#  'Good Heavens',
#  'Grace Under Fire',
#  'Growing Pains',
#  'Hail to the Chief',
#  "Hangin' with Mr. Cooper",
#  'Hank',
#  'Happy Days',
#  'Happy Endings',
#  'Harrigan and Son',
#  'Have Faith',
#  "He's the Mayor",
#  'Head of the Class',
#  'Help Me Help You',
#  'Here Come the Brides',
#  "Hi Honey, I'm Home",
#  'Hiller and Diller',
#  'Holmes and Yo-Yo',
#  'Home Free',
#  'Home Improvement',
#  'Homeroom',
#  'Hope & Faith',
#  'Hot l Baltimore',
#  'Hot Properties',
#  'How to Live with Your Parents',
#  'Hudson Street',
#  'I Married Dora',
#  "I'm a Big Girl Now",
#  "I'm with Her",
#  'In Case of Emergency',
#  'In the Motherhood',
#  'Imaginary Mary',
#  'It Takes Two',
#  "It's a Living",
#  "It's All Relative",
#  "It's Like, You Know...",
#  "It's Not Easy",
#  'Jake in Progress',
#  'Joanie Loves Chachi',
#  'Julie',
#  'Just in Time',
#  'Just Our Luck',
#  'Just the Ten of Us',
#  'Last Man Standing',
#  'Laurie Hill',
#  'Laverne & Shirley',
#  'Leave It to Beaver',
#  'Less than Perfect',
#  'Life with Bonnie',
#  'Life with Lucy',
#  "Life's Work",
#  'Living Dolls',
#  'Love American Style',
#  'Madigan Men',
#  'Maggie',
#  "Makin' It",
#  'Malibu Country',
#  'Man Up!',
#  'Manhattan Love Story',
#  'Married People',
#  'Married to the Kellys',
#  'Maybe This Time',
#  "McHale's Navy",
#  'Me and the Boys',
#  'Miss Guided',
#  'Mixology',
#  'Mork & Mindy',
#  'Mr. Belvedere',
#  'Mr. Sunshine',
#  'Mr. Sunshine',
#  'Mr. T and Tina',
#  'My Life and Times',
#  'My Three Sons',
#  'My Wife and Kids',
#  'Nanny and the Professor',
#  "Nobody's Perfect",
#  'Notes from the Underbelly',
#  'Odd Man Out',
#  'Off the Rack',
#  'Oh Madeline',
#  'Oh, Grow Up',
#  'On Our Own',
#  'On the Air',
#  'On the Rocks',
#  'Open All Night',
#  'Operation Petticoat',
#  'Out of the Blue',
#  'Perfect Strangers',
#  'Phenom',
#  'Police Squad!',
#  'Rango',
#  'Reggie',
#  'Regular Joe',
#  'Rodney',
#  'Romantically Challenged',
#  'Room for Two',
#  'Roseanne',
#  'Sabrina the Teenage Witch',
#  'The WB',
#  'Samantha Who%3F',
#  'Scrubs',
#  'Selfie',
#  'Sibs',
#  'Sister, Sister',
#  'The WB',
#  'Sledge Hammer!',
#  'Soap',
#  'Something So Right',
#  'Sons & Daughters',
#  'Soul Man',
#  'Spin City',
#  'Sports Night',
#  'Star of the Family',
#  'Stat',
#  'Step by Step',
#  'CBS',
#  'Suburgatory',
#  'Super Fun Night',
#  'Surviving Suburbia',
#  'Tabitha',
#  'Tammy',
#  ...]

# %% [markdown]
# # TMDB

# %%
import tmdbsimple as tmdb

# %%
tmdb.API_KEY = 'a317708aa6c2e5d9aa0213f98af91cd7'

# %%
search = tmdb.Search()

# %%
tmdb_dict = {}
count = 0
for i in flat_list:
    tmdb_dict[i] = search.tv(query=i)
    count += 1
    if count % 100 == 0:
        print("Currently pulling: ", count)
# Out:
# Currently pulling:  100
# Currently pulling:  200
# Currently pulling:  300
# Currently pulling:  400
# Currently pulling:  500
# Currently pulling:  600
# Currently pulling:  700
# Currently pulling:  800
# Currently pulling:  900
# Currently pulling:  1000
# Currently pulling:  1100
# Currently pulling:  1200

# %%
len(tmdb_dict)
# Out:
# 1104

# %%
tmdb_id = {}

for i in tmdb_dict:
    print(tmdb_dict[i]['results'][0]['id'])
# Out:
# 1416
# 1403
# 61056
# 71712
# 71766
# 76773
# 79928
# 81499
# 1421
# 49009
# 61381
# 61692
# 67040
# 67117
# 71764
# 81127
# 4448
# 74729
# 1562
# 1508
# 30703
# 75534
# 61190
# 69024
# 77093
# 3626
# 80130
# 80297
# 81675
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-91-b49b22f90eee> in <module>()
#       2
#       3 for i in tmdb_dict:
# ----> 4     print(tmdb_dict[i]['results'][0]['id'])
#
# IndexError: list index out of range

# %%
tmdb_dict.keys()
# Out:
# dict_keys(["Grey's Anatomy", 'Agents of S.H.I.E.L.D.', 'How to Get Away with Murder', 'The Good Doctor', 'For the People', 'Station 19', 'Take Two', 'A Million Little Things', 'Modern Family', 'The Goldbergs', 'Black-ish', 'Fresh Off the Boat', 'Speechless', 'American Housewife', 'Splitting Up Together', 'Single Parents', "America's Funniest Home Videos", 'The Bachelor', 'The Bachelorette', 'Dancing with the Stars', 'Shark Tank', 'The Great Christmas Light Fight', 'Bachelor in Paradise', 'The Great American Baking Show', 'The Bachelor Winter Games', 'American Idol', 'The Last Defense', 'The Proposal', 'Castaways', "Santa Claus Is Comin' to Town", "Dick Clark's New Year's Rockin' Eve", "Rudolph's Shiny New Year", 'Disney Parks Christmas Day Parade', 'Peanuts', 'Shrek the Halls', 'Prep & Landing', 'Country Music Association', 'Prep & Landing: Naughty vs. Nice', 'Toy Story of Terror!', 'Toy Story That Time Forgot', "Olaf's Frozen Adventure", 'Celebrity Family Feud', 'To Tell the Truth', 'Pyramid', 'Match Game', 'The Gong Show', 'Child Support', 'General Hospital', 'American Music Awards', 'Academy Awards', 'Country Music Association Awards', 'Miss America', 'The View', 'Jimmy Kimmel Live!', 'The Alec Baldwin Show', 'GMA Day', 'ABC World News Tonight', 'Good Morning America', '20/20', 'Nightline', 'This Week', 'America This Morning', 'World News Now', 'What Would You Do%3F', 'People', 'Jack Hanna', 'Sea Rescue', 'The Wildlife Docs', 'Outback Adventures with Tim Faulkner', 'Ocean Treks with Jeff Corwin', 'The Ten Commandments', 'The Sound of Music', 'ABC Saturday Movie of the Week', 'Mary Poppins', 'Beauty and the Beast', 'Frozen', 'Flushed Away', 'National Football League', 'NFL Playoffs', 'ESPN', 'Pro Bowl', 'National Football League draft', 'National Basketball Association', 'NBA Countdown', 'National Basketball Association Christmas games', 'NBA Saturday Primetime', 'NBA Sunday Showcase', 'NBA playoffs', 'NBA Finals', "Women's National Basketball Association", 'ESPN College Football on ABC', 'Saturday Night Football', 'Atlantic Coast Conference', 'Big Ten Conference', 'Big 12 Conference', 'Pac-12 Conference', 'Wimbledon Championships', 'Formula 1', 'X Games', 'Little League World Series', 'The Fix', 'Grand Hotel', 'Reef Break', 'The Rookie', 'Whiskey Cavalier', 'The Conners', 'The Kids Are Alright', 'Schooled', 'Dancing with the Stars: Juniors', 'Gabriel Iglesias', 'Ryan Seacrest', 'Kenya Barris', 'Alec Baldwin', 'The Middle', 'Adventures in Paradise', 'Alias', 'Batman', 'Birdland', 'Blue Thunder', 'Chopper One', 'Combat Hospital', 'Firehouse', 'Last Resort', 'Lois & Clark: The New Adventures of Superman', 'MacGyver', 'Agent Carter', 'Inhumans', 'Once a Hero', 'Sable', 'Tales of the Gold Monkey', 'The Fall Guy', 'The Green Hornet', 'The Persuaders!', 'The Quest', 'The River', 'The Swiss Family Robinson', 'The Young Indiana Jones Chronicles', 'The Young Rebels', 'Wonder Woman', 'Zorro', 'Arresting Behavior', 'Cupid', 'Desperate Housewives', 'Doogie Howser, M.D.', 'Eight Is Enough', 'Eli Stone', 'GCB', 'Hooperman', 'Kevin Saves the World', 'Me and Mom', 'Moonlighting', 'Pushing Daisies', 'Room 222', 'Snoops', 'The Commish', 'The Greatest American Hero', 'The Love Boat', 'The Wonder Years', 'Ugly Betty', '10-8: Officers on Duty', '77 Sunset Strip', '240-Robert', '666 Park Avenue', 'A Fine Romance', 'American Crime', 'B.A.D. Cats', 'B.L. Stryker', 'Barbary Coast', 'Baretta', 'Ben Casey', "Bert D'Angelo/Superstar", 'Betrayal', 'Big Shots', 'Black Box', 'Blind Justice', 'Blood & Oil', 'Blue Light', 'Body of Proof', 'Boston Legal', 'Bourbon Street Beat', 'Brothers & Sisters', 'Buck James', "Burke's Law", 'Bus Stop', 'Call to Glory', 'Capital News', 'Caribe', 'Cashmere Mafia', 'Castle', 'Charlie Grace', "Charlie's Angels", 'China Beach', 'Civil Wars', 'Code Red', 'Combat!', 'Commander in Chief', 'Conviction', 'Cop Rock', 'Court Martial', 'Covington Cross', 'Crime with Father', 'Crossroads', 'Dan August', 'Dangerous Minds', 'Darkroom',  ...

# %%
if not tmdb_dict["Rudolph's Shiny New Year"]['results']:
    print('test')
# Out:
# test

# %%
tmdb_id = {}
count = 0
for i in tmdb_dict:
    if tmdb_dict[i]['results']:
        tmdb_id[i] = tmdb_dict[i]['results'][0]['id']
        count += 1
        if count % 100 == 0:
            print("Currently pulling: ", count)
    elif not tmdb_dict[i]['results']:
        print(i + " shows no results")
# Out:
# Santa Claus Is Comin' to Townshows no results
# Rudolph's Shiny New Yearshows no results
# Disney Parks Christmas Day Paradeshows no results
# Shrek the Hallsshows no results
# Country Music Associationshows no results
# Prep & Landing: Naughty vs. Niceshows no results
# Toy Story of Terror!shows no results
# Toy Story That Time Forgotshows no results
# Olaf's Frozen Adventureshows no results
# Country Music Association Awardsshows no results
# GMA Dayshows no results
# What Would You Do%3Fshows no results
# The Wildlife Docsshows no results
# Outback Adventures with Tim Faulknershows no results
# Ocean Treks with Jeff Corwinshows no results
# Flushed Awayshows no results
# National Football League draftshows no results
# National Basketball Associationshows no results
# National Basketball Association Christmas gamesshows no results
# NBA Saturday Primetimeshows no results
# NBA Sunday Showcaseshows no results
# NBA playoffsshows no results
# NBA Finalsshows no results
# Women's National Basketball Associationshows no results
# ESPN College Football on ABCshows no results
# Atlantic Coast Conferenceshows no results
# Big Ten Conferenceshows no results
# Big 12 Conferenceshows no results
# Pac-12 Conferenceshows no results
# Wimbledon Championshipsshows no results
# Little League World Seriesshows no results
# Reef Breakshows no results
# Kenya Barrisshows no results
# Currently pulling:  100
# Currently pulling:  200
# Currently pulling:  300
# Currently pulling:  400
# How's Your Mother-in-Law%3Fshows no results
# Wanna Bet%3Fshows no results
# Who Do You Trust%3Fshows no results
# 20/2020/20 Downtownshows no results
# Dr. Seuss' How the Grinch Stole Christmasshows no results
# Are You Hot%3Fshows no results
# Currently pulling:  500
# Final Witnessshows no results
# Whodunnit%3Fshows no results
# Sing Your Face Offshows no results
# My Diet Is Better Than Yoursshows no results
# ABC Weekend Specialsshows no results
# Currently pulling:  600
# Little Rosieshows no results
# Monchichisshows no results
# ABC Kidsshows no results
# Power Rangers Wild Forceshows no results
# Power Rangers Ninja Stormshows no results
# Power Rangers Dino Thundershows no results
# Power Rangers S.P.D.shows no results
# Power Rangers Mystic Forceshows no results
# Power Rangers Operation Overdriveshows no results
# Power Rangers Jungle Furyshows no results
# Power Rangers RPMshows no results
# Recessshows no results
# Squigglevisionshows no results
# The Cattanooga Catsshows no results
# Currently pulling:  700
# Currently pulling:  800
# The WBshows no results
# Samantha Who%3Fshows no results
# Currently pulling:  900
# What About Joan%3Fshows no results
# Who's the Boss%3Fshows no results
# Rose Bowl Gameshows no results
# Good Afternoon Americashows no results
# Currently pulling:  1000
# The Grand Ole Opryshows no results
# Whose Line Is It Anyway%3Fshows no results
# American Broadcasting Companyshows no results
# Deadline Hollywoodshows no results
# Template:ABCNetwork Showsshows no results
# Template talk:ABCNetwork Showsshows no results
# 20/20: In an Instantshows no results
# WNBA on ESPNshows no results

# %%
type(tmdb_id)
# Out:
# dict

# %%
#tmdb_id

# %%
show_id = tmdb.TV_Seasons(series_id=80550, season_number=1)
show_id.info()
# Out:
# {'_id': '5b3a0f9cc3a368454900c7af',
#  'air_date': '2018-09-24',
#  'episodes': [{'air_date': '2018-10-16',
#    'episode_number': 1,
#    'id': 1530138,
#    'name': "Keep on Truckin'",
#    'overview': 'A sudden turn of events forces the Conners to face the daily struggles of life in Lanford in a way they never have before.',
#    'production_code': None,
#    'season_number': 1,
#    'show_id': 80550,
#    'still_path': '/lSPlU6WM8exW5PWP1fQ4louSrY0.jpg',
#    'vote_average': 0.0,
#    'vote_count': 0,
#    'crew': [],
#    'guest_stars': []}],
#  'name': 'Season 1',
#  'overview': '',
#  'id': 105805,
#  'poster_path': None,
#  'season_number': 1}

# %% [raw]
# tmdb_season_dict = {}
#
# for key in tmdb_id:
#     for value in key:
#
#         for number in np.arange(0,30,1):
#             show_id = tmdb.TV_Seasons(series_id=value, season_number=number)
#             if show_id.
#             elif
#                 tmdb_season_dict[key] = tmdb.TV_Seasons(series_id=value, season_number=number))

# %% [markdown]
# #### Try doing this with the API directly - create an IF/ELSE statement that checks for status code to be 200 in order to proceed

# %% [markdown]
# Last thing to grab:
#
#     tmdb.TV_Episodes(series_id=2316, season_number=1, episode_number=1)

# %% [markdown]
# # OMDB

# %%
omdb_url = "http://www.omdbapi.com/?apikey=c998cfb7&"

# %%
omdb_params = {
    's':'Modern Family',
#    's':'shrek',
    'type':'series',
    'r': 'json',
    'fullplot': True,
    'tomatoes': True
}

# %%
res = requests.get(omdb_url, params=omdb_params)
res.text
# Out:
# '{"Search":[{"Title":"Modern Family","Year":"2009–","imdbID":"tt1442437","Type":"series","Poster":"https://m.media-amazon.com/images/M/MV5BMTI5MjUyYjUtMzhmOC00NTc3LWIzMTctMTVlOTA2NjI2NDU2XkEyXkFqcGdeQXVyMzAzNTY3MDM@._V1_SX300.jpg"},{"Title":"Balancing Act: Portraits of the Modern Family","Year":"2015–","imdbID":"tt4998566","Type":"series","Poster":"https://images-na.ssl-images-amazon.com/images/M/MV5BODIzNTI5NDU3Ml5BMl5BanBnXkFtZTgwMjc4Mzc3NjE@._V1_SX300.jpg"},{"Title":"Keswanis: A Most Modern Family","Year":"2015","imdbID":"tt6291042","Type":"series","Poster":"N/A"}],"totalResults":"3","Response":"True"}'

# %%
p = res.json()
p
# Out:
# {'Search': [{'Title': 'Modern Family',
#    'Year': '2009–',
#    'imdbID': 'tt1442437',
#    'Type': 'series',
#    'Poster': 'https://m.media-amazon.com/images/M/MV5BMTI5MjUyYjUtMzhmOC00NTc3LWIzMTctMTVlOTA2NjI2NDU2XkEyXkFqcGdeQXVyMzAzNTY3MDM@._V1_SX300.jpg'},
#   {'Title': 'Balancing Act: Portraits of the Modern Family',
#    'Year': '2015–',
#    'imdbID': 'tt4998566',
#    'Type': 'series',
#    'Poster': 'https://images-na.ssl-images-amazon.com/images/M/MV5BODIzNTI5NDU3Ml5BMl5BanBnXkFtZTgwMjc4Mzc3NjE@._V1_SX300.jpg'},
#   {'Title': 'Keswanis: A Most Modern Family',
#    'Year': '2015',
#    'imdbID': 'tt6291042',
#    'Type': 'series',
#    'Poster': 'N/A'}],
#  'totalResults': '3',
#  'Response': 'True'}

# %% [markdown]
# ## OMDB API Wrapper

# %%
import omdb

# %%
omdb.api._client.params_map['apikey'] = 'c998cfb7'
omdb.set_default('apikey', 'c998cfb7')

# %%
omdb_dict = {}
count = 0
for i in flat_list:
    omdb_dict[i] = (omdb.get(title=i, 
    fullplot=True, 
    tomatoes=True))
    count += 1
    if count % 100 == 0:
        print("Currently pulling: ", count)
# Out:
# Currently pulling:  100
# Currently pulling:  200
# Currently pulling:  300
# Currently pulling:  400
# Currently pulling:  500
# Currently pulling:  600
# Currently pulling:  700
# Currently pulling:  800
# Currently pulling:  900
# Currently pulling:  1000
# Currently pulling:  1100
# Currently pulling:  1200
# Currently pulling:  1300
# Currently pulling:  1400
# Currently pulling:  1500
# Currently pulling:  1600
# Currently pulling:  1700

# %%
omdb_dict.keys()
# Out:
# dict_keys(["Grey's Anatomy", 'Agents of S.H.I.E.L.D.', 'How to Get Away with Murder', 'The Good Doctor', 'For the People', 'Station 19', 'Take Two', 'A Million Little Things', 'Modern Family', 'The Goldbergs', 'Black-ish', 'Fresh Off the Boat', 'Speechless', 'American Housewife', 'Splitting Up Together', 'Single Parents', "America's Funniest Home Videos", 'The Bachelor', 'The Bachelorette', 'Dancing with the Stars', 'Shark Tank', 'The Great Christmas Light Fight', 'Bachelor in Paradise', 'The Great American Baking Show', 'The Bachelor Winter Games', 'American Idol', 'The Last Defense', 'The Proposal', 'Castaways', "Santa Claus Is Comin' to Town", "Dick Clark's New Year's Rockin' Eve", "Rudolph's Shiny New Year", 'Disney Parks Christmas Day Parade', 'Peanuts', 'Shrek the Halls', 'Prep & Landing', 'Country Music Association', 'Prep & Landing: Naughty vs. Nice', 'Toy Story of Terror!', 'Toy Story That Time Forgot', "Olaf's Frozen Adventure", 'Celebrity Family Feud', 'To Tell the Truth', 'Pyramid', 'Match Game', 'The Gong Show', 'Child Support', 'General Hospital', 'American Music Awards', 'Academy Awards', 'Country Music Association Awards', 'Miss America', 'The View', 'Jimmy Kimmel Live!', 'The Alec Baldwin Show', 'GMA Day', 'ABC World News Tonight', 'Good Morning America', '20/20', 'Nightline', 'This Week', 'America This Morning', 'World News Now', 'What Would You Do?', 'People', 'Jack Hanna', 'Sea Rescue', 'The Wildlife Docs', 'Outback Adventures with Tim Faulkner', 'Ocean Treks with Jeff Corwin', 'The Ten Commandments', 'The Sound of Music', 'ABC Saturday Movie of the Week', 'Mary Poppins', 'Beauty and the Beast', 'Frozen', 'Flushed Away', 'National Football League', 'NFL Playoffs', 'ESPN', 'Pro Bowl', 'National Football League draft', 'National Basketball Association', 'NBA Countdown', 'National Basketball Association Christmas games', 'NBA Saturday Primetime', 'NBA Sunday Showcase', 'NBA playoffs', 'NBA Finals', "Women's National Basketball Association", 'ESPN College Football on ABC', 'Saturday Night Football', 'Atlantic Coast Conference', 'Big Ten Conference', 'Big 12 Conference', 'Pac-12 Conference', 'Wimbledon Championships', 'Formula 1', 'X Games', 'Little League World Series', 'The Fix', 'Grand Hotel', 'Reef Break', 'The Rookie', 'Whiskey Cavalier', 'The Conners', 'The Kids Are Alright', 'Schooled', 'Dancing with the Stars: Juniors', 'Gabriel Iglesias', 'Ryan Seacrest', 'Kenya Barris', 'Alec Baldwin', 'The Middle', 'Adventures in Paradise', 'Alias', 'Batman', 'Birdland', 'Blue Thunder', 'Chopper One', 'Combat Hospital', 'Firehouse', 'Last Resort', 'Lois & Clark: The New Adventures of Superman', 'MacGyver', 'Agent Carter', 'Inhumans', 'Once a Hero', 'Sable', 'Tales of the Gold Monkey', 'The Fall Guy', 'The Green Hornet', 'The Persuaders!', 'The Quest', 'The River', 'The Swiss Family Robinson', 'The Young Indiana Jones Chronicles', 'The Young Rebels', 'Wonder Woman', 'Zorro', 'Arresting Behavior', 'Cupid', 'Desperate Housewives', 'Doogie Howser, M.D.', 'Eight Is Enough', 'Eli Stone', 'GCB', 'Hooperman', 'Kevin Saves the World', 'Me and Mom', 'Moonlighting', 'Pushing Daisies', 'Room 222', 'Snoops', 'The Commish', 'The Greatest American Hero', 'The Love Boat', 'The Wonder Years', 'Ugly Betty', '10-8: Officers on Duty', '77 Sunset Strip', '240-Robert', '666 Park Avenue', 'A Fine Romance', 'American Crime', 'B.A.D. Cats', 'B.L. Stryker', 'Barbary Coast', 'Baretta', 'Ben Casey', "Bert D'Angelo/Superstar", 'Betrayal', 'Big Shots', 'Black Box', 'Blind Justice', 'Blood & Oil', 'Blue Light', 'Body of Proof', 'Boston Legal', 'Bourbon Street Beat', 'Brothers & Sisters', 'Buck James', "Burke's Law", 'Bus Stop', 'Call to Glory', 'Capital News', 'Caribe', 'Cashmere Mafia', 'Castle', 'Charlie Grace', "Charlie's Angels", 'China Beach', 'Civil Wars', 'Code Red', 'Combat!', 'Commander in Chief', 'Conviction', 'Cop Rock', 'Court Martial', 'Covington Cross', 'Crime with Father', 'Crossroads', 'Dan August', 'Dangerous Minds', 'Darkroom', 'D ...

# %%
pp.pprint(omdb.get(title='Sea Rescue', 
         season=1, 
         episode=1,
         fullplot=True, 
         tomatoes=True))
# Out:
# { 'actors': 'Sam Champion',
#   'awards': 'N/A',
#   'box_office': 'N/A',
#   'country': 'N/A',
#   'director': 'Bryan Curb',
#   'dvd': 'N/A',
#   'episode': '1',
#   'genre': 'Family',
#   'imdb_id': 'tt2380855',
#   'imdb_rating': 'N/A',
#   'imdb_votes': 'N/A',
#   'language': 'N/A',
#   'metascore': 'N/A',
#   'plot': 'Rescuers race to assist a pod of more than 20 pilot whales that '
#           'have mysteriously stranded on a Florida beach. And, a baby dolphin '
#           'is tangled in a mass of potentially deadly fishing line while its f '
#           'rantic mother refuses to leave its side.',
#   'poster': 'http://ia.media-imdb.com/images/M/MV5BMTQ1NDkxODg1MF5BMl5BanBnXkFtZTgwNzgzNjczMjE@._V1_SX300.jpg',
#   'production': 'N/A',
#   'rated': 'N/A',
#   'ratings': [],
#   'released': '07 Apr 2012',
#   'response': 'True',
#   'runtime': '30 min',
#   'season': '1',
#   'series_id': 'tt2353113',
#   'title': 'Stranded',
#   'tomato_consensus': 'N/A',
#   'tomato_fresh': 'N/A',
#   'tomato_image': 'N/A',
#   'tomato_meter': 'N/A',
#   'tomato_rating': 'N/A',
#   'tomato_reviews': 'N/A',
#   'tomato_rotten': 'N/A',
#   'tomato_url': 'N/A',
#   'tomato_user_meter': 'N/A',
#   'tomato_user_rating': 'N/A',
#   'tomato_user_reviews': 'N/A',
#   'type': 'episode',
#   'website': 'N/A',
#   'writer': 'Nick Guettler',
#   'year': '2012'}

# %%
res = omdb.request(t='Sea Rescue', 
                   season=1, 
                   episode=1,
                   media_type='episode',
                   fullplot=True,
                   tomatoes=True,)

# %%
pp.pprint(res.json())
# Out:
# { 'Actors': 'Sam Champion',
#   'Awards': 'N/A',
#   'BoxOffice': 'N/A',
#   'Country': 'N/A',
#   'DVD': 'N/A',
#   'Director': 'Bryan Curb',
#   'Episode': '1',
#   'Genre': 'Family',
#   'Language': 'N/A',
#   'Metascore': 'N/A',
#   'Plot': 'Rescuers race to assist a pod of more than 20 pilot whales that '
#           'have mysteriously stranded on a Florida beach. And, a baby dolphin '
#           'is tangled in a mass of potentially deadly fishing line while its f '
#           'rantic mother refuses to leave its side.',
#   'Poster': 'http://ia.media-imdb.com/images/M/MV5BMTQ1NDkxODg1MF5BMl5BanBnXkFtZTgwNzgzNjczMjE@._V1_SX300.jpg',
#   'Production': 'N/A',
#   'Rated': 'N/A',
#   'Ratings': [],
#   'Released': '07 Apr 2012',
#   'Response': 'True',
#   'Runtime': '30 min',
#   'Season': '1',
#   'Title': 'Stranded',
#   'Type': 'episode',
#   'Website': 'N/A',
#   'Writer': 'Nick Guettler',
#   'Year': '2012',
#   'imdbID': 'tt2380855',
#   'imdbRating': 'N/A',
#   'imdbVotes': 'N/A',
#   'seriesID': 'tt2353113',
#   'tomatoConsensus': 'N/A',
#   'tomatoFresh': 'N/A',
#   'tomatoImage': 'N/A',
#   'tomatoMeter': 'N/A',
#   'tomatoRating': 'N/A',
#   'tomatoReviews': 'N/A',
#   'tomatoRotten': 'N/A',
#   'tomatoURL': 'N/A',
#   'tomatoUserMeter': 'N/A',
#   'tomatoUserRating': 'N/A',
#   'tomatoUserReviews': 'N/A'}

# %% [markdown]
# # TVDB

# %%
tvdb_url = "https://api.thetvdb.com"

headers = {
  "apikey": "I4NH1SXHARPKRI2P",
  "userkey": "J3E04YJ3CJ2KT7UO",
  "username": "ericyyoo0016tf"
}

# %%
login_url = tvdb_url + "/login"
y = requests.post(login_url, json=headers)
y.status_code
# Out:
# 200

# %%
token = y.text
token
# Out:
# '{"token":"eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCJ9.eyJleHAiOjE1MzkyMDExODgsImlkIjoiIiwib3JpZ19pYXQiOjE1MzkxMTQ3ODgsInVzZXJpZCI6NTEyMTc1LCJ1c2VybmFtZSI6ImVyaWN5eW9vMDAxNnRmIn0.dMetQusM1pAGbbsO3yaf6TxAWgOfqC5xLcL2DEWPxEQykGDw0v3ktCvbLcIlplTTGbNSnEjyRI9wUe995luc9SPedPpN8cKmpdcFwPncD2jd2BEFnFYEjF9aqSKUHfFd2kxpCWohJ1NxOXMNk_eqESTBk3z27TYPeAFr5PggWj6IhapzJzAT2XDzt4mMkzs0odfuqm2sFF3CRSBw5SVUIPm18n8iJtp6GSW036ne5OsTdPWB4lRjVdzzNXn-mDU2H5BapRrzEw-X9ZkHckfXrTex2aryR5y3j9hRjKHxjEXsms0BdAtyhxclnEexFbkWrS5sHh96OpITUE9vsHbLIA"}'

# %%
headers2 = {"Authorization":"Bearer eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCJ9.eyJleHAiOjE1MzkyMDExODgsImlkIjoiIiwib3JpZ19pYXQiOjE1MzkxMTQ3ODgsInVzZXJpZCI6NTEyMTc1LCJ1c2VybmFtZSI6ImVyaWN5eW9vMDAxNnRmIn0.dMetQusM1pAGbbsO3yaf6TxAWgOfqC5xLcL2DEWPxEQykGDw0v3ktCvbLcIlplTTGbNSnEjyRI9wUe995luc9SPedPpN8cKmpdcFwPncD2jd2BEFnFYEjF9aqSKUHfFd2kxpCWohJ1NxOXMNk_eqESTBk3z27TYPeAFr5PggWj6IhapzJzAT2XDzt4mMkzs0odfuqm2sFF3CRSBw5SVUIPm18n8iJtp6GSW036ne5OsTdPWB4lRjVdzzNXn-mDU2H5BapRrzEw-X9ZkHckfXrTex2aryR5y3j9hRjKHxjEXsms0BdAtyhxclnEexFbkWrS5sHh96OpITUE9vsHbLIA"}

# %% [markdown]
# ### Searching titles to grab ID

# %%
search_url = tvdb_url + "/search/series"

# %%
params = {"name":[flat_list[3]]}

# %%
res = requests.get(search_url, params=params, headers=headers2)

# %%
res.text
# Out:
# '{"data":[{"aliases":["The Good Doctor (KR) "],"banner":"graphical/271683-g2.jpg","firstAired":"2013-08-05","id":271683,"network":"KBS TV2","overview":"A medical drama based in the pediatrics department.\\r\\nThis drama will draw the story of a young man, Park Shi-on with Idiot Savant Syndrome who overcomes obstacles to become a pediatric surgeon. He is a pediatrician who despite his developmental disabilities is a medical genius. He is a gifted doctor but has trouble with other areas of his life, such as relating to people socially. \\r\\nMeanwhile, Cha Yoon-seo is a pediatric surgical fellow and Kim Do-han is the best pediatric surgeons in Korea. He will finds himself frequently in confrontation with Park Shi-on.","seriesName":"Good Doctor","slug":"good-doctor","status":"Ended"},{"aliases":["Good Doctor (US)"],"banner":"graphical/328634-g4.jpg","firstAired":"2017-09-25","id":328634,"network":"ABC (US)","overview":"Shaun Murphy, a young surgeon with autism and savant syndrome, relocates from a quiet country life to join a prestigious hospital\'s surgical unit. Alone in the world and unable to personally connect with those around him, Shaun uses his extraordinary medical gifts to save lives and challenge the skepticism of his colleagues. ","seriesName":"The Good Doctor","slug":"the-good-doctor","status":"Continuing"},{"aliases":[],"banner":"","firstAired":"","id":348149,"network":"Fuji TV","overview":"Twenty-six-years-old Shindo Minato has savant syndrome. His memory is amazing, but he has difficulty communicating with other people. When Shindo Minato was little, he dreamed of becoming a doctor. He meets Dr. Shiga Akira. Dr. Shiga was surprised by the seven-year-old\\u0026#39;s memory of the human organs and decided to support Shindo Minato in achieving his dream. Eventually, Shindo Minato graduates from a medical school. Shiga Akira who is currently a chief at a large hospital suggests Shindo Minato to work in that hospital\\u0026#39;s pediatric surgery department.","seriesName":"Good Doctor (JP)","slug":"good-doctor-jp","status":"Ended"}]}'

# %%
ga = res.json()
pp.pprint(ga)
# Out:
# { 'data': [ { 'aliases': ['The Good Doctor (KR) '],
#               'banner': 'graphical/271683-g2.jpg',
#               'firstAired': '2013-08-05',
#               'id': 271683,
#               'network': 'KBS TV2',
#               'overview': 'A medical drama based in the pediatrics '
#                           'department.\r\n'
#                           'This drama will draw the story of a young man, Park '
#                           'Shi-on with Idiot Savant Syndrome who overcomes '
#                           'obstacles to become a pediatric surgeon. He is a '
#                           'pediatrician who despite his developmental '
#                           'disabilities is a medical genius. He is a gifted '
#                           'doctor but has trouble with other areas of his '
#                           'life, such as relating to people socially. \r\n'
#                           'Meanwhile, Cha Yoon-seo is a pediatric surgical '
#                           'fellow and Kim Do-han is the best pediatric '
#                           'surgeons in Korea. He will finds himself frequently '
#                           'in confrontation with Park Shi-on.',
#               'seriesName': 'Good Doctor',
#               'slug': 'good-doctor',
#               'status': 'Ended'},
#             { 'aliases': ['Good Doctor (US)'],
#               'banner': 'graphical/328634-g4.jpg',
#               'firstAired': '2017-09-25',
#               'id': 328634,
#               'network': 'ABC (US)',
#               'overview': 'Shaun Murphy, a young surgeon with autism and '
#                           'savant syndrome, relocates from a quiet country '
#                           "life to join a prestigious hospital's surgical "
#                           'unit. Alone in the world and unable to personally '
#                           'connect with those around him, Shaun uses his '
#                           'extraordinary medical gifts to save lives and '
#                           'challenge the skepticism of his colleagues. ',
#               'seriesName': 'The Good Doctor',
#               'slug': 'the-good-doctor',
#               'status': 'Continuing'},
#             { 'aliases': [],
#               'banner': '',
#               'firstAired': '',
#               'id': 348149,
#               'network': 'Fuji TV',
#               'overview': 'Twenty-six-years-old Shindo Minato has savant '
#                           'syndrome. His memory is amazing, but he has '
#                           'difficulty communicating with other people. When '
#                           'Shindo Minato was little, he dreamed of becoming a '
#                           'doctor. He meets Dr. Shiga Akira. Dr. Shiga was '
#                           'surprised by the seven-year-old&#39;s memory of the '
#                           'human organs and decided to support Shindo Minato '
#                           'in achieving his dream. Eventually, Shindo Minato '
#                           'graduates from a medical school. Shiga Akira who is '
#                           'currently a chief at a large hospital suggests '
#                           'Shindo Minato to work in that hospital&#39;s '
#                           'pediatric surgery department.',
#               'seriesName': 'Good Doctor (JP)',
#               'slug': 'good-doctor-jp',
#               'status': 'Ended'}]}

# %%
ga_id = ga['data'][1]['id']
ga_id
# Out:
# 328634

# %% [markdown]
# ### Series using ID

# %%
series_url = tvdb_url + "/series/" + str(ga_id)
series_url
# Out:
# 'https://api.thetvdb.com/series/328634'

# %%
res2 = requests.get(series_url, headers=headers2)

# %%
ga_series = res2.json()
pp.pprint(ga_series)
# Out:
# { 'data': { 'added': '2017-05-16 10:22:44',
#             'addedBy': 396427,
#             'airsDayOfWeek': 'Monday',
#             'airsTime': '10:00 PM',
#             'aliases': ['Good Doctor (US)'],
#             'banner': 'graphical/328634-g4.jpg',
#             'firstAired': '2017-09-25',
#             'genre': ['Drama'],
#             'id': 328634,
#             'imdbId': 'tt6470478',
#             'lastUpdated': 1539111965,
#             'network': 'ABC (US)',
#             'networkId': '',
#             'overview': 'Shaun Murphy, a young surgeon with autism and savant '
#                         'syndrome, relocates from a quiet country life to join '
#                         "a prestigious hospital's surgical unit. Alone in the "
#                         'world and unable to personally connect with those '
#                         'around him, Shaun uses his extraordinary medical '
#                         'gifts to save lives and challenge the skepticism of '
#                         'his colleagues. ',
#             'rating': 'TV-14',
#             'runtime': '45',
#             'seriesId': '203695',
#             'seriesName': 'The Good Doctor',
#             'siteRating': 8.5,
#             'siteRatingCount': 18,
#             'slug': 'the-good-doctor',
#             'status': 'Continuing',
#             'zap2itId': 'SH02696628'}}

# %%
ga_series['data']
# Out:
# {'id': 328634,
#  'seriesName': 'The Good Doctor',
#  'aliases': ['Good Doctor (US)'],
#  'banner': 'graphical/328634-g4.jpg',
#  'seriesId': '203695',
#  'status': 'Continuing',
#  'firstAired': '2017-09-25',
#  'network': 'ABC (US)',
#  'networkId': '',
#  'runtime': '45',
#  'genre': ['Drama'],
#  'overview': "Shaun Murphy, a young surgeon with autism and savant syndrome, relocates from a quiet country life to join a prestigious hospital's surgical unit. Alone in the world and unable to personally connect with those around him, Shaun uses his extraordinary medical gifts to save lives and challenge the skepticism of his colleagues. ",
#  'lastUpdated': 1539111965,
#  'airsDayOfWeek': 'Monday',
#  'airsTime': '10:00 PM',
#  'rating': 'TV-14',
#  'imdbId': 'tt6470478',
#  'zap2itId': 'SH02696628',
#  'added': '2017-05-16 10:22:44',
#  'addedBy': 396427,
#  'siteRating': 8.5,
#  'siteRatingCount': 18,
#  'slug': 'the-good-doctor'}

# %%
series_ep_url = tvdb_url + '/series/' + str(ga_id) + '/episodes'
series_ep_url
# Out:
# 'https://api.thetvdb.com/series/328634/episodes'

# %%
params = {'page': '1'}

# Will need to count up on pages until a 404 is returned

# %%
res_test = requests.get(series_ep_url, params=params, headers=headers2)
pp.pprint(res_test.json())
# Out:
# { 'data': [ { 'absoluteNumber': 1,
#               'airedEpisodeNumber': 1,
#               'airedSeason': 1,
#               'airedSeasonID': 721921,
#               'airsAfterSeason': None,
#               'airsBeforeEpisode': None,
#               'airsBeforeSeason': None,
#               'director': 'Seth Gordon',
#               'directors': ['Seth Gordon'],
#               'dvdChapter': None,
#               'dvdDiscid': '',
#               'dvdEpisodeNumber': 1,
#               'dvdSeason': 1,
#               'episodeName': 'Burnt Food',
#               'filename': 'episodes/328634/6215283.jpg',
#               'firstAired': '2017-09-25',
#               'guestStars': ['Hannah Pederson'],
#               'id': 6215283,
#               'imdbId': 'tt6886400',
#               'language': {'episodeName': 'en', 'overview': 'en'},
#               'lastUpdated': 1537987606,
#               'lastUpdatedBy': 426467,
#               'overview': 'Dr. Shaun Murphy, a young surgeon with autism and '
#                           'savant syndrome, relocates from a quiet country '
#                           'life to join the prestigious St. Bonaventure '
#                           'hospital’s surgical unit. Alone in the world and '
#                           'unable to personally connect with those around him, '
#                           'his only advocate, Dr. Aaron Glassman, challenges '
#                           'the skepticism and prejudices of the hospital’s '
#                           'board and staff when he brings him in to join the '
#                           'team. Shaun will need to work harder than he ever '
#                           'has before, as he navigates his new environment and '
#                           'relationships to prove to his colleagues that his '
#                           'extraordinary medical gifts will save lives. ',
#               'productionCode': '101',
#               'seriesId': 328634,
#               'showUrl': '',
#               'siteRating': 8.8,
#               'siteRatingCount': 5,
#               'thumbAdded': '2017-08-05 14:56:06',
#               'thumbAuthor': 468845,
#               'thumbHeight': '225',
#               'thumbWidth': '400',
#               'writers': ['David Shore']},
#             { 'absoluteNumber': 2,
#               'airedEpisodeNumber': 2,
#               'airedSeason': 1,
#               'airedSeasonID': 721921,
#               'airsAfterSeason': None,
#               'airsBeforeEpisode': None,
#               'airsBeforeSeason': None,
#               'director': 'Mike Listo',
#               'directors': ['Mike Listo'],
#               'dvdChapter': None,
#               'dvdDiscid': '',
#               'dvdEpisodeNumber': 2,
#               'dvdSeason': 1,
#               'episodeName': 'Mount Rushmore',
#               'filename': 'episodes/328634/6306602.jpg',
#               'firstAired': '2017-10-02',
#               'guestStars': ['Jasika Nicole'],
#               'id': 6306602,
#               'imdbId': 'tt7179006',
#               'language': {'episodeName': 'en', 'overview': 'en'},
#               'lastUpdated': 1537987643,
#               'lastUpdatedBy': 426467,
#               'overview': 'Dr. Shaun Murphy’s attention to detail complicates '
#                           'his first day at St. Bonaventure Hospital. '
#                           'Meanwhile, Dr. Claire Browne learns a valuable '
#                           'lesson about honesty when confronted with a '
#                           'difficult diagnosis for her patient.',
#               'productionCode': '102',
#               'seriesId': 328634,
#               'showUrl': '',
#               'siteRating': 8.3,
#               'siteRatingCount': 6,
#               'thumbAdded': '2017-09-22 14:14:45',
#               'thumbAuthor': 468845,
#               'thumbHeight': '225',
#               'thumbWidth': '400',
#               'writers': ['David Shore']},
#             { 'absoluteNumber': 3,
#               'airedEpisodeNumber': 3,
#               'airedSeason': 1,
#               'airedSeasonID': 721921,
#               'airsAfterSeason': None,
#               'airsBeforeEpisode': None,
#               'airsBeforeSeason': None,
#               'director': 'John Dahl',
#               'directors': ['John Dahl'],
#               'dvdChapter': None,
#               'dvdDiscid': '',
#               'dvdEpisodeNumber': 3,
#               'dvdSeason': 1,
#               'episodeName': 'Oliver',
#               'filename': 'episodes/328634/6328600.jpg',
#               'firstAired': '2017-10-09',
#               'guestStars': [],
#               'id': 6328600,
#               'imdbId': 'tt7375334',
#               'language': {'episodeName': 'en', 'overview': 'en'},
#               'lastUpdated': 1537987676,
#               'lastUpdatedBy': 426467,
#               'overview': 'Dr. Neil Melendez and Dr. Jared Kalu discover their '
#                           'patient isn’t being completely honest with them '
#                           'which may cost him his chance at a life-saving '
#                           'surgery. Meanwhile, Dr. Claire Browne must learn to '
#                           'communicate with Dr. Shaun Murphy as they race back '
#                           'to St. Bonaventure Hospital with a donated organ.',
#               'productionCode': '103',
#               'seriesId': 328634,
#               'showUrl': '',
#               'siteRating': 7.7,
#               'siteRatingCount': 6,
#               'thumbAdded': '2017-09-27 17:44:56',
#               'thumbAuthor': 468845,
#               'thumbHeight': '225',
#               'thumbWidth': '400',
#               'writers': ['Bill Rotko']},
#             { 'absoluteNumber': 4,
#               'airedEpisodeNumber': 4,
#               'airedSeason': 1,
#               'airedSeasonID': 721921,
#               'airsAfterSeason': None,
#               'airsBeforeEpisode': None,
#               'airsBeforeSeason': None,
#               'director': 'Stephen DePaul',
#               'directors': ['Stephen DePaul'],
#               'dvdChapter': None,
#               'dvdDiscid': '',
#               'dvdEpisodeNumber': 4,
#               'dvdSeason': 1,
#               'episodeName': 'Pipes',
#               'filename': 'episodes/328634/6338342.jpg',
#               'firstAired': '2017-10-16',
#               'guestStars': [],
#               'id': 6338342,
#               'imdbId': 'tt7375342',
#               'language': {'episodeName': 'en', 'overview': 'en'},
#               'lastUpdated': 1537987730,
#               'lastUpdatedBy': 426467,
#               'overview': 'Dr. Neil Melendez and the team have to wade through '
#                           'legal waters when a husband and wife have to make a '
#                           'life-changing decision about their unborn child. '
#                           'Meanwhile, Dr. Shaun Murphy struggles to adjust to '
#                           'his new environment at home and makes a huge step '
#                           'forward with his colleagues.',
#               'productionCode': '',
#               'seriesId': 328634,
#               'showUrl': '',
#               'siteRating': 8,
#               'siteRatingCount': 5,
#               'thumbAdded': '2017-10-04 19:23:46',
#               'thumbAuthor': 468845,
#               'thumbHeight': '225',
#               'thumbWidth': '400',
#               'writers': ['Thomas L. Moran']},
#             { 'absoluteNumber': 5,
#               'airedEpisodeNumber': 5,
#               'airedSeason': 1,
#               'airedSeasonID': 721921,
#               'airsAfterSeason': None,
#               'airsBeforeEpisode': None,
#               'airsBeforeSeason': None,
#               'director': 'Larry Teng',
#               'directors': ['Larry Teng'],
#               'dvdChapter': None,
#               'dvdDiscid': '',
#               'dvdEpisodeNumber': 5,
#               'dvdSeason': 1,
#               'episodeName': 'Point Three Percent',
#               'filename': 'episodes/328634/6353553.jpg',
#               'firstAired': '2017-10-23',
#               'guestStars': [],
#               'id': 6353553,
#               'imdbId': 'tt7375346',
#               'language': {'episodeName': 'en', 'overview': 'en'},
#               'lastUpdated': 1537987764,
#               'lastUpdatedBy': 426467,
#               'overview': 'While in the exam area of St. Bonaventure Hospital, '
#                           'Dr. Shaun Murphy encounters a young patient who '
#                           'looks eerily similar to his deceased brother, '
#                           'Steve. After discovering his parents have hidden '
#                           'his diagnosis from him, Shaun struggles to '
#                           'understand why he doesn’t deserve to hear the truth '
#                           'about his own health. Meanwhile, the team can’t '
#                           'figure out what keeps triggering their patients’ '
#                           'increasingly severe allergic reactions and races to '
#                           'find the cause before the next one kills another '
#                           'patient.',
#               'productionCode': '',
#               'seriesId': 328634,
#               'showUrl': '',
#               'siteRating': 7.5,
#               'siteRatingCount': 4,
#               'thumbAdded': '2017-10-09 13:32:14',
#               'thumbAuthor': 468845,
#               'thumbHeight': '225',
#               'thumbWidth': '400',
#               'writers': ['David Hoselton']},
#             { 'absoluteNumber': 6,
#               'airedEpisodeNumber': 6,
#               'airedSeason': 1,
#               'airedSeasonID': 721921,
#               'airsAfterSeason': None,
#               'airsBeforeEpisode': None,
#               'airsBeforeSeason': None,
#               'director': 'Michael Patrick Jann',
#               'directors': ['Michael Patrick Jann'],
#               'dvdChapter': None,
#               'dvdDiscid': '',
#               'dvdEpisodeNumber': 6,
#               'dvdSeason': 1,
#               'episodeName': 'Not Fake',
#               'filename': 'episodes/328634/6362417.jpg',
#               'firstAired': '2017-10-30',
#               'guestStars': [],
#               'id': 6362417,
#               'imdbId': 'tt7375350',
#               'language': {'episodeName': 'en', 'overview': 'en'},
#               'lastUpdated': 1537987786,
#               'lastUpdatedBy': 426467,
#               'overview': 'Dr. Shaun Murphy and Dr. Claire Browne devise an '
#                           'experimental procedure that can save the leg and '
#                           'life of a young groom, that is if his bride-to-be '
#                           'and parents can learn to work together. Meanwhile, '
#                           'Jared struggles to emotionally connect with his '
#                           'patient whose scars may prove too deep to overcome.',
#               'productionCode': '',
#               'seriesId': 328634,
#               'showUrl': '',
#               'siteRating': 7.4,
#               'siteRatingCount': 5,
#               'thumbAdded': '2017-10-24 09:52:57',
#               'thumbAuthor': 468845,
#               'thumbHeight': '225',
#               'thumbWidth': '400',
#               'writers': ['Simran Baidwan']},
#             { 'absoluteNumber': 7,
#               'airedEpisodeNumber': 7,
#               'airedSeason': 1,
#               'airedSeasonID': 721921,
#               'airsAfterSeason': None,
#               'airsBeforeEpisode': None,
#               'airsBeforeSeason': None,
#               'director': 'David Straiton',
#               'directors': ['David Straiton'],
#               'dvdChapter': None,
#               'dvdDiscid': '',
#               'dvdEpisodeNumber': 7,
#               'dvdSeason': 1,
#               'episodeName': '22 Steps',
#               'filename': 'episodes/328634/6384925.jpg',
#               'firstAired': '2017-11-13',
#               'guestStars': [],
#               'id': 6384925,
#               'imdbId': 'tt7521790',
#               'language': {'episodeName': 'en', 'overview': 'en'},
#               'lastUpdated': 1537987818,
#               'lastUpdatedBy': 426467,
#               'overview': 'Dr. Shaun Murphy has to confront prejudice from an '
#                           'unlikely source when he takes on the case of a '
#                           'patient with autism, and Dr. Jared Kalu has to '
#                           'learn to accept his limitations as a surgeon.',
#               'productionCode': '',
#               'seriesId': 328634,
#               'showUrl': '',
#               'siteRating': 7.7,
#               'siteRatingCount': 3,
#               'thumbAdded': '2017-10-31 14:12:46',
#               'thumbAuthor': 468845,
#               'thumbHeight': '225',
#               'thumbWidth': '400',
#               'writers': ['Johanna Lee']},
#             { 'absoluteNumber': 8,
#               'airedEpisodeNumber': 8,
#               'airedSeason': 1,
#               'airedSeasonID': 721921,
#               'airsAfterSeason': None,
#               'airsBeforeEpisode': None,
#               'airsBeforeSeason': None,
#               'director': 'Nestor Carbonell',
#               'directors': ['Nestor Carbonell'],
#               'dvdChapter': None,
#               'dvdDiscid': '',
#               'dvdEpisodeNumber': 8,
#               'dvdSeason': 1,
#               'episodeName': 'Apple',
#               'filename': 'episodes/328634/6398802.jpg',
#               'firstAired': '2017-11-20',
#               'guestStars': [],
#               'id': 6398802,
#               'imdbId': 'tt7524390',
#               'language': {'episodeName': 'en', 'overview': 'en'},
#               'lastUpdated': 1537987841,
#               'lastUpdatedBy': 426467,
#               'overview': 'During a robbery at the grocery mart Dr. Shaun '
#                           'Murphy is shopping at, his communication '
#                           'limitations puts lives at risk. Meanwhile, after '
#                           'Shaun’s traumatic day, Dr. Aaron Glassman worries '
#                           'that he isn’t doing enough to help Shaun.',
#               'productionCode': '',
#               'seriesId': 328634,
#               'showUrl': '',
#               'siteRating': 8.2,
#               'siteRatingCount': 6,
#               'thumbAdded': '2017-11-18 06:22:46',
#               'thumbAuthor': 468845,
#               'thumbHeight': '225',
#               'thumbWidth': '400',
#               'writers': ['David Renaud']},
#             { 'absoluteNumber': 9,
#               'airedEpisodeNumber': 9,
#               'airedSeason': 1,
#               'airedSeasonID': 721921,
#               'airsAfterSeason': None,
#               'airsBeforeEpisode': None,
#               'airsBeforeSeason': None,
#               'director': 'Bronwen Hughes',
#               'directors': ['Bronwen Hughes'],
#               'dvdChapter': None,
#               'dvdDiscid': '',
#               'dvdEpisodeNumber': 9,
#               'dvdSeason': 1,
#               'episodeName': 'Intangibles',
#               'filename': 'episodes/328634/6404216.jpg',
#               'firstAired': '2017-11-27',
#               'guestStars': [],
#               'id': 6404216,
#               'imdbId': 'tt7524394',
#               'language': {'episodeName': 'en', 'overview': 'en'},
#               'lastUpdated': 1537987873,
#               'lastUpdatedBy': 426467,
#               'overview': 'As part of St. Bonaventure hospital’s international '
#                           'humanitarian program, the team takes on the case of '
#                           'a young boy from the Congo who has severe '
#                           'congenital heart anomalies. Dr. Neil Melendez has '
#                           'doubts about the safety of the procedure, while Dr. '
#                           'Shaun Murphy works out the best course of action. '
#                           'Meanwhile, Murphy’s latest encounter with his '
#                           'neighbor Lea has him confused.',
#               'productionCode': '',
#               'seriesId': 328634,
#               'showUrl': '',
#               'siteRating': 7.8,
#               'siteRatingCount': 5,
#               'thumbAdded': '2017-11-22 11:31:45',
#               'thumbAuthor': 468845,
#               'thumbHeight': '225',
#               'thumbWidth': '400',
#               'writers': ['Karen Struck']},
#             { 'absoluteNumber': 10,
#               'airedEpisodeNumber': 10,
#               'airedSeason': 1,
#               'airedSeasonID': 721921,
#               'airsAfterSeason': None,
#               'airsBeforeEpisode': None,
#               'airsBeforeSeason': None,
#               'director': 'Michael Patrick Jann',
#               'directors': ['Michael Patrick Jann'],
#               'dvdChapter': None,
#               'dvdDiscid': '',
#               'dvdEpisodeNumber': 10,
#               'dvdSeason': 1,
#               'episodeName': 'Sacrifice',
#               'filename': 'episodes/328634/6404217.jpg',
#               'firstAired': '2017-12-04',
#               'guestStars': [],
#               'id': 6404217,
#               'imdbId': 'tt7536406',
#               'language': {'episodeName': 'en', 'overview': 'en'},
#               'lastUpdated': 1537987902,
#               'lastUpdatedBy': 426467,
#               'overview': 'Members of the hospital’s surgical team are '
#                           'initially impressed with a charming young doctor, '
#                           'but his true character puts one of them in an '
#                           'awkward position at work. Meanwhile, Dr. Glassman '
#                           'feels Dr. Shaun Murphy needs a little more support '
#                           'with his personal life and suggests he meet with a '
#                           'therapist. However, Shaun is determined to show him '
#                           'that he can do it on his own.',
#               'productionCode': '',
#               'seriesId': 328634,
#               'showUrl': '',
#               'siteRating': 7.8,
#               'siteRatingCount': 4,
#               'thumbAdded': '2017-11-30 04:59:38',
#               'thumbAuthor': 468845,
#               'thumbHeight': '225',
#               'thumbWidth': '400',
#               'writers': ['Lloyd Gilyard Jr.']},
#             { 'absoluteNumber': 11,
#               'airedEpisodeNumber': 11,
#               'airedSeason': 1,
#               'airedSeasonID': 721921,
#               'airsAfterSeason': None,
#               'airsBeforeEpisode': None,
#               'airsBeforeSeason': None,
#               'director': 'Bill D’Elia',
#               'directors': ['Bill D’Elia'],
#               'dvdChapter': None,
#               'dvdDiscid': '',
#               'dvdEpisodeNumber': 11,
#               'dvdSeason': 1,
#               'episodeName': 'Islands: Part One',
#               'filename': 'episodes/328634/6431699.jpg',
#               'firstAired': '2018-01-08',
#               'guestStars': [],
#               'id': 6431699,
#               'imdbId': 'tt7536382',
#               'language': {'episodeName': 'en', 'overview': 'en'},
#               'lastUpdated': 1537987937,
#               'lastUpdatedBy': 426467,
#               'overview': 'Dr. Marcus Andrews enlists Dr. Neil Melendez on a '
#                           'very sensitive kidney transplant between a pair of '
#                           'twins; Dr. Shaun Murphy decides to take an '
#                           'impromptu trip with his friend Lea and leave his '
#                           'problems behind.',
#               'productionCode': '',
#               'seriesId': 328634,
#               'showUrl': '',
#               'siteRating': 7.5,
#               'siteRatingCount': 4,
#               'thumbAdded': '2017-12-22 17:43:10',
#               'thumbAuthor': 468845,
#               'thumbHeight': '225',
#               'thumbWidth': '400',
#               'writers': ['Thomas L. Moran', 'William Rotko']},
#             { 'absoluteNumber': 12,
#               'airedEpisodeNumber': 12,
#               'airedSeason': 1,
#               'airedSeasonID': 721921,
#               'airsAfterSeason': None,
#               'airsBeforeEpisode': None,
#               'airsBeforeSeason': None,
#               'director': 'Cherie Nowlan',
#               'directors': ['Cherie Nowlan'],
#               'dvdChapter': None,
#               'dvdDiscid': '',
#               'dvdEpisodeNumber': 12,
#               'dvdSeason': 1,
#               'episodeName': 'Islands: Part Two',
#               'filename': 'episodes/328634/6449965.jpg',
#               'firstAired': '2018-01-15',
#               'guestStars': [],
#               'id': 6449965,
#               'imdbId': 'tt7536386',
#               'language': {'episodeName': 'en', 'overview': 'en'},
#               'lastUpdated': 1537987966,
#               'lastUpdatedBy': 426467,
#               'overview': 'The twins suffer complications from their surgery '
#                           'forcing the team to make a life-changing decision. '
#                           'Shaun returns to the hospital after his trip with '
#                           'Lea and decides he needs a more permanent change – '
#                           'and gives Dr. Glassman his two weeks’ notice.',
#               'productionCode': '',
#               'seriesId': 328634,
#               'showUrl': '',
#               'siteRating': 8,
#               'siteRatingCount': 6,
#               'thumbAdded': '2018-01-03 05:58:33',
#               'thumbAuthor': 468845,
#               'thumbHeight': '225',
#               'thumbWidth': '400',
#               'writers': ['Thomas L. Moran', 'William Rotko']},
#             { 'absoluteNumber': 13,
#               'airedEpisodeNumber': 13,
#               'airedSeason': 1,
#               'airedSeasonID': 721921,
#               'airsAfterSeason': None,
#               'airsBeforeEpisode': None,
#               'airsBeforeSeason': None,
#               'director': 'Mike Listo',
#               'directors': ['Mike Listo'],
#               'dvdChapter': None,
#               'dvdDiscid': '',
#               'dvdEpisodeNumber': 13,
#               'dvdSeason': 1,
#               'episodeName': 'Seven Reasons',
#               'filename': 'episodes/328634/6489377.jpg',
#               'firstAired': '2018-01-22',
#               'guestStars': [],
#               'id': 6489377,
#               'imdbId': 'tt7557306',
#               'language': {'episodeName': 'en', 'overview': 'en'},
#               'lastUpdated': 1537988001,
#               'lastUpdatedBy': 426467,
#               'overview': 'Shaun suspects his patient is lying about the '
#                           'reason for her injury and makes a controversial '
#                           'assumption about her motives. Dr. Melendez’s '
#                           'personal life could be affecting his work and, '
#                           "ultimately, his patients' lives.",
#               'productionCode': '',
#               'seriesId': 328634,
#               'showUrl': '',
#               'siteRating': 7.8,
#               'siteRatingCount': 4,
#               'thumbAdded': '2018-01-10 14:25:23',
#               'thumbAuthor': 468845,
#               'thumbHeight': '225',
#               'thumbWidth': '400',
#               'writers': ['David Shore', 'David Hoselton']},
#             { 'absoluteNumber': 14,
#               'airedEpisodeNumber': 14,
#               'airedSeason': 1,
#               'airedSeasonID': 721921,
#               'airsAfterSeason': None,
#               'airsBeforeEpisode': None,
#               'airsBeforeSeason': None,
#               'director': 'Seth Gordon',
#               'directors': ['Seth Gordon'],
#               'dvdChapter': None,
#               'dvdDiscid': '',
#               'dvdEpisodeNumber': 14,
#               'dvdSeason': 1,
#               'episodeName': 'She',
#               'filename': 'episodes/328634/6508572.jpg',
#               'firstAired': '2018-02-05',
#               'guestStars': [],
#               'id': 6508572,
#               'imdbId': 'tt7762884',
#               'language': {'episodeName': 'en', 'overview': 'en'},
#               'lastUpdated': 1537988021,
#               'lastUpdatedBy': 426467,
#               'overview': 'Shaun is surprised to learn that his young cancer '
#                           'patient identifies as a girl while being '
#                           'biologically male. He must quickly learn to '
#                           'understand his patient, her medical needs and how '
#                           'to work with her family, who all feel they know '
#                           'what is best for her.',
#               'productionCode': '',
#               'seriesId': 328634,
#               'showUrl': '',
#               'siteRating': 7.3,
#               'siteRatingCount': 3,
#               'thumbAdded': '2018-01-26 13:16:22',
#               'thumbAuthor': 468845,
#               'thumbHeight': '225',
#               'thumbWidth': '400',
#               'writers': ['Simran Baidwan']},
#             { 'absoluteNumber': 15,
#               'airedEpisodeNumber': 15,
#               'airedSeason': 1,
#               'airedSeasonID': 721921,
#               'airsAfterSeason': None,
#               'airsBeforeEpisode': None,
#               'airsBeforeSeason': None,
#               'director': 'Regina King',
#               'directors': ['Regina King'],
#               'dvdChapter': None,
#               'dvdDiscid': '',
#               'dvdEpisodeNumber': 15,
#               'dvdSeason': 1,
#               'episodeName': 'Heartfelt',
#               'filename': 'episodes/328634/6508573.jpg',
#               'firstAired': '2018-02-26',
#               'guestStars': [],
#               'id': 6508573,
#               'imdbId': 'tt7762890',
#               'language': {'episodeName': 'en', 'overview': 'en'},
#               'lastUpdated': 1537988043,
#               'lastUpdatedBy': 426467,
#               'overview': "Dr. Shaun Murphy's teenage patient has been "
#                           'confined to her home her entire life due to a rare '
#                           'heart condition. Despite her condition, she has '
#                           'cultivated a large group of friends online and '
#                           'hopes that the surgical team can find a way to give '
#                           'her the life she has always dreamed of having. '
#                           "Meanwhile, a young patient's perfectly matched "
#                           'organ donor is causing a moral dilemma for the '
#                           'parents and the patient.',
#               'productionCode': '',
#               'seriesId': 328634,
#               'showUrl': '',
#               'siteRating': 7.3,
#               'siteRatingCount': 4,
#               'thumbAdded': '2018-02-26 19:14:29',
#               'thumbAuthor': 468845,
#               'thumbHeight': '225',
#               'thumbWidth': '400',
#               'writers': ['Thomas L. Moran', 'Johanna Lee']},
#             { 'absoluteNumber': 16,
#               'airedEpisodeNumber': 16,
#               'airedSeason': 1,
#               'airedSeasonID': 721921,
#               'airsAfterSeason': None,
#               'airsBeforeEpisode': None,
#               'airsBeforeSeason': None,
#               'director': 'Allison Liddi Brown',
#               'directors': ['Allison Liddi Brown'],
#               'dvdChapter': None,
#               'dvdDiscid': '',
#               'dvdEpisodeNumber': 16,
#               'dvdSeason': 1,
#               'episodeName': 'Pain',
#               'filename': 'episodes/328634/6508574.jpg',
#               'firstAired': '2018-03-12',
#               'guestStars': [],
#               'id': 6508574,
#               'imdbId': 'tt7762900',
#               'language': {'episodeName': 'en', 'overview': 'en'},
#               'lastUpdated': 1538057906,
#               'lastUpdatedBy': 501748,
#               'overview': 'When the team treats a patient who has to decide '
#                           'between a dangerous surgery that could change his '
#                           'life or remain the same, he asks Dr. Shaun Murphy '
#                           'what he would if he had that same choice.',
#               'productionCode': '',
#               'seriesId': 328634,
#               'showUrl': '',
#               'siteRating': 8,
#               'siteRatingCount': 4,
#               'thumbAdded': '2018-03-05 12:22:27',
#               'thumbAuthor': 468845,
#               'thumbHeight': '225',
#               'thumbWidth': '400',
#               'writers': ['William L. Rotko', 'David Renaud']},
#             { 'absoluteNumber': 17,
#               'airedEpisodeNumber': 17,
#               'airedSeason': 1,
#               'airedSeasonID': 721921,
#               'airsAfterSeason': None,
#               'airsBeforeEpisode': None,
#               'airsBeforeSeason': None,
#               'director': 'Bill D’Elia',
#               'directors': ['Bill D’Elia'],
#               'dvdChapter': None,
#               'dvdDiscid': '',
#               'dvdEpisodeNumber': 17,
#               'dvdSeason': 1,
#               'episodeName': 'Smile',
#               'filename': 'episodes/328634/6508575.jpg',
#               'firstAired': '2018-03-19',
#               'guestStars': ['Will Yun Lee', 'Fiona Gubelmann'],
#               'id': 6508575,
#               'imdbId': 'tt7762904',
#               'language': {'episodeName': 'en', 'overview': 'en'},
#               'lastUpdated': 1538057932,
#               'lastUpdatedBy': 501748,
#               'overview': 'Dr. Shaun Murphy questions the need for an elective '
#                           'surgery that will allow his young patient to smile '
#                           'for the first time. Meanwhile, Dr. Claire Brown and '
#                           'Dr. Morgan Reznick discover that their patient lied '
#                           'about her identity.',
#               'productionCode': '',
#               'seriesId': 328634,
#               'showUrl': '',
#               'siteRating': 8,
#               'siteRatingCount': 4,
#               'thumbAdded': '2018-03-06 16:38:51',
#               'thumbAuthor': 468845,
#               'thumbHeight': '225',
#               'thumbWidth': '400',
#               'writers': ['David Hoselton', 'Karen Struck']},
#             { 'absoluteNumber': 18,
#               'airedEpisodeNumber': 18,
#               'airedSeason': 1,
#               'airedSeasonID': 721921,
#               'airsAfterSeason': None,
#               'airsBeforeEpisode': None,
#               'airsBeforeSeason': None,
#               'director': 'Mike Listo',
#               'directors': ['Mike Listo'],
#               'dvdChapter': None,
#               'dvdDiscid': '',
#               'dvdEpisodeNumber': 18,
#               'dvdSeason': 1,
#               'episodeName': 'More',
#               'filename': 'episodes/328634/6508576.jpg',
#               'firstAired': '2018-03-26',
#               'guestStars': [ 'Will Yun Lee',
#                               'Fiona Gubelmann',
#                               'Donnie MacNeil',
#                               'Graham Patrick Martin',
#                               'Anjali Jay',
#                               'Audrey Wise Alvarez',
#                               'Aadila Dosani'],
#               'id': 6508576,
#               'imdbId': 'tt7762906',
#               'language': {'episodeName': 'en', 'overview': 'en'},
#               'lastUpdated': 1538428418,
#               'lastUpdatedBy': 501748,
#               'overview': 'The team at St. Bonaventure needs to quickly '
#                           'discover the truth behind a young college student’s '
#                           'unexplained injuries before his condition worsens. '
#                           'Meanwhile, after losing his most prized possession, '
#                           'Shaun’s distraction during a surgical procedure may '
#                           'end up risking more than just his job.',
#               'productionCode': '',
#               'seriesId': 328634,
#               'showUrl': '',
#               'siteRating': 7.5,
#               'siteRatingCount': 4,
#               'thumbAdded': '2018-03-12 11:54:50',
#               'thumbAuthor': 468845,
#               'thumbHeight': '225',
#               'thumbWidth': '400',
#               'writers': ['David Shore; Lloyd Gilyard, Jr.']},
#             { 'absoluteNumber': 19,
#               'airedEpisodeNumber': 1,
#               'airedSeason': 2,
#               'airedSeasonID': 759942,
#               'airsAfterSeason': None,
#               'airsBeforeEpisode': None,
#               'airsBeforeSeason': None,
#               'director': '|Mike Listo|',
#               'directors': ['Mike Listo'],
#               'dvdChapter': None,
#               'dvdDiscid': '',
#               'dvdEpisodeNumber': 1,
#               'dvdSeason': 2,
#               'episodeName': 'Hello',
#               'filename': 'episodes/328634/6640288.jpg',
#               'firstAired': '2018-09-24',
#               'guestStars': [ 'Lisa Edelstein',
#                               'Raphael Sbarge',
#                               'Lane Edwards',
#                               'Gabrielle Rose',
#                               'Carly Bentall',
#                               'Nitin Prasad',
#                               'Jessica Heafey',
#                               'Ema Mlinar',
#                               'Potjana Khongjareon',
#                               'Ray G. Thunderchild',
#                               'Nneka Croal',
#                               'Tony Nikl',
#                               'Jason Samson'],
#               'id': 6640288,
#               'imdbId': 'tt8242670',
#               'language': {'episodeName': 'en', 'overview': 'en'},
#               'lastUpdated': 1538487833,
#               'lastUpdatedBy': 456964,
#               'overview': 'Shaun’s proposed treatment for a homeless patient '
#                           'puts him and Dr. Kalu in Dr. Andrews’ crosshairs. '
#                           'Claire tries to overcome Dr. Melendez’s reluctance '
#                           'to do a risky heart operation. Dr. Glassman faces a '
#                           'difficult decision about his health.',
#               'productionCode': '201',
#               'seriesId': 328634,
#               'showUrl': '',
#               'siteRating': 9,
#               'siteRatingCount': 1,
#               'thumbAdded': '2018-09-12 14:36:26',
#               'thumbAuthor': 456964,
#               'thumbHeight': '225',
#               'thumbWidth': '400',
#               'writers': ['Freddie Highmore']},
#             { 'absoluteNumber': 20,
#               'airedEpisodeNumber': 2,
#               'airedSeason': 2,
#               'airedSeasonID': 759942,
#               'airsAfterSeason': None,
#               'airsBeforeEpisode': None,
#               'airsBeforeSeason': None,
#               'director': '|Steve Robin|',
#               'directors': ['Steve Robin'],
#               'dvdChapter': None,
#               'dvdDiscid': '',
#               'dvdEpisodeNumber': 2,
#               'dvdSeason': 2,
#               'episodeName': 'Middle Ground',
#               'filename': 'episodes/328634/6762369.jpg',
#               'firstAired': '2018-10-01',
#               'guestStars': [ 'Lisa Edelstein ',
#                               'Camille Hyde',
#                               'Necar Zadegan',
#                               'Khalilah Joi',
#                               'Alimi Ballard',
#                               'Faustino Di Bauda',
#                               'Jordana Largy',
#                               'Eileen Barrett',
#                               'Max Chadburn',
#                               'Conchita Campbell',
#                               'Arthur Mackinnon'],
#               'id': 6762369,
#               'imdbId': 'tt8680760',
#               'language': {'episodeName': 'en', 'overview': 'en'},
#               'lastUpdated': 1539111965,
#               'lastUpdatedBy': 435843,
#               'overview': 'As Shaun pushes back against Dr. Melendez in order '
#                           'to treat a gravely ill hospital janitor, Dr. Lim '
#                           'risks a lawsuit to repair a teenage girl’s ritual '
#                           'circumcision. Dr. Glassman exercises demanding '
#                           'oversight in choosing a doctor for his brain '
#                           'surgery.',
#               'productionCode': '202',
#               'seriesId': 328634,
#               'showUrl': '',
#               'siteRating': 10,
#               'siteRatingCount': 1,
#               'thumbAdded': '2018-09-24 20:40:37',
#               'thumbAuthor': 456964,
#               'thumbHeight': '225',
#               'thumbWidth': '400',
#               'writers': ['David Shore']},
#             { 'absoluteNumber': 21,
#               'airedEpisodeNumber': 3,
#               'airedSeason': 2,
#               'airedSeasonID': 759942,
#               'airsAfterSeason': None,
#               'airsBeforeEpisode': None,
#               'airsBeforeSeason': None,
#               'director': '|Larry Teng|',
#               'directors': ['Larry Teng'],
#               'dvdChapter': None,
#               'dvdDiscid': '',
#               'dvdEpisodeNumber': 2,
#               'dvdSeason': 2,
#               'episodeName': '36 Hours',
#               'filename': 'episodes/328634/6782343.jpg',
#               'firstAired': '2018-10-08',
#               'guestStars': [ 'Liza Lapira',
#                               'Holly Taylor',
#                               'Arjay Smith',
#                               'David DeSantos',
#                               'Elfina Luk',
#                               'Amatai Marmorstein',
#                               'Christine Willis',
#                               'Teryl Rothery',
#                               'Alvina August',
#                               'Sari Mercer',
#                               'Malik McCall',
#                               'Steve Baran',
#                               "Laura O'Reilly",
#                               'Caio De Figueiroa',
#                               'Isa Sanchez',
#                               'Takaya White',
#                               'Gregory Tavern',
#                               'Leslie Dos Remedios',
#                               'Damoon Gomari'],
#               'id': 6782343,
#               'imdbId': 'tt8707328',
#               'language': {'episodeName': 'en', 'overview': 'en'},
#               'lastUpdated': 1539091470,
#               'lastUpdatedBy': 456964,
#               'overview': 'Dr. Melendez, Dr. Brown and Dr. Park have given a '
#                           'young married couple two choices about their '
#                           'future: save the wife’s life or their future '
#                           'ability to start a family. Meanwhile, when Dr. Lim '
#                           'has to take care of some personal business, she '
#                           'leaves oversight of the emergency room to Dr. '
#                           'Murphy and Dr. Reznick; and Dr. Glassman’s post-op '
#                           'recovery leaves him struggling to get the rest he '
#                           'needs for recovery and also confronting his '
#                           'relationship with his daughter.',
#               'productionCode': '203',
#               'seriesId': 328634,
#               'showUrl': '',
#               'siteRating': 0,
#               'siteRatingCount': 0,
#               'thumbAdded': '2018-10-04 17:06:18',
#               'thumbAuthor': 456964,
#               'thumbHeight': '225',
#               'thumbWidth': '400',
#               'writers': ['Thomas L. Moran']},
#             { 'absoluteNumber': 22,
#               'airedEpisodeNumber': 4,
#               'airedSeason': 2,
#               'airedSeasonID': 759942,
#               'airsAfterSeason': None,
#               'airsBeforeEpisode': None,
#               'airsBeforeSeason': None,
#               'director': '|Steven DePaul|',
#               'directors': ['Steven DePaul'],
#               'dvdChapter': None,
#               'dvdDiscid': '',
#               'dvdEpisodeNumber': 4,
#               'dvdSeason': 2,
#               'episodeName': 'Tough Titmouse',
#               'filename': '',
#               'firstAired': '2018-10-15',
#               'guestStars': [ 'Graham Verchere',
#                               'Elfina Luk',
#                               'Teryl Rothery',
#                               'Holly Taylor',
#                               'Brooke Smith'],
#               'id': 6843706,
#               'imdbId': 'tt8970130',
#               'language': {'episodeName': 'en', 'overview': 'en'},
#               'lastUpdated': 1539049047,
#               'lastUpdatedBy': 495006,
#               'overview': 'Shaun recalls his own past to help an '
#                           'intellectually disabled teenager face separation '
#                           'from his mother, while Claire is put between an '
#                           'injured teenage rock climber and her worried '
#                           'parents. Meanwhile, Glassman’s post-op '
#                           'hallucinations force him to confront a personal '
#                           'tragedy.',
#               'productionCode': '204',
#               'seriesId': 328634,
#               'showUrl': '',
#               'siteRating': 0,
#               'siteRatingCount': 0,
#               'thumbAdded': '',
#               'thumbAuthor': 1,
#               'thumbHeight': None,
#               'thumbWidth': None,
#               'writers': ['David Hoselton']}],
#   'links': {'first': 1, 'last': 1, 'next': None, 'prev': None}}

# %% [markdown]
# ### Searching Episodes using ID

# %%
ep_url = tvdb_url + '/episodes/' + str(ga_id)
ep_url
# Out:
# 'https://api.thetvdb.com/episodes/328634'

# %%
res3 = requests.get(ep_url, headers=headers2)
ep_ga = res3.json()
pp.pprint(ep_ga)
# Out:
# { 'data': { 'absoluteNumber': None,
#             'airedEpisodeNumber': 1,
#             'airedSeason': 1,
#             'airedSeasonID': 17771,
#             'airsAfterSeason': None,
#             'airsBeforeEpisode': None,
#             'airsBeforeSeason': None,
#             'director': '',
#             'directors': [],
#             'dvdChapter': None,
#             'dvdDiscid': '',
#             'dvdEpisodeNumber': None,
#             'dvdSeason': None,
#             'episodeName': 'Trumors',
#             'filename': '',
#             'firstAired': '2007-03-27',
#             'guestStars': [],
#             'id': 328634,
#             'imdbId': '',
#             'language': {'episodeName': 'en', 'overview': 'en'},
#             'lastUpdated': 1483984657,
#             'lastUpdatedBy': 471726,
#             'overview': 'Reviews of the Aqua Teen Hunger Force movie and '
#                         'Cooking Mama: Cook Off for the Wii, discussion of '
#                         "John Carpenter's gaming habits, the Gears of War "
#                         'film, the Xbox Elite, Ratchet and Clank Future: Tools '
#                         'of Destruction, and more, and we answer viewer '
#                         'questions from before the first show has even aired! '
#                         'It\'s the Totally Rad Show Episode 1: "Trumors". The '
#                         'one in which Dan reveals more than he should about '
#                         'his upbringing, Jeff changes his tune about a certain '
#                         'gaming machine, Alex longs for a simpler time when '
#                         'people would crap in holes, and we all witness the '
#                         'big bang that begins the Radiverse.',
#             'productionCode': '',
#             'seriesId': 80140,
#             'showUrl': '',
#             'siteRating': 0,
#             'siteRatingCount': 0,
#             'thumbAdded': '',
#             'thumbAuthor': 1,
#             'thumbHeight': None,
#             'thumbWidth': None,
#             'writers': []}}

# %% [markdown]
# # Next Steps

# %% [markdown]
# Once I have obtained all the relevant information from the APIs, I will want to save them as individual dictionaries/sparse dataframes.

# %% [markdown]
# Current working features:
#     - Number of Seasons
#     - Number of Episodes in Season
#     - Director - Will need to be weighted
#     - Show Overview - NLP for topics?
#     - Season Overview - NLP for topics?
#     - Episode Overview - NLP for topics?
#     - Writers - Will need to be weighted
#     - Network - Categorical
#     - Guest Stars - 0/1
#     - Series Name
#     - Status
#     - Runtime
#     - Genre
#     - AirDay
#     - AirTime
#     - IMDB Rating
#     - IMDB Number of Ratings
