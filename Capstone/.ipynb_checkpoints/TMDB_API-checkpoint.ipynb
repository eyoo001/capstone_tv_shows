# %%
import requests
import time
import pandas as pd
import pprint
import re

pp = pprint.PrettyPrinter(indent=2)

# %%
import tmdbsimple as tmdb

# %%
import pickle

with open ('new_show_list', 'rb') as fp:
    show_names = pickle.load(fp)
    
with open ('show_list', 'rb') as fp:
    show_list = pickle.load(fp)

# %%
show_list[:10]
# Out:
# [['Grey%27s_Anatomy'],
#  ['Agents_of_S.H.I.E.L.D.'],
#  ['How_to_Get_Away_with_Murder'],
#  ['The_Good_Doctor_(TV_series)'],
#  ['For_the_People_(2018_TV_series)'],
#  ['Station_19'],
#  ['Take_Two_(TV_series)'],
#  ['A_Million_Little_Things'],
#  ['Modern_Family'],
#  ['The_Goldbergs_(2013_TV_series)']]

# %%
flat_list = [item for sublist in show_list for item in sublist]

# %%
flat_list = [re.sub('_', ' ', i) for i in flat_list]

# %%
flat_list = [re.sub('%27', '\'', i) for i in flat_list]

# %%
flat_list = [re.sub(' \(([^)]+)\)', '', i) for i in flat_list]

# %%
flat_list = [re.sub('%26', '\'', i) for i in flat_list]

# %%
flat_list[:10]
# Out:
# ["Grey's Anatomy",
#  'Agents of S.H.I.E.L.D.',
#  'How to Get Away with Murder',
#  'The Good Doctor',
#  'For the People',
#  'Station 19',
#  'Take Two',
#  'A Million Little Things',
#  'Modern Family',
#  'The Goldbergs']

# %%
with open('clean_list', 'wb') as fp:
    pickle.dump(flat_list, fp)

# %%
len(flat_list)
# Out:
# 63878

# %%
tmdb.API_KEY = 'a317708aa6c2e5d9aa0213f98af91cd7'

# %%
search = tmdb.Search()

# %%
omdb_dict = {}
count = 0
for i in flat_list:
    omdb_dict[i] = search.tv(query=i)
    count += 1
    if count % 250 == 0:
        print("Currently pulling: ", count)
# Out:
# Currently pulling:  250
# Currently pulling:  500
# Currently pulling:  750
# Currently pulling:  1000
# Currently pulling:  1250
# Currently pulling:  1500
# Currently pulling:  1750
# Currently pulling:  2000
# Currently pulling:  2250
# Currently pulling:  2500
# Currently pulling:  2750
# Currently pulling:  3000
# Currently pulling:  3250
# Currently pulling:  3500
# Currently pulling:  3750
# Currently pulling:  4000
# Currently pulling:  4250
# Currently pulling:  4500
# Currently pulling:  4750
# Currently pulling:  5000
# Currently pulling:  5250
# Currently pulling:  5500
# Currently pulling:  5750
# Currently pulling:  6000
# Currently pulling:  6250
# Currently pulling:  6500
# Currently pulling:  6750
# Currently pulling:  7000
# Currently pulling:  7250
# Currently pulling:  7500
# Currently pulling:  7750
# Currently pulling:  8000
# Currently pulling:  8250
# Currently pulling:  8500
# Currently pulling:  8750
# Currently pulling:  9000
# Currently pulling:  9250
# Currently pulling:  9500
# Currently pulling:  9750
# Currently pulling:  10000
# Currently pulling:  10250
# Currently pulling:  10500
# Currently pulling:  10750
# Currently pulling:  11000
# Currently pulling:  11250
# Currently pulling:  11500
# Currently pulling:  11750
# Currently pulling:  12000
# Currently pulling:  12250
# Currently pulling:  12500
# Currently pulling:  12750
# Currently pulling:  13000
# Currently pulling:  13250
# Currently pulling:  13500
# Currently pulling:  13750
# Currently pulling:  14000
# Currently pulling:  14250
# Currently pulling:  14500
# Currently pulling:  14750
# Currently pulling:  15000
# Currently pulling:  15250
# Currently pulling:  15500
# Currently pulling:  15750
# Currently pulling:  16000
# Currently pulling:  16250
# Currently pulling:  16500
# Currently pulling:  16750
# Currently pulling:  17000
# Currently pulling:  17250
# Currently pulling:  17500
# Currently pulling:  17750
# Currently pulling:  18000
# Currently pulling:  18250
# Currently pulling:  18500
# Currently pulling:  18750
# Currently pulling:  19000
# Currently pulling:  19250
# Currently pulling:  19500
# Currently pulling:  19750
# Currently pulling:  20000
# Currently pulling:  20250
# Currently pulling:  20500
# Currently pulling:  20750
# Currently pulling:  21000
# Currently pulling:  21250
# Currently pulling:  21500
# Currently pulling:  21750
# Currently pulling:  22000
# Currently pulling:  22250
# Currently pulling:  22500
# Currently pulling:  22750
# Currently pulling:  23000
# Currently pulling:  23250
# Currently pulling:  23500
# Currently pulling:  23750
# Currently pulling:  24000
# Currently pulling:  24250
# Currently pulling:  24500
# Currently pulling:  24750
# Currently pulling:  25000
# Currently pulling:  25250
# Currently pulling:  25500
# Currently pulling:  25750
# Currently pulling:  26000
# Currently pulling:  26250
# Currently pulling:  26500
# Currently pulling:  26750
# Currently pulling:  27000
# Currently pulling:  27250
# Currently pulling:  27500
# Currently pulling:  27750
# Currently pulling:  28000
# Currently pulling:  28250
# Currently pulling:  28500
# Currently pulling:  28750
# Currently pulling:  29000
# Currently pulling:  29250
# Currently pulling:  29500
# Currently pulling:  29750
# Currently pulling:  30000
# Currently pulling:  30250
# Currently pulling:  30500
# Currently pulling:  30750
# Currently pulling:  31000
# Currently pulling:  31250
# Currently pulling:  31500
# Currently pulling:  31750
# Currently pulling:  32000
# Currently pulling:  32250
# Currently pulling:  32500
# Currently pulling:  32750
# Currently pulling:  33000
# Currently pulling:  33250
# Currently pulling:  33500
# Currently pulling:  33750
# Currently pulling:  34000
# Currently pulling:  34250
# Currently pulling:  34500
# Currently pulling:  34750
# Currently pulling:  35000
# Currently pulling:  35250
# Currently pulling:  35500
# Currently pulling:  35750
# Currently pulling:  36000
# Currently pulling:  36250
# Currently pulling:  36500
# Currently pulling:  36750
# Currently pulling:  37000
# Currently pulling:  37250
# Currently pulling:  37500
# Currently pulling:  37750
# Currently pulling:  38000
# Currently pulling:  38250
# Currently pulling:  38500
# Currently pulling:  38750
# Currently pulling:  39000
# Currently pulling:  39250
# Currently pulling:  39500
# Currently pulling:  39750
# Currently pulling:  40000
# Currently pulling:  40250
# Currently pulling:  40500
# Currently pulling:  40750
# Currently pulling:  41000
# Currently pulling:  41250
# Currently pulling:  41500
# Currently pulling:  41750
# Currently pulling:  42000
# Currently pulling:  42250
# Currently pulling:  42500
# Currently pulling:  42750
# Currently pulling:  43000
# Currently pulling:  43250
# Currently pulling:  43500
# Currently pulling:  43750
# Currently pulling:  44000
# Currently pulling:  44250
# Currently pulling:  44500
# Currently pulling:  44750
# Currently pulling:  45000
# Currently pulling:  45250
# Currently pulling:  45500
# Currently pulling:  45750
# Currently pulling:  46000
# Currently pulling:  46250
# Currently pulling:  46500
# Currently pulling:  46750
# Currently pulling:  47000
# Currently pulling:  47250
# Currently pulling:  47500
# Currently pulling:  47750
# Currently pulling:  48000
# Currently pulling:  48250
# Currently pulling:  48500
# Currently pulling:  48750
# Currently pulling:  49000
# Currently pulling:  49250
# Currently pulling:  49500
# Currently pulling:  49750
# Currently pulling:  50000
# Currently pulling:  50250
# Currently pulling:  50500
# Currently pulling:  50750
# Currently pulling:  51000
# Currently pulling:  51250
# Currently pulling:  51500
# Currently pulling:  51750
# Currently pulling:  52000
# Currently pulling:  52250
# Currently pulling:  52500
# Currently pulling:  52750
# Currently pulling:  53000
# Currently pulling:  53250
# Currently pulling:  53500
# Currently pulling:  53750
# Currently pulling:  54000
# Currently pulling:  54250
# Currently pulling:  54500
# Currently pulling:  54750
# Currently pulling:  55000
# Currently pulling:  55250
# Currently pulling:  55500
# Currently pulling:  55750
# Currently pulling:  56000
# Currently pulling:  56250
# Currently pulling:  56500
# Currently pulling:  56750
# Currently pulling:  57000
# Currently pulling:  57250
# Currently pulling:  57500
# Currently pulling:  57750
# Currently pulling:  58000
# Currently pulling:  58250
# Currently pulling:  58500
# Currently pulling:  58750
# Currently pulling:  59000
# Currently pulling:  59250
# Currently pulling:  59500
# Currently pulling:  59750
# Currently pulling:  60000
# Currently pulling:  60250
# Currently pulling:  60500
# Currently pulling:  60750
# Currently pulling:  61000
# Currently pulling:  61250
# Currently pulling:  61500
# Currently pulling:  61750
# Currently pulling:  62000
# Currently pulling:  62250
# Currently pulling:  62500
# Currently pulling:  62750
# Currently pulling:  63000
# Currently pulling:  63250
# Currently pulling:  63500
# Currently pulling:  63750

# %%
len(omdb_dict)
# Out:
# 12725

# %%
omdb_dict.keys()
# Out:
# dict_keys(["Grey's Anatomy", 'Agents of S.H.I.E.L.D.', 'How to Get Away with Murder', 'The Good Doctor ', 'For the People ', 'Station 19', 'Take Two ', 'A Million Little Things', 'Modern Family', 'The Goldbergs ', 'Black-ish', 'Fresh Off the Boat', 'Speechless ', 'American Housewife', 'Splitting Up Together', 'Single Parents ', "America's Funniest Home Videos", 'The Bachelor ', 'The Bachelorette', 'Dancing with the Stars ', 'Shark Tank', 'The Great Christmas Light Fight', 'Bachelor in Paradise ', 'The Great American Baking Show', 'The Bachelor Winter Games', 'American Idol', 'The Last Defense ', 'The Proposal ', 'Castaways ', "Santa Claus Is Comin' to Town", "Dick Clark's New Year's Rockin' Eve", "Rudolph's Shiny New Year", 'Disney Parks Christmas Day Parade', 'Peanuts', 'Shrek the Halls', 'Prep %26 Landing', 'Country Music Association', 'Prep %26 Landing: Naughty vs. Nice', 'Toy Story of Terror!', 'Toy Story That Time Forgot', "Olaf's Frozen Adventure", 'Celebrity Family Feud', 'To Tell the Truth', 'Pyramid ', 'Match Game', 'The Gong Show', 'Child Support ', 'General Hospital', 'American Music Awards', 'Academy Awards', 'Country Music Association Awards', 'Miss America', 'The View ', 'Jimmy Kimmel Live!', 'The Alec Baldwin Show', 'GMA Day', 'ABC World News Tonight', 'Good Morning America', '20/20 ', 'Nightline', 'This Week ', 'America This Morning', 'World News Now', 'What Would You Do%3F ', 'People ', 'Jack Hanna', 'Sea Rescue', 'The Wildlife Docs', 'Outback Adventures with Tim Faulkner', 'Ocean Treks with Jeff Corwin', 'The Ten Commandments ', 'The Sound of Music ', 'ABC Saturday Movie of the Week', 'Mary Poppins ', 'Beauty and the Beast ', 'Frozen ', 'Flushed Away', 'National Football League', 'NFL Playoffs', 'ESPN', 'Pro Bowl', 'National Football League draft', 'National Basketball Association', 'NBA Countdown', 'National Basketball Association Christmas games', 'NBA Saturday Primetime', 'NBA Sunday Showcase', 'NBA playoffs', 'NBA Finals', "Women's National Basketball Association", 'ESPN College Football on ABC', 'Saturday Night Football', 'Atlantic Coast Conference', 'Big Ten Conference', 'Big 12 Conference', 'Pac-12 Conference', 'Wimbledon Championships', 'Formula 1', 'X Games', 'Little League World Series', 'The Fix ', 'Grand Hotel ', 'Reef Break', 'The Rookie ', 'Whiskey Cavalier', 'The Conners', 'The Kids Are Alright ', 'Schooled ', 'Gabriel Iglesias', 'Ryan Seacrest', 'Kenya Barris', 'Alec Baldwin', 'The Middle ', 'Adventures in Paradise ', 'Alias ', 'Batman ', 'Birdland ', 'Blue Thunder ', 'Chopper One', 'Combat Hospital', 'Firehouse ', 'Last Resort ', 'Lois %26 Clark: The New Adventures of Superman', 'MacGyver ', 'Agent Carter ', 'Inhumans ', 'Once a Hero', 'Sable ', 'Tales of the Gold Monkey', 'The Fall Guy', 'The Green Hornet ', 'The Persuaders!', 'The Quest ', 'The River ', 'The Swiss Family Robinson ', 'The Young Indiana Jones Chronicles', 'The Young Rebels', 'Wonder Woman ', 'Zorro ', 'Arresting Behavior', 'Cupid ', 'Desperate Housewives', 'Doogie Howser, M.D.', 'Eight Is Enough', 'Eli Stone', 'GCB ', 'Hooperman', 'Kevin  Saves the World', 'Me and Mom', 'Moonlighting ', 'Pushing Daisies', 'Room 222', 'Snoops ', 'The Commish', 'The Greatest American Hero', 'The Love Boat', 'The Wonder Years', 'Ugly Betty', '10-8: Officers on Duty', '77 Sunset Strip', '240-Robert', '666 Park Avenue', 'A Fine Romance ', 'American Crime ', 'B.A.D. Cats', 'B.L. Stryker', 'Barbary Coast ', 'Baretta', 'Ben Casey', "Bert D'Angelo/Superstar", 'Betrayal ', 'Big Shots ', 'Black Box ', 'Blind Justice ', 'Blood %26 Oil', 'Blue Light ', 'Body of Proof', 'Boston Legal', 'Bourbon Street Beat', 'Brothers %26 Sisters ', 'Buck James', "Burke's Law ", 'Bus Stop ', 'Call to Glory', 'Capital News', 'Caribe ', 'Cashmere Mafia', 'Castle ', 'Charlie Grace ', "Charlie's Angels", "Charlie's Angels ", 'China Beach', 'Civil Wars ', 'Code Red ', 'Combat!', 'Commander in Chief ', 'Conviction ', 'Cop Rock', 'Court Martial ', 'Covington Cross', 'Crime with F ...

# %% [markdown]
# # Need to clean the "category: " and "network: " etc. names

# %%
omdb_dict['How to Get Away with Murder']
# Out:
# {'page': 1,
#  'total_results': 1,
#  'total_pages': 1,
#  'results': [{'original_name': 'How to Get Away with Murder',
#    'id': 61056,
#    'name': 'How to Get Away with Murder',
#    'vote_count': 341,
#    'vote_average': 7.41,
#    'poster_path': '/llEtOsaRoVoNN0dtsYenAvelNxX.jpg',
#    'first_air_date': '2014-09-25',
#    'popularity': 32.701,
#    'genre_ids': [80, 18, 9648],
#    'original_language': 'en',
#    'backdrop_path': '/bzji0Cti9iuzzFeVDsB0S815RaG.jpg',
#    'overview': 'A sexy, suspense-driven legal thriller about a group of ambitious law students and their brilliant, mysterious criminal defense professor. They become entangled in a murder plot and will shake the entire university and change the course of their lives.',
#    'origin_country': ['US']}]}

# %%
with open('tmdb_list.pickle', 'wb') as fp:
    pickle.dump(omdb_dict, fp)

# %%
omdb_dict['How to Get Away with Murder']
# Out:
# {'page': 1,
#  'total_results': 1,
#  'total_pages': 1,
#  'results': [{'original_name': 'How to Get Away with Murder',
#    'id': 61056,
#    'name': 'How to Get Away with Murder',
#    'vote_count': 341,
#    'vote_average': 7.41,
#    'poster_path': '/llEtOsaRoVoNN0dtsYenAvelNxX.jpg',
#    'first_air_date': '2014-09-25',
#    'popularity': 32.701,
#    'genre_ids': [80, 18, 9648],
#    'original_language': 'en',
#    'backdrop_path': '/bzji0Cti9iuzzFeVDsB0S815RaG.jpg',
#    'overview': 'A sexy, suspense-driven legal thriller about a group of ambitious law students and their brilliant, mysterious criminal defense professor. They become entangled in a murder plot and will shake the entire university and change the course of their lives.',
#    'origin_country': ['US']}]}

# %%
omdb_dict['How to Get Away with Murder']['results'][0]['id']
# Out:
# 61056

# %%
# Grab IDs and stick them in a df

# %%
import numpy as np

# %%
tmdb_dict = {}

for i in omdb_dict:
    tmdb_dict[i] = omdb_dict[i]['results']
#    for number in np.arange(0, 6, 1):
#        omdb_dict[i]['results'][number]

        
        
        #        tmdb_dict[i] = omdb_dict[i]['results'][0]

# %%
new_stupid_dict = {}

len(tmdb_dict)
# Out:
# 12725

# %%
search.tv(query="Yogis Gang")
# Out:
# {'page': 1,
#  'total_results': 1,
#  'total_pages': 1,
#  'results': [{'original_name': "Yogi's Gang",
#    'id': 14698,
#    'name': "Yogi's Gang",
#    'vote_count': 2,
#    'vote_average': 8.5,
#    'poster_path': '/cc2wX5HhfWfxgjp5DdvEbjNtaba.jpg',
#    'first_air_date': '1973-09-08',
#    'popularity': 1.01,
#    'genre_ids': [16, 35],
#    'original_language': 'en',
#    'backdrop_path': '/li9XixTQCWpPhpWoltMWn15C2Vg.jpg',
#    'overview': "Yogi's Gang is a 30-minute animated series and the second incarnation of Hanna-Barbera's Yogi Bear which aired 16 half-hour episodes on ABC from September 8, 1973, to December 29, 1973. The show began as Yogi's Ark Lark, a special TV movie on The ABC Saturday Superstar Movie in 1972. Fifteen original episodes were produced for broadcast on ABC, with the hour-long Yogi's Ark Lark thrown in as a split-in-half two-parter.\n\nAfter a successful run on Saturday mornings, Yogi Gang returned in 1977 as a segment on the syndicated weekday series, Fred Flintstone and Friends. In the late 1980s, repeats were shown on USA Cartoon Express and later resurfaced on Nickelodeon, Cartoon Network and Boomerang.",
#    'origin_country': ['US']}]}

# %% [raw]
# test = {'a': {'aa':[{'apple': 'elppa'}, {'aapple': 'elppaa'}]},
#         'b': {'aa':[{'apple': 'elppab'}, {'aapple': 'elppabb'}]},
#         'c': {'aa':[{'apple': 'elpparc'}, {'aapple': 'elpparcc'}]},
#         'd': {'aa':[{'apple': 'elppad'}, {'aapple': 'elppadd'}]}}

# %% [raw]
# test_dict = {}
#
# for i in test:
#     test_dict[i] = test[i]['aa'][0]['apple']
#
# test_dict

# %%
tmdb.TV_Seasons(series_id=61056, season_number=1).info()
# Out:
# {'_id': '53c8dbdc0e0a26649c0017a2',
#  'air_date': '2014-09-25',
#  'episodes': [{'air_date': '2014-09-25',
#    'episode_number': 1,
#    'id': 996909,
#    'name': 'Pilot',
#    'overview': 'A ruthless defense attorney and no-nonsense law professor at a Philadelphia university selects a group of her best students to work at her firm.',
#    'production_code': None,
#    'season_number': 1,
#    'show_id': 61056,
#    'still_path': '/evze0uVSUdXKmFlSXQz7ikTfjvx.jpg',
#    'vote_average': 8.0,
#    'vote_count': 8,
#    'crew': [{'id': 166757,
#      'credit_id': '56366a429251414ad80198e7',
#      'name': 'Michael Offer',
#      'department': 'Directing',
#      'job': 'Director',
#      'gender': 2,
#      'profile_path': '/pdBqzlmHw9eMpQN4IgBjwUWCyab.jpg'},
#     {'id': 1366909,
#      'credit_id': '542167ecbcca014cf6000086',
#      'name': 'Peter Nowalk',
#      'department': 'Writing',
#      'job': 'Writer',
#      'gender': 2,
#      'profile_path': None},
#     {'id': 720,
#      'credit_id': '589dcba0c3a3685f93007a68',
#      'name': 'Jeff Jur',
#      'department': 'Camera',
#      'job': 'Director of Photography',
#      'gender': 2,
#      'profile_path': None},
#     {'id': 1419815,
#      'credit_id': '589dcf599251412cc3008e98',
#      'name': 'Robb Foglia',
#      'department': 'Directing',
#      'job': 'Script Supervisor',
#      'gender': 0,
#      'profile_path': None}],
#    'guest_stars': [{'id': 1444789,
#      'name': 'Lenny Platt',
#      'credit_id': '5510e270c3a3683e7f0067d4',
#      'character': "Griffin O'Reilly",
#      'order': 2,
#      'gender': 2,
#      'profile_path': '/fnqPGXQT5G1GcjVTvHDPSVZZRGu.jpg'},
#     {'id': 33241,
#      'name': 'Michael Gaston',
#      'credit_id': '5510e27ac3a36802c3000a17',
#      'character': 'Henry Wiliams',
#      'order': 3,
#      'gender': 2,
#      'profile_path': '/tAmpD16aVzWbs8evbCFaed9perN.jpg'},
#     {'id': 108922,
#      'name': 'Suzanne Savoy',
#      'credit_id': '5510e2fa9251415c320009ab',
#      'character': 'Judge Kathy Powell',
#      'order': 5,
#      'gender': 1,
#      'profile_path': '/w1YgmaOgbs5lzLOcWnpyWMEKt12.jpg'},
#     {'id': 1444792,
#      'name': 'Andrea Syglowski',
#      'credit_id': '5510e302c3a36801bb00097d',
#      'character': 'Gina Sadowski',
#      'order': 6,
#      'gender': 0,
#      'profile_path': '/vH1TQkTrxmVaC2Mjf4UJey15Lpk.jpg'},
#     {'id': 1444791,
#      'name': 'Conrad Ricamora',
#      'credit_id': '5510e2839251415c3200099c',
#      'character': 'Oliver Hampton',
#      'order': 6,
#      'gender': 2,
#      'profile_path': '/oWxKQWG4S8r3qM4Ge2I2Uz00teS.jpg'},
#     {'id': 107095,
#      'name': 'Megan West',
#      'credit_id': '5510e30c925141065c006995',
#      'character': 'Lila Stangard',
#      'order': 7,
#      'gender': 0,
#      'profile_path': '/oRK8DXDyW9aPrzloweWJuljremC.jpg'},
#     {'id': 1202693,
#      'name': 'Dave Droxler',
#      'credit_id': '5510e3189251415c320009af',
#      'character': 'Detective Gill',
#      'order': 8,
#      'gender': 0,
#      'profile_path': None},
#     {'id': 1444793,
#      'name': 'Kate Kearney-Patch',
#      'credit_id': '5510e32b92514107010069c3',
#      'character': 'Linda Tanner',
#      'order': 9,
#      'gender': 1,
#      'profile_path': '/xceVHdzGkJEArbqWSTqnbAFyGaH.jpg'},
#     {'id': 1014572,
#      'name': 'Joseph Melendez',
#      'credit_id': '5510e3369251415c320009b5',
#      'character': 'Lionel Bryant',
#      'order': 10,
#      'gender': 2,
#      'profile_path': '/l0bsVQaWCpowRhqI2h0aO7aIaL6.jpg'},
#     {'id': 1444795,
#      'name': 'Susan Wilder',
#      'credit_id': '5510e3429251415c320009bb',
#      'character': 'Agnes Kaufman',
#      'order': 11,
#      'gender': 0,
#      'profile_path': '/yx7FrvDdJeZcferCBUtezDxd2kk.jpg'},
#     {'id': 11618,
#      'name': 'Greg Wood',
#      'credit_id': '5510e34cc3a3683e7f0067ec',
#      'character': 'Arthur Kaufman',
#      'order': 12,
#      'gender': 0,
#      'profile_path': '/r06r7SzAjQDpHkLefIcDvabHZm1.jpg'},
#     {'id': 155423,
#      'name': 'Tom Verica',
#      'credit_id': '5510e3a79251415c320009c8',
#      'character': 'Sam Keating',
#      'order': 13,
#      'gender': 2,
#      'profile_path': '/eyOTcWS4vAbciBRbOoZcmkw2TRH.jpg'}]},
#   {'air_date': '2014-10-02',
#    'episode_number': 2,
#    'id': 1009807,
#    'name': "It's All Her Fault",
#    'overview': "Annalise takes on a new client, Max St. Vincent, an eccentric millionaire who is the key suspect in his wife's brutal murder. All the clues point to St. Vincent as the killer, but Annalise challenges her students to prove he's innocent - whether that's the truth or not. Meanwhile, Annalise deals with issues in her own home when her growing suspicions that Sam is somehow involved in Lila's disappearance start to affect their marriage. In flash forwards, we go back to the night of the murder and learn that Wes might be hiding a few secrets of his own.",
#    'production_code': None,
#    'season_number': 1,
#    'show_id': 61056,
#    'still_path': '/xFawNvIKOn7qVEAROlLreo0sHbE.jpg',
#    'vote_average': 7.714,
#    'vote_count': 7,
#    'crew': [{'id': 1366909,
#      'credit_id': '542167ecbcca014cf6000086',
#      'name': 'Peter Nowalk',
#      'department': 'Writing',
#      'job': 'Writer',
#      'gender': 2,
#      'profile_path': None},
#     {'id': 155007,
#      'credit_id': '542167ecbcca014cf6000088',
#      'name': "Bill D'Elia",
#      'department': 'Directing',
#      'job': 'Director',
#      'gender': 2,
#      'profile_path': '/7f7wWAkx0Ob59vPFXOAGDOh5UkQ.jpg'}],
#    'guest_stars': [{'id': 1444791,
#      'name': 'Conrad Ricamora',
#      'credit_id': '5510e2839251415c3200099c',
#      'character': 'Oliver Hampton',
#      'order': 6,
#      'gender': 2,
#      'profile_path': '/oWxKQWG4S8r3qM4Ge2I2Uz00teS.jpg'},
#     {'id': 155423,
#      'name': 'Tom Verica',
#      'credit_id': '5510e3a79251415c320009c8',
#      'character': 'Sam Keating',
#      'order': 13,
#      'gender': 2,
#      'profile_path': '/eyOTcWS4vAbciBRbOoZcmkw2TRH.jpg'},
#     {'id': 1358648,
#      'name': 'Laura Coover',
#      'credit_id': '5510e3c49251415bb300090b',
#      'character': 'Eloise St. Vincent',
#      'order': 14,
#      'gender': 0,
#      'profile_path': None},
#     {'id': 6106,
#      'name': 'Steven Weber',
#      'credit_id': '5510e3cec3a3683f39006903',
#      'character': 'Max St. Vincent',
#      'order': 15,
#      'gender': 2,
#      'profile_path': '/ujINzDjLNtELBSUkRHQgExzP4Fb.jpg'},
#     {'id': 1211945,
#      'name': 'Jill Remez',
#      'credit_id': '5510e3d8c3a3680174000a68',
#      'character': 'Lucinda Blair',
#      'order': 16,
#      'gender': 0,
#      'profile_path': '/bBdQOzN5R2Ltt79LdOt5elEQoim.jpg'},
#     {'id': 1211945,
#      'name': 'Jill Remez',
#      'credit_id': '5510e3fd925141065c0069b1',
#      'character': 'Judge',
#      'order': 17,
#      'gender': 0,
#      'profile_path': '/bBdQOzN5R2Ltt79LdOt5elEQoim.jpg'},
#     {'id': 1326901,
#      'name': 'Tye Alexander',
#      'credit_id': '5510e406c3a3680174000a6b',
#      'character': 'Officer Jake Dorsey',
#      'order': 18,
#      'gender': 0,
#      'profile_path': '/tmPlsW1GvOS3fBIMTpfglYdCukR.jpg'}]},
#   {'air_date': '2014-10-09',
#    'episode_number': 3,
#    'id': 1010283,
#    'name': 'Smile, or Go to Jail',
#    'overview': 'Annalise helps Paula Murphy, a suburban soccer mom, get released from jail after she was arrested for a misdemeanor, but just as she’s about to walk free, she’s arrested again by the FBI in connection for felony murder. Annalise and her students are tasked with proving her innocence which will depend on the testimony from another suspect in the case. Meanwhile, the Middleton University president asks Annalise to represent Griffin O’ Reilly, the star quarterback who has also been linked to Lila’s disappearance but she’s unable to make a decision until she knows that Sam wasn’t involved in the case. In flash forwards, more clues are revealed and we discover someone else was also there besides the students during the night of the murder.',
#    'production_code': None,
#    'season_number': 1,
#    'show_id': 61056,
#    'still_path': '/363bOEGgxpKlTMDVfaR0a9KIaak.jpg',
#    'vote_average': 7.688,
#    'vote_count': 8,
#    'crew': [{'id': 167333,
#      'credit_id': '56366dc9c3a3681b5201ac05',
#      'name': 'Rob Fresco',
#      'department': 'Writing',
#      'job': 'Writer',
#      'profile_path': None},
#     {'id': 1214368,
#      'credit_id': '56366c73c3a3681b6101bd47',
#      'name': 'Randall Zisk',
#      'department': 'Directing',
#      'job': 'Director',
#      'profile_path': '/8c5KROdeOyseRJjxcz9g27lm6k8.jpg'}],
#    'guest_stars': [{'id': 1444789,
#      'name': 'Lenny Platt',
#      'credit_id': '5510e270c3a3683e7f0067d4',
#      'character': "Griffin O'Reilly",
#      'order': 2,
#      'gender': 2,
#      'profile_path': '/fnqPGXQT5G1GcjVTvHDPSVZZRGu.jpg'},
#     {'id': 155423,
#      'name': 'Tom Verica',
#      'credit_id': '5510e3a79251415c320009c8',
#      'character': 'Sam Keating',
#      'order': 13,
#      'gender': 2,
#      'profile_path': '/eyOTcWS4vAbciBRbOoZcmkw2TRH.jpg'},
#     {'id': 48012,
#      'name': 'Jason Gedrick',
#      'credit_id': '5510e434c3a3680174000a77',
#      'character': 'Gabriel Shaw',
#      'order': 19,
#      'gender': 2,
#      'profile_path': '/mTaV9lBl4GYy2Mjs2l6xEkjoCKX.jpg'},
#     {'id': 38333,
#      'name': 'Ana Ortiz',
#      'credit_id': '5510e43e9251415caa00098e',
#      'character': 'Paula Murphy',
#      'order': 20,
#      'gender': 1,
#      'profile_path': '/wMwPs5CVcmW6PjriAqUpr5O1AcS.jpg'},
#     {'id': 62562,
#      'name': 'David Denman',
#      'credit_id': '5510e447c3a36801d20009c3',
#      'character': 'Kevin Murphy',
#      'order': 21,
#      'gender': 2,
#      'profile_path': '/7fjnNnXLDOYRlDlCVOuVb7hiF7h.jpg'},
#     {'id': 109740,
#      'name': 'Alysia Reiner',
#      'credit_id': '5510e451c3a3680174000a7d',
#      'character': 'D.A. Wendy Parks',
#      'order': 22,
#      'gender': 1,
#      'profile_path': '/njyrAkHTJlsUtsdY30ZRcbwPX8A.jpg'},
#     {'id': 20211,
#      'name': 'John Getz',
#      'credit_id': '5510e4599251415caa000993',
#      'character': 'David Dolan',
#      'order': 23,
#      'gender': 2,
#      'profile_path': '/a0uOMxCiYqvcr3h49jopyKzKVfX.jpg'},
#     {'id': 1246803,
#      'name': 'Arjun Gupta',
#      'credit_id': '5510e463c3a36802c3000a46',
#      'character': 'Kan',
#      'order': 24,
#      'gender': 2,
#      'profile_path': '/oMd0ojzDAUdcBmMuO1gC4GXSrEB.jpg'},
#     {'id': 1344869,
#      'name': 'Elliot Knight',
#      'credit_id': '5510e46b9251415bb300091b',
#      'character': 'Aiden Walker',
#      'order': 25,
#      'gender': 2,
#      'profile_path': '/r1J3yXH0uYHpV7XP7MbmILtZJFm.jpg'},
#     {'id': 1444798,
#      'name': 'Tom Beyer',
#      'credit_id': '5510e4829251415c96000919',
#      'character': 'Trent Davis',
#      'order': 26,
#      'gender': 0,
#      'profile_path': '/n8JZATSaEY7tDqHwyMaqmGAd6Pi.jpg'},
#     {'id': 228701,
#      'name': 'Joni Bovill',
#      'credit_id': '5510e48bc3a3680174000a85',
#      'character': 'Judge',
#      'order': 27,
#      'gender': 0,
#      'profile_path': '/flIPjuTJvvj1hOLGbZb1gzTi3a3.jpg'},
#     {'id': 20809,
#      'name': 'Joshua Wolf Coleman',
#      'credit_id': '5510e49392514166db0045c1',
#      'character': 'Ted',
#      'order': 28,
#      'gender': 0,
#      'profile_path': None},
#     {'id': 60944,
#      'name': 'Steven M. Gagnon',
#      'credit_id': '5510e4a292514107010069ef',
#      'character': 'Officer James Nelson',
#      'order': 29,
#      'gender': 2,
#      'profile_path': None},
#     {'id': 1364232,
#      'name': 'Eva La Dare',
#      'credit_id': '5510e4b1c3a36801d20009da',
#      'character': 'Leah',
#      'order': 30,
#      'gender': 0,
#      'profile_path': '/jllT2rMbeLinJMaIprTiQ6XoRop.jpg'},
#     {'id': 989546,
#      'name': 'James McAndrew',
#      'credit_id': '5510e4b8c3a3683e7f006811',
#      'character': 'Clayton',
#      'order': 31,
#      'gender': 2,
#      'profile_path': None}]},
#   {'air_date': '2014-10-16',
#    'episode_number': 4,
#    'id': 1011026,
#    'name': 'Let’s Get to Snooping',
#    'overview': 'Annalise and her students uncover a shocking truth while investigating the case of Marren Trudeau, founder and CEO of a major brokerage firm, who has recently been arrested for insider trading. Meanwhile, Wes discovers a cell phone hidden by Rebecca whose contents reveal an unsettling clue in the Lila Stangard murder case.',
#    'production_code': None,
#    'season_number': 1,
#    'show_id': 61056,
#    'still_path': '/23vbISCUYq4yFH8hM4RwDNlF8Xv.jpg',
#    'vote_average': 8.429,
#    'vote_count': 7,
#    'crew': [{'id': 454973,
#      'credit_id': '56366de3c3a3681b4b0195ca',
#      'name': 'Laura Innes',
#      'department': 'Directing',
#      'job': 'Director',
#      'profile_path': '/1XMMSTVdPIgYfxUwTF4em8T5rB0.jpg'},
#     {'id': 1239502,
#      'credit_id': '566c83a0c3a3682647008cca',
#      'name': 'Erika Green Swafford',
#      'department': 'Writing',
#      'job': 'Writer',
#      'profile_path': None}],
#    'guest_stars': [{'id': 1444791,
#      'name': 'Conrad Ricamora',
#      'credit_id': '5510e2839251415c3200099c',
#      'character': 'Oliver Hampton',
#      'order': 6,
#      'gender': 2,
#      'profile_path': '/oWxKQWG4S8r3qM4Ge2I2Uz00teS.jpg'},
#     {'id': 155423,
#      'name': 'Tom Verica',
#      'credit_id': '5510e3a79251415c320009c8',
#      'character': 'Sam Keating',
#      'order': 13,
#      'gender': 2,
#      'profile_path': '/eyOTcWS4vAbciBRbOoZcmkw2TRH.jpg'},
#     {'id': 109740,
#      'name': 'Alysia Reiner',
#      'credit_id': '5510e451c3a3680174000a7d',
#      'character': 'D.A. Wendy Parks',
#      'order': 22,
#      'gender': 1,
#      'profile_path': '/njyrAkHTJlsUtsdY30ZRcbwPX8A.jpg'},
#     {'id': 1246803,
#      'name': 'Arjun Gupta',
#      'credit_id': '5510e463c3a36802c3000a46',
#      'character': 'Kan',
#      'order': 24,
#      'gender': 2,
#      'profile_path': '/oMd0ojzDAUdcBmMuO1gC4GXSrEB.jpg'},
#     {'id': 27031,
#      'name': 'Tim Griffin',
#      'credit_id': '5510e4e39251415b60000945',
#      'character': 'AUSA Caleb Abernathy',
#      'order': 32,
#      'gender': 2,
#      'profile_path': '/hwGjdnFT8MAowE4oYsIGQovqUsD.jpg'},
#     {'id': 60072,
#      'name': 'Sara Paxton',
#      'credit_id': '5510e4eb9251415bb3000928',
#      'character': 'Talia Lewis',
#      'order': 33,
#      'gender': 1,
#      'profile_path': '/bJjI9jEmvk5Mmyo7LKKqkIK2mbr.jpg'},
#     {'id': 997406,
#      'name': 'Niko Pepaj',
#      'credit_id': '5510e5119251415b60000949',
#      'character': 'Pax Curtis',
#      'order': 34,
#      'gender': 2,
#      'profile_path': '/r2KeKKE0HZdXs106F4eaUzLm8S6.jpg'},
#     {'id': 138324,
#      'name': 'Tony Elias',
#      'credit_id': '5510e519c3a3680174000a94',
#      'character': 'Jimmy Wordshaw',
#      'order': 35,
#      'gender': 2,
#      'profile_path': '/pHlx7TAasqdMboz8AwAxoR3Hxpa.jpg'},
#     {'id': 20,
#      'name': 'Elizabeth Perkins',
#      'credit_id': '5510e521c3a36802c3000a61',
#      'character': 'Marren Trudeau',
#      'order': 36,
#      'gender': 1,
#      'profile_path': '/bkdWnnrMADJcFpKAOitMjQH3uEQ.jpg'},
#     {'id': 104915,
#      'name': 'Bob Rumnock',
#      'credit_id': '5510e52bc3a3680174000a99',
#      'character': 'Judge Granville Killinger',
#      'order': 37,
#      'gender': 2,
#      'profile_path': '/unKBkAbYs6HU12nSXUjJNz6PKJs.jpg'},
#     {'id': 1212471,
#      'name': 'Jeff Austin',
#      'credit_id': '5510e534c3a36801bb0009b3',
#      'character': 'Sgt. Matthew Joseph',
#      'order': 38,
#      'gender': 2,
#      'profile_path': '/6hiEiQiWIGeZ3ob85lIuHIrPYs0.jpg'},
#     {'id': 1444800,
#      'name': 'Daniel Nguyen',
#      'credit_id': '5510e53dc3a3683f39006929',
#      'character': 'Evan Blackstone',
#      'order': 39,
#      'gender': 0,
#      'profile_path': None},
#     {'id': 291133,
#      'name': 'Tai Bennett',
#      'credit_id': '5510e545c3a3683e7f00681f',
#      'character': 'Gene Wallace',
#      'order': 40,
#      'gender': 0,
#      'profile_path': '/w3RoTqou0e2YeLtI1zGgWSuDzmY.jpg'},
#     {'id': 1212706,
#      'name': 'Karen Malina White',
#      'credit_id': '5510e54dc3a3683f3900692d',
#      'character': 'Carla Brookings',
#      'order': 41,
#      'gender': 1,
#      'profile_path': '/dUcXPsYW5flTdR81bdpHCltc3Fs.jpg'},
#     {'id': 1430898,
#      'name': 'Jeff L. Williams',
#      'credit_id': '5510e558c3a36801bb0009b6',
#      'character': 'Elias Edson',
#      'order': 42,
#      'gender': 0,
#      'profile_path': None}]},
#   {'air_date': '2014-10-23',
#    'episode_number': 5,
#    'id': 1012040,
#    'name': "We're Not Friends",
#    'overview': 'Annalise takes on a tough case defending a minor who fatally shoots his police officer father. Meanwhile, Annalise and Sam continue to argue over his relationship with Lila, and Wes and Rebecca begin to question Annalise’s motives. In flash-forwards, we learn more about Laurel’s relationship with Frank and why he was calling her the night of Sam’s death.',
#    'production_code': None,
#    'season_number': 1,
#    'show_id': 61056,
#    'still_path': '/3jLoCYxb4tIdr0oW4ZW0edxXamK.jpg',
#    'vote_average': 7.357,
#    'vote_count': 7,
#    'crew': [{'id': 1237455,
#      'credit_id': '56366e6e9251413b4600d27c',
#      'name': 'Tracy Bellomo',
#      'department': 'Writing',
#      'job': 'Writer',
#      'profile_path': None},
#     {'id': 1213545,
#      'credit_id': '56366f0a9251416d5200cf14',
#      'name': 'Mike Listo',
#      'department': 'Directing',
#      'job': 'Director',
#      'profile_path': None}],
#    'guest_stars': [{'id': 1866144,
#      'name': 'Eamon Hunt',
#      'credit_id': '598a015a9251414bd1018db8',
#      'character': 'Judge Colton Lee',
#      'order': 190,
#      'gender': 2,
#      'profile_path': None},
#     {'id': 1444801,
#      'name': 'Gregory North',
#      'credit_id': '5510e5b392514166db0045de',
#      'character': 'Officer Gary Miller',
#      'order': 48,
#      'gender': 0,
#      'profile_path': None},
#     {'id': 183907,
#      'name': 'Pamela Shaddock',
#      'credit_id': '5510e5a992514166db0045d9',
#      'character': 'Ms. Medick',
#      'order': 47,
#      'gender': 1,
#      'profile_path': '/3cLLbqyCytYvZwnBvjJEA1dsb73.jpg'},
#     {'id': 1226175,
#      'name': 'Julian De La Celle',
#      'credit_id': '5510e595925141065c0069d5',
#      'character': 'Ryan Remini',
#      'order': 45,
#      'gender': 0,
#      'profile_path': '/lAukmdQsoPTxC3Ws7uY7GmLZSbq.jpg'},
#     {'id': 134082,
#      'name': 'Amy Pietz',
#      'credit_id': '5510e588c3a36802c3000a6a',
#      'character': 'Sharon Remini',
#      'order': 44,
#      'gender': 0,
#      'profile_path': '/oCe6UQJSug2rqHbAsusigaA2AuR.jpg'},
#     {'id': 156633,
#      'name': 'Tracy Vilar',
#      'credit_id': '5510e578c3a3683f39006933',
#      'character': 'Prosecutor Barker',
#      'order': 43,
#      'gender': 1,
#      'profile_path': '/qizLuMAfvMudC1VyODiSp9ukeGK.jpg'},
#     {'id': 1246803,
#      'name': 'Arjun Gupta',
#      'credit_id': '5510e463c3a36802c3000a46',
#      'character': 'Kan',
#      'order': 24,
#      'gender': 2,
#      'profile_path': '/oMd0ojzDAUdcBmMuO1gC4GXSrEB.jpg'},
#     {'id': 155423,
#      'name': 'Tom Verica',
#      'credit_id': '5510e3a79251415c320009c8',
#      'character': 'Sam Keating',
#      'order': 13,
#      'gender': 2,
#      'profile_path': '/eyOTcWS4vAbciBRbOoZcmkw2TRH.jpg'}]},
#   {'air_date': '2014-10-30',
#    'episode_number': 6,
#    'id': 1012380,
#    'name': 'Freakin’ Whack-a-Mole',
#    'overview': 'A case gets personal for Annalise and the team when their client is a man from the projects who was sentenced to death by Asher’s father several years ago. Meanwhile, Wes is still angry at Annalise for hiding information about Lila’s case, so Annalise must convince him to get back in line. In flash-forwards, we find out exactly where Asher was on the night of the murder.',
#    'production_code': None,
#    'season_number': 1,
#    'show_id': 61056,
#    'still_path': '/kyzDx4m9qrcRFT9NZF0NIc8KhTD.jpg',
#    'vote_average': 8.0,
#    'vote_count': 6,
#    'crew': [{'id': 155007,
#      'credit_id': '542167ecbcca014cf6000088',
#      'name': "Bill D'Elia",
#      'department': 'Directing',
#      'job': 'Director',
#      'profile_path': None},
#     {'id': 1530365,
#      'credit_id': '56366faa9251416d5200cf1f',
#      'name': 'Michael Foley',
#      'department': 'Writing',
#      'job': 'Writer',
#      'profile_path': None}],
#    'guest_stars': [{'id': 1444817,
#      'name': 'Hilda Boulware',
#      'credit_id': '5510ea979251410701006a7a',
#      'character': "David's Mother",
#      'order': 58,
#      'gender': 0,
#      'profile_path': '/b3PU6qzr3GGYjbR9uKoLkntcCog.jpg'},
#     {'id': 41691,
#      'name': 'Ungela Brockman',
#      'credit_id': '5510ea8f9251415caa000a13',
#      'character': "David's Sister",
#      'order': 57,
#      'gender': 0,
#      'profile_path': '/q66RPSSUYmtgbLNvkdKdeqAbOwc.jpg'},
#     {'id': 181154,
#      'name': 'Donna Pieroni',
#      'credit_id': '5510ea6b9251415c32000a60',
#      'character': 'Linda Morelli',
#      'order': 56,
#      'gender': 1,
#      'profile_path': '/jdJXNryq0ct92kmuI0XueSuhAQa.jpg'},
#     {'id': 1091867,
#      'name': 'Eric Davis',
#      'credit_id': '5510ea63c3a36801d2000a64',
#      'character': 'Counsel Clark Byers',
#      'order': 55,
#      'gender': 0,
#      'profile_path': '/ti3nDKQMs8L7uzrPqcfFd51Jwki.jpg'},
#     {'id': 58510,
#      'name': 'John Burke',
#      'credit_id': '5510ea369251415c32000a5d',
#      'character': 'ADA Vince Travers',
#      'order': 54,
#      'gender': 2,
#      'profile_path': '/4GxnaBErIUcoDs5xybyeSlFSY8u.jpg'},
#     {'id': 58768,
#      'name': 'Jim Turner',
#      'credit_id': '5510e9bbc3a3683e7f006888',
#      'character': 'George Gabler',
#      'order': 53,
#      'gender': 2,
#      'profile_path': '/mujwEKBe86I89VblEvK3zQbE81j.jpg'},
#     {'id': 168269,
#      'name': 'David Gautreaux',
#      'credit_id': '5510e9b492514166db004642',
#      'character': 'Senator Art Trucco',
#      'order': 52,
#      'gender': 2,
#      'profile_path': '/jqvxI1AbuQKehAk3tEQ4Y0TiBla.jpg'},
#     {'id': 44060,
#      'name': 'John Posey',
#      'credit_id': '5510e9acc3a36801d2000a55',
#      'character': 'Bill Millstone',
#      'order': 51,
#      'gender': 2,
#      'profile_path': '/9wvwfykeDDQltlrzgOYTjKpp8LV.jpg'},
#     {'id': 1444816,
#      'name': 'Peter Macon',
#      'credit_id': '5510e9a3c3a3683e7f006886',
#      'character': 'David Allen',
#      'order': 50,
#      'gender': 0,
#      'profile_path': '/oA3AbLBLWVR0cYzPqxNOX3WXzUy.jpg'},
#     {'id': 70440,
#      'name': 'Robin Gammell',
#      'credit_id': '5510e99a925141065c006a2b',
#      'character': 'Chief Justice',
#      'order': 49,
#      'gender': 2,
#      'profile_path': '/zpx0BpA28aSQdSihTdp9Yk2MMgG.jpg'},
#     {'id': 155423,
#      'name': 'Tom Verica',
#      'credit_id': '5510e3a79251415c320009c8',
#      'character': 'Sam Keating',
#      'order': 13,
#      'gender': 2,
#      'profile_path': '/eyOTcWS4vAbciBRbOoZcmkw2TRH.jpg'}]},
#   {'air_date': '2014-11-06',
#    'episode_number': 7,
#    'id': 1014083,
#    'name': 'He Deserved to Die',
#    'overview': 'Annalise and the team are focused on Rebecca’s case, but when the judge enforces a gag order, Rebecca takes things into her own hands. Meanwhile, Michaela is surprised by a pre-nup, sparks fly between Laurel and Frank, and in flash-forwards, we find out more about Wes and Rebecca’s relationship.',
#    'production_code': None,
#    'season_number': 1,
#    'show_id': 61056,
#    'still_path': '/miqjAu1rWIfriTtXK0oUttNQIA6.jpg',
#    'vote_average': 8.167,
#    'vote_count': 6,
#    'crew': [{'id': 7036,
#      'credit_id': '56367081925141616700cf1b',
#      'name': 'Eric Stoltz',
#      'department': 'Directing',
#      'job': 'Director',
#      'profile_path': '/fXaULtqnMDKsqT1to8vnLjSXe0w.jpg'},
#     {'id': 1369152,
#      'credit_id': '56367091c3a3681b5c01ce42',
#      'name': 'Warren Hsu Leonard',
#      'department': 'Writing',
#      'job': 'Writer',
#      'profile_path': None}],
#    'guest_stars': [{'id': 365939,
#      'name': 'Sarah McMullen',
#      'credit_id': '5510eb3ac3a3681db200d16a',
#      'character': 'Ally Burnham',
#      'order': 67,
#      'profile_path': None},
#     {'id': 93090,
#      'name': 'Graham Sibley',
#      'credit_id': '5510eb2f925141065c006a57',
#      'character': 'Peyton Whitmore',
#      'order': 66,
#      'profile_path': '/eciTx3gZjD3pFTPsZ1buhkUkJtS.jpg'},
#     {'id': 58039,
#      'name': 'Bonnie Burroughs',
#      'credit_id': '5510eb27c3a36801d2000a79',
#      'character': 'Mrs. Stangard',
#      'order': 65,
#      'profile_path': '/lIYp88dXlarJmNQ89eUW1JrTsUq.jpg'},
#     {'id': 64057,
#      'name': 'Dean Cameron',
#      'credit_id': '5510eb1ec3a3680174000b2f',
#      'character': 'Jim Buchanan',
#      'order': 64,
#      'profile_path': '/hrATK7lU4dO6MQy2jkVFXlrnlrj.jpg'},
#     {'id': 158782,
#      'name': 'Van Epperson',
#      'credit_id': '5510eb14c3a36802960009a1',
#      'character': 'Dr. Silas Root',
#      'order': 63,
#      'profile_path': '/2l4N2WTYen9cz5HJKeDvIEtzsB1.jpg'},
#     {'id': 4511,
#      'name': 'Mark Adair-Rios',
#      'credit_id': '5510eb0bc3a36801d2000a77',
#      'character': 'Dr. Erik Turner',
#      'order': 62,
#      'profile_path': '/rX4d1e5jlF5P73qynjjUzJslB0c.jpg'},
#     {'id': 928695,
#      'name': 'Michael Adam Hamilton',
#      'credit_id': '5510eaf69251415b600009d6',
#      'character': 'Julien',
#      'order': 61,
#      'profile_path': '/6mNFohP06qoF4zIPE9tdPwo4FfN.jpg'},
#     {'id': 3134,
#      'name': 'Tamlyn Tomita',
#      'credit_id': '5510eae6c3a36802c3000af4',
#      'character': 'Judge Carol Morrow',
#      'order': 60,
#      'profile_path': '/iX6zGWXFWLdUnxaVebXGzXXwgft.jpg'},
#     {'id': 19974,
#      'name': 'Greg Germann',
#      'credit_id': '5510eacf92514166db00465c',
#      'character': 'Jared Keegan',
#      'order': 59,
#      'profile_path': '/oP3ogELIPIaWxShJst905uuOn3L.jpg'},
#     {'id': 1246803,
#      'name': 'Arjun Gupta',
#      'credit_id': '5510e463c3a36802c3000a46',
#      'character': 'Kan',
#      'order': 24,
#      'profile_path': '/oMd0ojzDAUdcBmMuO1gC4GXSrEB.jpg'},
#     {'id': 109740,
#      'name': 'Alysia Reiner',
#      'credit_id': '5510e451c3a3680174000a7d',
#      'character': 'D.A. Wendy Parks',
#      'order': 22,
#      'profile_path': '/njyrAkHTJlsUtsdY30ZRcbwPX8A.jpg'},
#     {'id': 155423,
#      'name': 'Tom Verica',
#      'credit_id': '5510e3a79251415c320009c8',
#      'character': 'Sam Keating',
#      'order': 13,
#      'profile_path': '/eyOTcWS4vAbciBRbOoZcmkw2TRH.jpg'},
#     {'id': 107095,
#      'name': 'Megan West',
#      'credit_id': '5510e30c925141065c006995',
#      'character': 'Lila Stangard',
#      'order': 7,
#      'profile_path': '/oRK8DXDyW9aPrzloweWJuljremC.jpg'},
#     {'id': 1444789,
#      'name': 'Lenny Platt',
#      'credit_id': '5510e270c3a3683e7f0067d4',
#      'character': "Griffin O'Reilly",
#      'order': 2,
#      'profile_path': '/jOg8TZLbIF3ndcebssFr9Qqw89z.jpg'}]},
#   {'air_date': '2014-11-13',
#    'episode_number': 8,
#    'id': 1014432,
#    'name': 'He Has a Wife',
#    'overview': "The team represents a mother who's on trial for killing her family's nanny while on heavy medication. Meanwhile, a shocking discovery is revealed in Lila's case that could change everything for Rebecca and Bonnie's loyalty to Annalise. In flashbacks, we learn more about Lila and Sam's relationship.",
#    'production_code': None,
#    'season_number': 1,
#    'show_id': 61056,
#    'still_path': '/o9vik8oeBxdWAt5x6NRsCnyean4.jpg',
#    'vote_average': 8.8,
#    'vote_count': 5,
#    'crew': [{'id': 32395,
#      'credit_id': '566c8594925141500100394d',
#      'name': 'Debbie Allen',
#      'department': 'Directing',
#      'job': 'Director',
#      'profile_path': '/ilRAAFScoujz9VfFHug0GsYDyA6.jpg'},
#     {'id': 1548201,
#      'credit_id': '566c85d29251412dbc003fcc',
#      'name': 'Doug Stockstill',
#      'department': 'Writing',
#      'job': 'Writer',
#      'profile_path': None}],
#    'guest_stars': [{'id': 107095,
#      'name': 'Megan West',
#      'credit_id': '5510e30c925141065c006995',
#      'character': 'Lila Stangard',
#      'order': 7,
#      'gender': 0,
#      'profile_path': '/oRK8DXDyW9aPrzloweWJuljremC.jpg'},
#     {'id': 155423,
#      'name': 'Tom Verica',
#      'credit_id': '5510e3a79251415c320009c8',
#      'character': 'Sam Keating',
#      'order': 13,
#      'gender': 2,
#      'profile_path': '/eyOTcWS4vAbciBRbOoZcmkw2TRH.jpg'},
#     {'id': 16217,
#      'name': 'Lynn Whitfield',
#      'credit_id': '5510ebb1c3a3683e7f0068c1',
#      'character': 'Mary Walker',
#      'order': 68,
#      'gender': 1,
#      'profile_path': '/vl99aENfo3wOBWJVvOVj0uIUNfL.jpg'},
#     {'id': 43372,
#      'name': 'Stacy Edwards',
#      'credit_id': '5510ebbac3a36801bb000a36',
#      'character': 'Gretchen Thomas',
#      'order': 69,
#      'gender': 1,
#      'profile_path': '/3FBtBFrmjUx0W0bbKYqW2gpgIkI.jpg'},
#     {'id': 107408,
#      'name': 'David Burke',
#      'credit_id': '5510ebc39251415bb30009b7',
#      'character': 'Mr. Thomas',
#      'order': 70,
#      'gender': 2,
#      'profile_path': '/nmPAFugItLQAGyUQCsMUdkJIZni.jpg'},
#     {'id': 1343585,
#      'name': 'Max Gray Wilbur',
#      'credit_id': '5510ebccc3a36801bb000a39',
#      'character': 'Cody Thomas',
#      'order': 71,
#      'gender': 2,
#      'profile_path': None},
#     {'id': 1225269,
#      'name': 'Aubrey Manning',
#      'credit_id': '5510ebe2c3a3681db200d180',
#      'character': 'Claire',
#      'order': 72,
#      'gender': 0,
#      'profile_path': None},
#     {'id': 1016151,
#      'name': 'Jeffrey De Serrano',
#      'credit_id': '5510ebf39251415caa000a32',
#      'character': 'ADA Hector Rodriguez',
#      'order': 73,
#      'gender': 2,
#      'profile_path': '/sg7Nb65NnNWqpmFRUw4s5ynuXbZ.jpg'},
#     {'id': 96881,
#      'name': 'Catherine Carlen',
#      'credit_id': '5510ebfdc3a3683f390069c2',
#      'character': 'Judge Emily Hargrove',
#      'order': 74,
#      'gender': 1,
#      'profile_path': '/5Xb31dGsZpPIsEBWeM9Wvo1O22e.jpg'},
#     {'id': 1231548,
#      'name': 'Katie Cleary',
#      'credit_id': '5510ec08c3a36801bb000a44',
#      'character': 'Sasha',
#      'order': 75,
#      'gender': 0,
#      'profile_path': None},
#     {'id': 965224,
#      'name': 'Thomas Robinson',
#      'credit_id': '5510ec11c3a36801bb000a46',
#      'character': 'Kenny Thomas',
#      'order': 76,
#      'gender': 2,
#      'profile_path': '/duhdLnjGG7s05T4xjXDu7ISYKeN.jpg'},
#     {'id': 1444818,
#      'name': 'Makenna James',
#      'credit_id': '5510ec1a9251415c32000a9a',
#      'character': 'Mia Thomas',
#      'order': 77,
#      'gender': 0,
#      'profile_path': None},
#     {'id': 1444819,
#      'name': 'Jacqueline Guzman Cereceres',
#      'credit_id': '5510ec26c3a36801d2000a9a',
#      'character': 'Elke',
#      'order': 78,
#      'gender': 0,
#      'profile_path': None}]},
#   {'air_date': '2014-11-20',
#    'episode_number': 9,
#    'id': 1014433,
#    'name': 'Kill Me, Kill Me, Kill Me',
#    'overview': 'It’s the evening of the bonfire and we finally see what exactly happened on the night of Sam’s death.',
#    'production_code': None,
#    'season_number': 1,
#    'show_id': 61056,
#    'still_path': '/ctXXQiLSoySOmJ9v4CU6PxpiqoR.jpg',
#    'vote_average': 8.857,
#    'vote_count': 7,
#    'crew': [{'id': 166461,
#      'credit_id': '56252adb92514144b0005559',
#      'name': 'Stephen Williams',
#      'department': 'Directing',
#      'job': 'Director',
#      'profile_path': '/7XRIDfL8ZSnJWkwaWuqvZwheTav.jpg'},
#     {'id': 1530365,
#      'credit_id': '56366faa9251416d5200cf1f',
#      'name': 'Michael Foley',
#      'department': 'Writing',
#      'job': 'Writer',
#      'profile_path': None},
#     {'id': 1239502,
#      'credit_id': '566c83a0c3a3682647008cca',
#      'name': 'Erika Green Swafford',
#      'department': 'Writing',
#      'job': 'Writer',
#      'profile_path': None}],
#    'guest_stars': [{'id': 1444791,
#      'name': 'Conrad Ricamora',
#      'credit_id': '5510e2839251415c3200099c',
#      'character': 'Oliver Hampton',
#      'order': 6,
#      'gender': 2,
#      'profile_path': '/oWxKQWG4S8r3qM4Ge2I2Uz00teS.jpg'},
#     {'id': 155423,
#      'name': 'Tom Verica',
#      'credit_id': '5510e3a79251415c320009c8',
#      'character': 'Sam Keating',
#      'order': 13,
#      'gender': 2,
#      'profile_path': '/eyOTcWS4vAbciBRbOoZcmkw2TRH.jpg'},
#     {'id': 16217,
#      'name': 'Lynn Whitfield',
#      'credit_id': '5510ebb1c3a3683e7f0068c1',
#      'character': 'Mary Walker',
#      'order': 68,
#      'gender': 1,
#      'profile_path': '/vl99aENfo3wOBWJVvOVj0uIUNfL.jpg'},
#     {'id': 16217,
#      'name': 'Lynn Whitfield',
#      'credit_id': '5510ec7ac3a36801bb000a56',
#      'character': 'Dennis',
#      'order': 79,
#      'gender': 1,
#      'profile_path': '/vl99aENfo3wOBWJVvOVj0uIUNfL.jpg'}]},
#   {'air_date': '2015-01-29',
#    'episode_number': 10,
#    'id': 1038103,
#    'name': 'Hello, Raskolnikov',
#    'overview': 'It’s the day after Sam’s murder and the students are called in to help Annalise find her missing husband, but just how much does Annalise know? And when a surprise visitor shows up in town, getting away with this murder might not be as easy as the students had hoped.',
#    'production_code': None,
#    'season_number': 1,
#    'show_id': 61056,
#    'still_path': '/yuyoUqJu20uyZ4aIiWP2tJVQhmy.jpg',
#    'vote_average': 8.5,
#    'vote_count': 6,
#    'crew': [{'id': 166757,
#      'credit_id': '56366a429251414ad80198e7',
#      'name': 'Michael Offer',
#      'department': 'Directing',
#      'job': 'Director',
#      'profile_path': '/pdBqzlmHw9eMpQN4IgBjwUWCyab.jpg'},
#     {'id': 1548198,
#      'credit_id': '566c8523c3a36834c1009194',
#      'name': 'Marcus Dalzine',
#      'department': 'Writing',
#      'job': 'Writer',
#      'profile_path': None}],
#    'guest_stars': [{'id': 1444791,
#      'name': 'Conrad Ricamora',
#      'credit_id': '5510e2839251415c3200099c',
#      'character': 'Oliver Hampton',
#      'order': 6,
#      'gender': 2,
#      'profile_path': '/oWxKQWG4S8r3qM4Ge2I2Uz00teS.jpg'},
#     {'id': 107095,
#      'name': 'Megan West',
#      'credit_id': '5510e30c925141065c006995',
#      'character': 'Lila Stangard',
#      'order': 7,
#      'gender': 0,
#      'profile_path': '/oRK8DXDyW9aPrzloweWJuljremC.jpg'},
#     {'id': 155423,
#      'name': 'Tom Verica',
#      'credit_id': '5510e3a79251415c320009c8',
#      'character': 'Sam Keating',
#      'order': 13,
#      'gender': 2,
#      'profile_path': '/eyOTcWS4vAbciBRbOoZcmkw2TRH.jpg'},
#     {'id': 109740,
#      'name': 'Alysia Reiner',
#      'credit_id': '5510e451c3a3680174000a7d',
#      'character': 'D.A. Wendy Parks',
#      'order': 22,
#      'gender': 1,
#      'profile_path': '/njyrAkHTJlsUtsdY30ZRcbwPX8A.jpg'},
#     {'id': 1246803,
#      'name': 'Arjun Gupta',
#      'credit_id': '5510e463c3a36802c3000a46',
#      'character': 'Kan',
#      'order': 24,
#      'gender': 2,
#      'profile_path': '/oMd0ojzDAUdcBmMuO1gC4GXSrEB.jpg'},
#     {'id': 3134,
#      'name': 'Tamlyn Tomita',
#      'credit_id': '5510eae6c3a36802c3000af4',
#      'character': 'Judge Carol Morrow',
#      'order': 60,
#      'gender': 1,
#      'profile_path': '/iX6zGWXFWLdUnxaVebXGzXXwgft.jpg'},
#     {'id': 57452,
#      'name': 'Faran Tahir',
#      'credit_id': '5510ecd3c3a36802960009d6',
#      'character': 'Detective Terrence Amos',
#      'order': 80,
#      'gender': 2,
#      'profile_path': '/zEcur3BBkXD0gosZQ1nAZRyQZUq.jpg'},
#     {'id': 1435965,
#      'name': 'April Parker-Jones',
#      'credit_id': '5510eceac3a3680174000b69',
#      'character': 'Detective Claire Bryce',
#      'order': 81,
#      'gender': 1,
#      'profile_path': '/5Bg87vQBXIbjP1FBhRb5bx6ScHz.jpg'},
#     {'id': 1444821,
#      'name': 'Trevor J. Davis',
#      'credit_id': '5510ed06c3a3681db200d1ac',
#      'character': 'Mr. Ingram',
#      'order': 82,
#      'gender': 0,
#      'profile_path': None},
#     {'id': 4726,
#      'name': 'Marcia Gay Harden',
#      'credit_id': '5510ed0f9251415caa000a5a',
#      'character': 'Hannah Keating',
#      'order': 83,
#      'gender': 1,
#      'profile_path': '/x2AZcxKZoozIoigbwOhPMn8nngE.jpg'}]},
#   {'air_date': '2015-02-05',
#    'episode_number': 11,
#    'id': 1038104,
#    'name': 'Best Christmas Ever',
#    'overview': "School is back in session after the holiday break and the entire university is talking about Annalise's missing husband. The Keating Five continue to be questioned by the police and we find out exactly how they've been dealing with the guilt of killing Sam. Meanwhile, Annalise tries to keep things business as usual by taking on a new client who is in the mob, but Hannah continues to pressure her for answers.",
#    'production_code': None,
#    'season_number': 1,
#    'show_id': 61056,
#    'still_path': '/kQxFyXgRk9C8unkyrb9MRIrK9C1.jpg',
#    'vote_average': 8.0,
#    'vote_count': 6,
#    'crew': [{'id': 1237455,
#      'credit_id': '56366e6e9251413b4600d27c',
#      'name': 'Tracy Bellomo',
#      'department': 'Writing',
#      'job': 'Writer',
#      'profile_path': None},
#     {'id': 35971,
#      'credit_id': '566c84c692514169e2009278',
#      'name': 'Michael Katleman',
#      'department': 'Directing',
#      'job': 'Director',
#      'profile_path': '/e8RG1KMCLPxuGFH7CqaJuUfKPj0.jpg'},
#     {'id': 1369152,
#      'credit_id': '56367091c3a3681b5c01ce42',
#      'name': 'Warren Hsu Leonard',
#      'department': 'Writing',
#      'job': 'Writer',
#      'profile_path': None}],
#    'guest_stars': [{'id': 1444791,
#      'name': 'Conrad Ricamora',
#      'credit_id': '5510e2839251415c3200099c',
#      'character': 'Oliver Hampton',
#      'order': 6,
#      'gender': 2,
#      'profile_path': '/oWxKQWG4S8r3qM4Ge2I2Uz00teS.jpg'},
#     {'id': 1344869,
#      'name': 'Elliot Knight',
#      'credit_id': '5510e46b9251415bb300091b',
#      'character': 'Aiden Walker',
#      'order': 25,
#      'gender': 2,
#      'profile_path': '/r1J3yXH0uYHpV7XP7MbmILtZJFm.jpg'},
#     {'id': 4726,
#      'name': 'Marcia Gay Harden',
#      'credit_id': '5510ed0f9251415caa000a5a',
#      'character': 'Hannah Keating',
#      'order': 83,
#      'gender': 1,
#      'profile_path': '/x2AZcxKZoozIoigbwOhPMn8nngE.jpg'},
#     {'id': 166688,
#      'name': 'Jackie Geary',
#      'credit_id': '5510ed33c3a36802960009e2',
#      'character': 'Jackie Groves',
#      'order': 84,
#      'gender': 1,
#      'profile_path': '/saIV0KEUYjfDSKsCyODWxCGqbUr.jpg'},
#     {'id': 10963,
#      'name': 'José Zúñiga',
#      'credit_id': '5510ed3d9251415caa000a5f',
#      'character': "Laurel's Dad",
#      'order': 85,
#      'gender': 2,
#      'profile_path': '/uD8aacPO6Zqsr4f3yAkqgT6G4wS.jpg'},
#     {'id': 13029,
#      'name': 'Anne Betancourt',
#      'credit_id': '5510ed4d92514166db0046ac',
#      'character': 'Judge',
#      'order': 86,
#      'gender': 0,
#      'profile_path': '/6UU5P4DzjJTSBFztIu1nALT2tk0.jpg'},
#     {'id': 1384233,
#      'name': 'Tabitha Morella',
#      'credit_id': '5510ed639251415c32000ac1',
#      'character': 'Lynn Applewhite',
#      'order': 87,
#      'gender': 0,
#      'profile_path': None},
#     {'id': 1444822,
#      'name': 'Tayler Vee Robinson',
#      'credit_id': '5510ed70c3a3680174000b88',
#      'character': 'Rachel Parker',
#      'order': 88,
#      'gender': 0,
#      'profile_path': None},
#     {'id': 1099819,
#      'name': 'Jennifer Christopher',
#      'credit_id': '5510ed7c925141065c006a9d',
#      'character': 'Gemma Walsh',
#      'order': 89,
#      'gender': 0,
#      'profile_path': None},
#     {'id': 1216971,
#      'name': 'Brynn Thayer',
#      'credit_id': '5510ed84c3a3683e7f0068ee',
#      'character': 'Elena Castillo',
#      'order': 90,
#      'gender': 1,
#      'profile_path': '/yzhOOltoLStU7qs2E1JbrMo4Glq.jpg'},
#     {'id': 155316,
#      'name': 'Vincent Duvall',
#      'credit_id': '5510eef7c3a3683e7f006927',
#      'character': 'D.A. Roger Galvinson',
#      'order': 92,
#      'gender': 2,
#      'profile_path': '/zBlHOpxfltTSB8zB0t2beNNyjNA.jpg'},
#     {'id': 1444823,
#      'name': 'James Logan',
#      'credit_id': '5510ef4b9251415bb3000a24',
#      'character': 'Vince Groves',
#      'order': 93,
#      'gender': 2,
#      'profile_path': '/5fMRvOQ2DafzBPjtYELgTXb9P0P.jpg'},
#     {'id': 138944,
#      'name': 'Innis Casey',
#      'credit_id': '5513e6969251412c52000ea3',
#      'character': 'Adrian Castillo',
#      'order': 116,
#      'gender': 0,
#      'profile_path': '/yMvHEUwWanFCDmIEoDzsOGGWkv7.jpg'}]},
#   {'air_date': '2015-02-12',
#    'episode_number': 12,
#    'id': 1039542,
#    'name': 'She’s a Murderer',
#    'overview': "A stunning discovery in Sam's murder case leads to changes for Annalise and the students.",
#    'production_code': None,
#    'season_number': 1,
#    'show_id': 61056,
#    'still_path': '/hJu1HBS2icN6Rrx7hWUNXKYVa4V.jpg',
#    'vote_average': 8.6,
#    'vote_count': 5,
#    'crew': [{'id': 155007,
#      'credit_id': '542167ecbcca014cf6000088',
#      'name': "Bill D'Elia",
#      'department': 'Directing',
#      'job': 'Director',
#      'gender': 2,
#      'profile_path': '/7f7wWAkx0Ob59vPFXOAGDOh5UkQ.jpg'},
#     {'id': 1548195,
#      'credit_id': '566c84a0c3a3682e98008a64',
#      'name': 'Erika Harrison',
#      'department': 'Writing',
#      'job': 'Writer',
#      'gender': 0,
#      'profile_path': None}],
#    'guest_stars': [{'id': 1344869,
#      'name': 'Elliot Knight',
#      'credit_id': '5510e46b9251415bb300091b',
#      'character': 'Aiden Walker',
#      'order': 25,
#      'gender': 2,
#      'profile_path': '/r1J3yXH0uYHpV7XP7MbmILtZJFm.jpg'},
#     {'id': 4726,
#      'name': 'Marcia Gay Harden',
#      'credit_id': '5510ed0f9251415caa000a5a',
#      'character': 'Hannah Keating',
#      'order': 83,
#      'gender': 1,
#      'profile_path': '/x2AZcxKZoozIoigbwOhPMn8nngE.jpg'},
#     {'id': 166688,
#      'name': 'Jackie Geary',
#      'credit_id': '5510ed33c3a36802960009e2',
#      'character': 'Jackie Groves',
#      'order': 84,
#      'gender': 1,
#      'profile_path': '/saIV0KEUYjfDSKsCyODWxCGqbUr.jpg'},
#     {'id': 10963,
#      'name': 'José Zúñiga',
#      'credit_id': '5510ed3d9251415caa000a5f',
#      'character': "Laurel's Dad",
#      'order': 85,
#      'gender': 2,
#      'profile_path': '/uD8aacPO6Zqsr4f3yAkqgT6G4wS.jpg'},
#     {'id': 13029,
#      'name': 'Anne Betancourt',
#      'credit_id': '5510ed4d92514166db0046ac',
#      'character': 'Judge',
#      'order': 86,
#      'gender': 0,
#      'profile_path': '/6UU5P4DzjJTSBFztIu1nALT2tk0.jpg'},
#     {'id': 1384233,
#      'name': 'Tabitha Morella',
#      'credit_id': '5510ed639251415c32000ac1',
#      'character': 'Lynn Applewhite',
#      'order': 87,
#      'gender': 0,
#      'profile_path': None},
#     {'id': 1444822,
#      'name': 'Tayler Vee Robinson',
#      'credit_id': '5510ed70c3a3680174000b88',
#      'character': 'Rachel Parker',
#      'order': 88,
#      'gender': 0,
#      'profile_path': None},
#     {'id': 1099819,
#      'name': 'Jennifer Christopher',
#      'credit_id': '5510ed7c925141065c006a9d',
#      'character': 'Gemma Walsh',
#      'order': 89,
#      'gender': 0,
#      'profile_path': None},
#     {'id': 1216971,
#      'name': 'Brynn Thayer',
#      'credit_id': '5510ed84c3a3683e7f0068ee',
#      'character': 'Elena Castillo',
#      'order': 90,
#      'gender': 1,
#      'profile_path': '/yzhOOltoLStU7qs2E1JbrMo4Glq.jpg'},
#     {'id': 155316,
#      'name': 'Vincent Duvall',
#      'credit_id': '5510eef7c3a3683e7f006927',
#      'character': 'D.A. Roger Galvinson',
#      'order': 92,
#      'gender': 2,
#      'profile_path': '/zBlHOpxfltTSB8zB0t2beNNyjNA.jpg'},
#     {'id': 1444823,
#      'name': 'James Logan',
#      'credit_id': '5510ef4b9251415bb3000a24',
#      'character': 'Vince Groves',
#      'order': 93,
#      'gender': 2,
#      'profile_path': '/5fMRvOQ2DafzBPjtYELgTXb9P0P.jpg'},
#     {'id': 138944,
#      'name': 'Innis Casey',
#      'credit_id': '5513e6969251412c52000ea3',
#      'character': 'Adrian Castillo',
#      'order': 116,
#      'gender': 0,
#      'profile_path': '/yMvHEUwWanFCDmIEoDzsOGGWkv7.jpg'}]},
#   {'air_date': '2015-02-19',
#    'episode_number': 13,
#    'id': 1041991,
#    'name': "Mama's Here Now",
#    'overview': 'Annalise is wracked with guilt and turns to an unlikely source for help. Meanwhile, Bonnie must step up and represent a new client accused of rape.',
#    'production_code': None,
#    'season_number': 1,
#    'show_id': 61056,
#    'still_path': '/sqrpLZeLW1m6bYRqgOkLVjsWI0E.jpg',
#    'vote_average': 9.167,
#    'vote_count': 6,
#    'crew': [{'id': 1548201,
#      'credit_id': '566c85d29251412dbc003fcc',
#      'name': 'Doug Stockstill',
#      'department': 'Writing',
#      'job': 'Writer',
#      'profile_path': None},
#     {'id': 1213545,
#      'credit_id': '56366f0a9251416d5200cf14',
#      'name': 'Mike Listo',
#      'department': 'Directing',
#      'job': 'Director',
#      'profile_path': None},
#     {'id': 1239502,
#      'credit_id': '566c83a0c3a3682647008cca',
#      'name': 'Erika Green Swafford',
#      'department': 'Writing',
#      'job': 'Writer',
#      'profile_path': None}],
#    'guest_stars': [{'id': 1435033,
#      'name': 'Chris Kos',
#      'credit_id': '54f792e8c3a3683a690030c1',
#      'character': 'Chad Manning',
#      'order': 1,
#      'gender': 0,
#      'profile_path': '/klfVAq7Mvlh9cnA66HvmX784Ob2.jpg'},
#     {'id': 1435965,
#      'name': 'April Parker-Jones',
#      'credit_id': '5510eceac3a3680174000b69',
#      'character': 'Detective Claire Bryce',
#      'order': 81,
#      'gender': 1,
#      'profile_path': '/5Bg87vQBXIbjP1FBhRb5bx6ScHz.jpg'},
#     {'id': 4726,
#      'name': 'Marcia Gay Harden',
#      'credit_id': '5510ed0f9251415caa000a5a',
#      'character': 'Hannah Keating',
#      'order': 83,
#      'gender': 1,
#      'profile_path': '/x2AZcxKZoozIoigbwOhPMn8nngE.jpg'},
#     {'id': 21490,
#      'name': 'Peter Onorati',
#      'credit_id': '5510f082c3a36801bb000ac3',
#      'character': 'Leo Lombardo',
#      'order': 95,
#      'gender': 2,
#      'profile_path': '/lQ88es19MLX8pNOQc7CmCnIJlng.jpg'},
#     {'id': 157015,
#      'name': 'Michael McGrady',
#      'credit_id': '5510f08b9251415c32000b10',
#      'character': 'AUSA Hobbs',
#      'order': 96,
#      'gender': 2,
#      'profile_path': '/s8P82DWDBLyg1iMedzWdWHfD20v.jpg'},
#     {'id': 1216158,
#      'name': 'Karl Makinen',
#      'credit_id': '5510f094c3a36801d2000b0f',
#      'character': 'Paul Lombardo',
#      'order': 97,
#      'gender': 2,
#      'profile_path': '/nm0elEBcQySAJsx0gWADV7SG5Mf.jpg'},
#     {'id': 177198,
#      'name': 'Hector Luis Bustamante',
#      'credit_id': '5510f0aa9251415c96000a5c',
#      'character': 'Pedro Hortua',
#      'order': 98,
#      'gender': 2,
#      'profile_path': '/85TxAWM7cM6znWpmDsItEfq3gUN.jpg'},
#     {'id': 1444831,
#      'name': 'Matthew Downs',
#      'credit_id': '5510f0c0c3a36802c3000bae',
#      'character': 'Agent Anthony Fain',
#      'order': 99,
#      'gender': 0,
#      'profile_path': None},
#     {'id': 1444832,
#      'name': 'Thomas W. Ashworth',
#      'credit_id': '5510f0cbc3a3683e7f006952',
#      'character': 'Mr. Fisher',
#      'order': 100,
#      'gender': 2,
#      'profile_path': None},
#     {'id': 57959,
#      'name': 'Nelson Mashita',
#      'credit_id': '5510f0d79251415c32000b16',
#      'character': 'Judge Gene Escobar',
#      'order': 101,
#      'gender': 2,
#      'profile_path': None},
#     {'id': 81326,
#      'name': 'Jerry Hauck',
#      'credit_id': '5510f0e2c3a36802c3000bb1',
#      'character': 'Judge James Badgely',
#      'order': 102,
#      'gender': 2,
#      'profile_path': '/4Irw84301bGmjVTPLJlcxx5HbYC.jpg'},
#     {'id': 1136665,
#      'name': 'Cyrus Deboo',
#      'credit_id': '5510f0ec9251415bb3000a4e',
#      'character': 'Professor Tim Dozier',
#      'order': 103,
#      'gender': 2,
#      'profile_path': '/5rQ7CDPdbchjmMtqJAQ5pnQ2hxI.jpg'},
#     {'id': 1444835,
#      'name': 'Marie Caldare',
#      'credit_id': '5510f0f7925141065c006b07',
#      'character': "Leo's Wife",
#      'order': 104,
#      'gender': 0,
#      'profile_path': None},
#     {'id': 1444836,
#      'name': 'Ellen Haun',
#      'credit_id': '5510f101c3a36801d2000b21',
#      'character': 'Ms. Chapin',
#      'order': 105,
#      'gender': 0,
#      'profile_path': None},
#     {'id': 18249,
#      'name': 'Cicely Tyson',
#      'credit_id': '56f8725692514123a0001044',
#      'character': 'Ophelia Hartness',
#      'order': 140,
#      'gender': 1,
#      'profile_path': '/j7j7Qc1qi3W6JOqmPVWqqs5awjt.jpg'}]},
#   {'air_date': '2015-02-26',
#    'episode_number': 14,
#    'id': 1043654,
#    'name': 'The Night Lila Died',
#    'overview': "In flashbacks, we start to piece together what really happened the night of Lila's murder. In present day, Annalise takes on a priest who is accused of murdering another priest. Meanwhile, Connor and Oliver take things to a new level in their relationship, and Wes and Rebecca continue to grow suspicious of each other.",
#    'production_code': None,
#    'season_number': 1,
#    'show_id': 61056,
#    'still_path': '/3YRbqBj5a2v8zlLLbgg3vJetPjf.jpg',
#    'vote_average': 9.0,
#    'vote_count': 5,
#    'crew': [{'id': 454973,
#      'credit_id': '56366de3c3a3681b4b0195ca',
#      'name': 'Laura Innes',
#      'department': 'Directing',
#      'job': 'Director',
#      'profile_path': '/1XMMSTVdPIgYfxUwTF4em8T5rB0.jpg'},
#     {'id': 1530365,
#      'credit_id': '56366faa9251416d5200cf1f',
#      'name': 'Michael Foley',
#      'department': 'Writing',
#      'job': 'Writer',
#      'profile_path': None}],
#    'guest_stars': [{'id': 1444789,
#      'name': 'Lenny Platt',
#      'credit_id': '5510e270c3a3683e7f0067d4',
#      'character': "Griffin O'Reilly",
#      'order': 2,
#      'gender': 2,
#      'profile_path': '/fnqPGXQT5G1GcjVTvHDPSVZZRGu.jpg'},
#     {'id': 1444791,
#      'name': 'Conrad Ricamora',
#      'credit_id': '5510e2839251415c3200099c',
#      'character': 'Oliver Hampton',
#      'order': 6,
#      'gender': 2,
#      'profile_path': '/oWxKQWG4S8r3qM4Ge2I2Uz00teS.jpg'},
#     {'id': 107095,
#      'name': 'Megan West',
#      'credit_id': '5510e30c925141065c006995',
#      'character': 'Lila Stangard',
#      'order': 7,
#      'gender': 0,
#      'profile_path': '/oRK8DXDyW9aPrzloweWJuljremC.jpg'},
#     {'id': 16857,
#      'name': 'Tom Everett Scott',
#      'credit_id': '5510f14ec3a3683e7f00695d',
#      'character': 'Father Andrew Crawford',
#      'order': 106,
#      'gender': 2,
#      'profile_path': '/5f85Hirx8TYIvb9irRtBSrqsq11.jpg'},
#     {'id': 1320468,
#      'name': 'Lilli Birdsell',
#      'credit_id': '5510f1599251415caa000ad6',
#      'character': 'Agnes Wills',
#      'order': 107,
#      'gender': 0,
#      'profile_path': '/iikCSIYVLcOmES4rjbogpymBoEx.jpg'},
#     {'id': 1444845,
#      'name': 'Nick Warnock',
#      'credit_id': '5510f1b49251415bb3000a64',
#      'character': 'Attorney Trent Stockton',
#      'order': 108,
#      'gender': 0,
#      'profile_path': None},
#     {'id': 141293,
#      'name': 'Mari Weiss',
#      'credit_id': '5510f25a925141065c006b2b',
#      'character': 'Judge Clarice Redding',
#      'order': 109,
#      'gender': 1,
#      'profile_path': '/poOqhxdRbrKhpdtREDVIevzVAUn.jpg'},
#     {'id': 155703,
#      'name': 'Karl T. Wright',
#      'credit_id': '5510f278c3a36801bb000b12',
#      'character': 'Judge Bradford Wilkins',
#      'order': 110,
#      'gender': 2,
#      'profile_path': '/AmOifjc4mlmffg4XbwwsnVGkIzq.jpg'},
#     {'id': 156828,
#      'name': 'Sharon Omi',
#      'credit_id': '5510f283c3a36801bb000b18',
#      'character': 'ADA Karen Hawley',
#      'order': 111,
#      'gender': 1,
#      'profile_path': None},
#     {'id': 95796,
#      'name': 'Dan Martin',
#      'credit_id': '5510f292c3a36801bb000b1c',
#      'character': 'Janitor Joe',
#      'order': 112,
#      'gender': 2,
#      'profile_path': '/u24mFuqwEE7kguXK32SS1UzIQzJ.jpg'},
#     {'id': 1444854,
#      'name': 'Jack Mikesell',
#      'credit_id': '5510f2a19251415bb3000a7d',
#      'character': 'Rudy Walters',
#      'order': 113,
#      'gender': 0,
#      'profile_path': None},
#     {'id': 154867,
#      'name': 'Lou Richards',
#      'credit_id': '5510f2b29251415c32000b4f',
#      'character': 'Father Bernard',
#      'order': 114,
#      'gender': 2,
#      'profile_path': '/5R9kZPXG2jIyQvSt3w63EtoaVax.jpg'},
#     {'id': 1444856,
#      'name': 'Caleb Mixson',
#      'credit_id': '5510f2bdc3a3680174000c36',
#      'character': 'Zach',
#      'order': 115,
#      'gender': 0,
#      'profile_path': None},
#     {'id': 1444857,
#      'name': 'Christina Leone',
#      'credit_id': '5510f2c7925141065c006b39',
#      'character': 'Buffy',
#      'order': 116,
#      'gender': 0,
#      'profile_path': None}]},
#   {'air_date': '2015-02-26',
#    'episode_number': 15,
#    'id': 1043655,
#    'name': "It's All My Fault",
#    'overview': "Wes, Connor, Michaela and Laurel may have dug themselves in too deep a hole for Annalise to save them, and the shocking truth about Lila's murder is finally revealed.",
#    'production_code': None,
#    'season_number': 1,
#    'show_id': 61056,
#    'still_path': '/f60xlbBlzn3mHQbk7Zn2KSeBFmi.jpg',
#    'vote_average': 9.0,
#    'vote_count': 5,
#    'crew': [{'id': 1366909,
#      'credit_id': '542167ecbcca014cf6000086',
#      'name': 'Peter Nowalk',
#      'department': 'Writing',
#      'job': 'Writer',
#      'gender': 2,
#      'profile_path': None},
#     {'id': 155007,
#      'credit_id': '542167ecbcca014cf6000088',
#      'name': "Bill D'Elia",
#      'department': 'Directing',
#      'job': 'Director',
#      'gender': 2,
#      'profile_path': '/7f7wWAkx0Ob59vPFXOAGDOh5UkQ.jpg'}],
#    'guest_stars': [{'id': 1444789,
#      'name': 'Lenny Platt',
#      'credit_id': '5510e270c3a3683e7f0067d4',
#      'character': "Griffin O'Reilly",
#      'order': 2,
#      'gender': 2,
#      'profile_path': '/fnqPGXQT5G1GcjVTvHDPSVZZRGu.jpg'},
#     {'id': 1444791,
#      'name': 'Conrad Ricamora',
#      'credit_id': '5510e2839251415c3200099c',
#      'character': 'Oliver Hampton',
#      'order': 6,
#      'gender': 2,
#      'profile_path': '/oWxKQWG4S8r3qM4Ge2I2Uz00teS.jpg'},
#     {'id': 107095,
#      'name': 'Megan West',
#      'credit_id': '5510e30c925141065c006995',
#      'character': 'Lila Stangard',
#      'order': 7,
#      'gender': 0,
#      'profile_path': '/oRK8DXDyW9aPrzloweWJuljremC.jpg'},
#     {'id': 155423,
#      'name': 'Tom Verica',
#      'credit_id': '5510e3a79251415c320009c8',
#      'character': 'Sam Keating',
#      'order': 13,
#      'gender': 2,
#      'profile_path': '/eyOTcWS4vAbciBRbOoZcmkw2TRH.jpg'},
#     {'id': 16217,
#      'name': 'Lynn Whitfield',
#      'credit_id': '5510ebb1c3a3683e7f0068c1',
#      'character': 'Mary Walker',
#      'order': 68,
#      'gender': 1,
#      'profile_path': '/vl99aENfo3wOBWJVvOVj0uIUNfL.jpg'},
#     {'id': 1444854,
#      'name': 'Jack Mikesell',
#      'credit_id': '5510f2a19251415bb3000a7d',
#      'character': 'Rudy Walters',
#      'order': 113,
#      'gender': 0,
#      'profile_path': None},
#     {'id': 80592,
#      'name': 'Sarah Burns',
#      'credit_id': '56366b8ec3a3681b4d01d66c',
#      'character': 'Emily Sinclair',
#      'order': 116,
#      'gender': 1,
#      'profile_path': '/xGyBTIJUG7WC3wjQu0ILBCSSnh0.jpg'}]}],
#  'name': 'Season 1',
#  'overview': '',
#  'id': 61882,
#  'poster_path': '/lub62zywrVzwwdcEVu6FnejIjAI.jpg',
#  'season_number': 1}

# %%
tmdb.TV_Episodes(series_id=61056, season_number=1, episode_number=12).info()
# Out:
# {'air_date': '2015-02-12',
#  'crew': [{'id': 155007,
#    'credit_id': '542167ecbcca014cf6000088',
#    'name': "Bill D'Elia",
#    'department': 'Directing',
#    'job': 'Director',
#    'gender': 2,
#    'profile_path': '/7f7wWAkx0Ob59vPFXOAGDOh5UkQ.jpg'},
#   {'id': 1548195,
#    'credit_id': '566c84a0c3a3682e98008a64',
#    'name': 'Erika Harrison',
#    'department': 'Writing',
#    'job': 'Writer',
#    'gender': 0,
#    'profile_path': None}],
#  'episode_number': 12,
#  'guest_stars': [{'id': 1344869,
#    'name': 'Elliot Knight',
#    'credit_id': '5510e46b9251415bb300091b',
#    'character': 'Aiden Walker',
#    'order': 25,
#    'gender': 2,
#    'profile_path': '/r1J3yXH0uYHpV7XP7MbmILtZJFm.jpg'},
#   {'id': 4726,
#    'name': 'Marcia Gay Harden',
#    'credit_id': '5510ed0f9251415caa000a5a',
#    'character': 'Hannah Keating',
#    'order': 83,
#    'gender': 1,
#    'profile_path': '/x2AZcxKZoozIoigbwOhPMn8nngE.jpg'},
#   {'id': 166688,
#    'name': 'Jackie Geary',
#    'credit_id': '5510ed33c3a36802960009e2',
#    'character': 'Jackie Groves',
#    'order': 84,
#    'gender': 1,
#    'profile_path': '/saIV0KEUYjfDSKsCyODWxCGqbUr.jpg'},
#   {'id': 10963,
#    'name': 'José Zúñiga',
#    'credit_id': '5510ed3d9251415caa000a5f',
#    'character': "Laurel's Dad",
#    'order': 85,
#    'gender': 2,
#    'profile_path': '/uD8aacPO6Zqsr4f3yAkqgT6G4wS.jpg'},
#   {'id': 13029,
#    'name': 'Anne Betancourt',
#    'credit_id': '5510ed4d92514166db0046ac',
#    'character': 'Judge',
#    'order': 86,
#    'gender': 0,
#    'profile_path': '/6UU5P4DzjJTSBFztIu1nALT2tk0.jpg'},
#   {'id': 1384233,
#    'name': 'Tabitha Morella',
#    'credit_id': '5510ed639251415c32000ac1',
#    'character': 'Lynn Applewhite',
#    'order': 87,
#    'gender': 0,
#    'profile_path': None},
#   {'id': 1444822,
#    'name': 'Tayler Vee Robinson',
#    'credit_id': '5510ed70c3a3680174000b88',
#    'character': 'Rachel Parker',
#    'order': 88,
#    'gender': 0,
#    'profile_path': None},
#   {'id': 1099819,
#    'name': 'Jennifer Christopher',
#    'credit_id': '5510ed7c925141065c006a9d',
#    'character': 'Gemma Walsh',
#    'order': 89,
#    'gender': 0,
#    'profile_path': None},
#   {'id': 1216971,
#    'name': 'Brynn Thayer',
#    'credit_id': '5510ed84c3a3683e7f0068ee',
#    'character': 'Elena Castillo',
#    'order': 90,
#    'gender': 1,
#    'profile_path': '/yzhOOltoLStU7qs2E1JbrMo4Glq.jpg'},
#   {'id': 155316,
#    'name': 'Vincent Duvall',
#    'credit_id': '5510eef7c3a3683e7f006927',
#    'character': 'D.A. Roger Galvinson',
#    'order': 92,
#    'gender': 2,
#    'profile_path': '/zBlHOpxfltTSB8zB0t2beNNyjNA.jpg'},
#   {'id': 1444823,
#    'name': 'James Logan',
#    'credit_id': '5510ef4b9251415bb3000a24',
#    'character': 'Vince Groves',
#    'order': 93,
#    'gender': 2,
#    'profile_path': '/5fMRvOQ2DafzBPjtYELgTXb9P0P.jpg'},
#   {'id': 138944,
#    'name': 'Innis Casey',
#    'credit_id': '5513e6969251412c52000ea3',
#    'character': 'Adrian Castillo',
#    'order': 116,
#    'gender': 0,
#    'profile_path': '/yMvHEUwWanFCDmIEoDzsOGGWkv7.jpg'}],
#  'name': 'She’s a Murderer',
#  'overview': "A stunning discovery in Sam's murder case leads to changes for Annalise and the students.",
#  'id': 1039542,
#  'production_code': None,
#  'season_number': 1,
#  'still_path': '/hJu1HBS2icN6Rrx7hWUNXKYVa4V.jpg',
#  'vote_average': 8.6,
#  'vote_count': 5}

# %%
#search.tv(query='The Office')

# %%
tv = tmdb.TV(2316)
#pp.pprint(tv.info())

# %%
sea = tmdb.TV_Seasons(series_id=2316, season_number=1)

# %%
pp.pprint(sea.info())
# Out:
# { '_id': '5257307a760ee3776a33fed0',
#   'air_date': '2005-03-24',
#   'episodes': [ { 'air_date': '2005-03-24',
#                   'crew': [ { 'credit_id': '52573080760ee3776a340945',
#                               'department': 'Writing',
#                               'id': 17835,
#                               'job': 'Writer',
#                               'name': 'Ricky Gervais',
#                               'profile_path': '/Ar8i0W8jOXYFiqUjWk10hjuNtxy.jpg'},
#                             { 'credit_id': '52573080760ee3776a34097d',
#                               'department': 'Writing',
#                               'id': 39189,
#                               'job': 'Writer',
#                               'name': 'Stephen Merchant',
#                               'profile_path': '/A70Gtg3kkTeCBgtFkSRPu9qfPQu.jpg'},
#                             { 'credit_id': '5257307f760ee3776a340736',
#                               'department': 'Directing',
#                               'id': 29009,
#                               'job': 'Director',
#                               'name': 'Ken Kwapis',
#                               'profile_path': '/oPjor2KnZcSXmtude62KT62yBsu.jpg'},
#                             { 'credit_id': '5257307d760ee3776a340339',
#                               'department': 'Writing',
#                               'id': 1216630,
#                               'job': 'Writer',
#                               'name': 'Greg Daniels',
#                               'profile_path': '/fkB49DuNjKknUpfCmqqGaN4U5NY.jpg'}],
#                   'episode_number': 1,
#                   'guest_stars': [ { 'character': '',
#                                      'credit_id': '5257307a760ee3776a34004c',
#                                      'gender': 2,
#                                      'id': 62562,
#                                      'name': 'David Denman',
#                                      'order': 1,
#                                      'profile_path': '/7fjnNnXLDOYRlDlCVOuVb7hiF7h.jpg'},
#                                    { 'character': '',
#                                      'credit_id': '5257307a760ee3776a34007e',
#                                      'gender': 1,
#                                      'id': 404,
#                                      'name': 'Melora Hardin',
#                                      'order': 2,
#                                      'profile_path': '/uecs9JKOqgYj3PrSGECaFzc3E2r.jpg'},
#                                    { 'character': '',
#                                      'credit_id': '5257307a760ee3776a3400b0',
#                                      'gender': 1,
#                                      'id': 113867,
#                                      'name': 'Angela Kinsey',
#                                      'order': 3,
#                                      'profile_path': '/omLdRLdwMLliVeVIualEnWVhm1a.jpg'},
#                                    { 'character': '',
#                                      'credit_id': '5257307b760ee3776a340114',
#                                      'gender': 2,
#                                      'id': 94622,
#                                      'name': 'Brian Baumgartner',
#                                      'order': 5,
#                                      'profile_path': '/vQU66gkfPae07VhTDySajDOXpHy.jpg'},
#                                    { 'character': '',
#                                      'credit_id': '52573080760ee3776a340911',
#                                      'gender': 0,
#                                      'id': 1224522,
#                                      'name': 'Henriette Mantel',
#                                      'order': 6,
#                                      'profile_path': '/b6R7YCtfOdGBfrlKfjQDgaQwZhA.jpg'},
#                                    { 'character': '',
#                                      'credit_id': '5257307c760ee3776a340148',
#                                      'gender': 2,
#                                      'id': 1230842,
#                                      'name': 'Leslie David Baker',
#                                      'order': 6,
#                                      'profile_path': '/9h3xlV5IYqKinlQCW1ouU7sjwWF.jpg'},
#                                    { 'character': '',
#                                      'credit_id': '5257307d760ee3776a34017c',
#                                      'gender': 1,
#                                      'id': 169200,
#                                      'name': 'Phyllis Smith',
#                                      'order': 7,
#                                      'profile_path': '/jSheKnNOV5UJq4RNMbpFT3ONniy.jpg'}],
#                   'id': 170135,
#                   'name': 'Pilot',
#                   'overview': 'A documentary crew arrives at the offices of '
#                               'Dunder Mifflin to observe the employees and '
#                               'learn about modern management. Manager Michael '
#                               'Scott tries to paint a happy picture, while '
#                               'sales rep Jim fights with his nemesis Dwight '
#                               'and flirts with receptionist Pam.',
#                   'production_code': '1001',
#                   'season_number': 1,
#                   'show_id': 2316,
#                   'still_path': '/qSIPTlgutivKQOAXO5DlgUPtOIn.jpg',
#                   'vote_average': 7.5,
#                   'vote_count': 2},
#                 { 'air_date': '2005-03-29',
#                   'crew': [ { 'credit_id': '5257307f760ee3776a340736',
#                               'department': 'Directing',
#                               'id': 29009,
#                               'job': 'Director',
#                               'name': 'Ken Kwapis',
#                               'profile_path': '/oPjor2KnZcSXmtude62KT62yBsu.jpg'},
#                             { 'credit_id': '5257307f760ee3776a340702',
#                               'department': 'Writing',
#                               'id': 107770,
#                               'job': 'Writer',
#                               'name': 'B. J. Novak',
#                               'profile_path': '/aD2ewhKJymfPGYpGFS4JCzop7Lh.jpg'}],
#                   'episode_number': 2,
#                   'guest_stars': [ { 'character': '',
#                                      'credit_id': '5257307d760ee3776a3403ae',
#                                      'gender': 2,
#                                      'id': 154091,
#                                      'name': 'Larry Wilmore',
#                                      'order': 0,
#                                      'profile_path': '/8Sa6pB7gEHY4gkzCXDmJMIkzqsW.jpg'},
#                                    { 'character': '',
#                                      'credit_id': '5257307a760ee3776a3400b0',
#                                      'gender': 1,
#                                      'id': 113867,
#                                      'name': 'Angela Kinsey',
#                                      'order': 3,
#                                      'profile_path': '/omLdRLdwMLliVeVIualEnWVhm1a.jpg'},
#                                    { 'character': '',
#                                      'credit_id': '5257307a760ee3776a3400e2',
#                                      'gender': 1,
#                                      'id': 304282,
#                                      'name': 'Kate Flannery',
#                                      'order': 4,
#                                      'profile_path': '/h6rtBhGejDbPyWCKMSUT06fJOVt.jpg'},
#                                    { 'character': '',
#                                      'credit_id': '5257307b760ee3776a340114',
#                                      'gender': 2,
#                                      'id': 94622,
#                                      'name': 'Brian Baumgartner',
#                                      'order': 5,
#                                      'profile_path': '/vQU66gkfPae07VhTDySajDOXpHy.jpg'},
#                                    { 'character': '',
#                                      'credit_id': '5257307e760ee3776a3403f8',
#                                      'gender': 1,
#                                      'id': 125167,
#                                      'name': 'Mindy Kaling',
#                                      'order': 5,
#                                      'profile_path': '/bZ8A6fYjn6FbiAhqHdGfFh95vLh.jpg'},
#                                    { 'character': '',
#                                      'credit_id': '5257307c760ee3776a340148',
#                                      'gender': 2,
#                                      'id': 1230842,
#                                      'name': 'Leslie David Baker',
#                                      'order': 6,
#                                      'profile_path': '/9h3xlV5IYqKinlQCW1ouU7sjwWF.jpg'},
#                                    { 'character': '',
#                                      'credit_id': '5257307d760ee3776a34017c',
#                                      'gender': 1,
#                                      'id': 169200,
#                                      'name': 'Phyllis Smith',
#                                      'order': 7,
#                                      'profile_path': '/jSheKnNOV5UJq4RNMbpFT3ONniy.jpg'}],
#                   'id': 170132,
#                   'name': 'Diversity Day',
#                   'overview': 'A consultant arrives to teach the staff about '
#                               'tolerance and diversity but Michael insists on '
#                               'imparting his own knowledge. Meanwhile, Jim '
#                               'struggles to keep hold of a lucrative contract '
#                               'extension.',
#                   'production_code': '1002',
#                   'season_number': 1,
#                   'show_id': 2316,
#                   'still_path': '/h539DweEaSNFQQPwwpbjKIuM1L.jpg',
#                   'vote_average': 8.0,
#                   'vote_count': 1},
#                 { 'air_date': '2005-04-05',
#                   'crew': [ { 'credit_id': '52573080760ee3776a3408ac',
#                               'department': 'Directing',
#                               'id': 1212689,
#                               'job': 'Director',
#                               'name': 'Ken Whittingham',
#                               'profile_path': '/5hnh03Wto8VkQcrosD8RtpMiLeQ.jpg'},
#                             { 'credit_id': '52573080760ee3776a340878',
#                               'department': 'Writing',
#                               'id': 1213125,
#                               'job': 'Writer',
#                               'name': 'Paul Lieberstein',
#                               'profile_path': '/txcTMWu5ARZhohRD6v9tKc13TXv.jpg'}],
#                   'episode_number': 3,
#                   'guest_stars': [ { 'character': '',
#                                      'credit_id': '5257307a760ee3776a34007e',
#                                      'gender': 1,
#                                      'id': 404,
#                                      'name': 'Melora Hardin',
#                                      'order': 2,
#                                      'profile_path': '/uecs9JKOqgYj3PrSGECaFzc3E2r.jpg'},
#                                    { 'character': '',
#                                      'credit_id': '5257307a760ee3776a3400b0',
#                                      'gender': 1,
#                                      'id': 113867,
#                                      'name': 'Angela Kinsey',
#                                      'order': 3,
#                                      'profile_path': '/omLdRLdwMLliVeVIualEnWVhm1a.jpg'},
#                                    { 'character': '',
#                                      'credit_id': '5257307a760ee3776a3400e2',
#                                      'gender': 1,
#                                      'id': 304282,
#                                      'name': 'Kate Flannery',
#                                      'order': 4,
#                                      'profile_path': '/h6rtBhGejDbPyWCKMSUT06fJOVt.jpg'},
#                                    { 'character': '',
#                                      'credit_id': '5257307b760ee3776a340114',
#                                      'gender': 2,
#                                      'id': 94622,
#                                      'name': 'Brian Baumgartner',
#                                      'order': 5,
#                                      'profile_path': '/vQU66gkfPae07VhTDySajDOXpHy.jpg'},
#                                    { 'character': '',
#                                      'credit_id': '5257307e760ee3776a3403f8',
#                                      'gender': 1,
#                                      'id': 125167,
#                                      'name': 'Mindy Kaling',
#                                      'order': 5,
#                                      'profile_path': '/bZ8A6fYjn6FbiAhqHdGfFh95vLh.jpg'},
#                                    { 'character': '',
#                                      'credit_id': '5257307c760ee3776a340148',
#                                      'gender': 2,
#                                      'id': 1230842,
#                                      'name': 'Leslie David Baker',
#                                      'order': 6,
#                                      'profile_path': '/9h3xlV5IYqKinlQCW1ouU7sjwWF.jpg'},
#                                    { 'character': '',
#                                      'credit_id': '52573080760ee3776a340844',
#                                      'gender': 2,
#                                      'id': 54704,
#                                      'name': 'Charlie Hartsock',
#                                      'order': 7,
#                                      'profile_path': '/x8P9MAClyW4pAGdB1RndzUxDtne.jpg'},
#                                    { 'character': '',
#                                      'credit_id': '5257307d760ee3776a34017c',
#                                      'gender': 1,
#                                      'id': 169200,
#                                      'name': 'Phyllis Smith',
#                                      'order': 7,
#                                      'profile_path': '/jSheKnNOV5UJq4RNMbpFT3ONniy.jpg'}],
#                   'id': 170134,
#                   'name': 'Health Care',
#                   'overview': "Michael doesn't want to upset the staff so he "
#                               "gets Dwight to pass on news about the company's "
#                               'reduced health provisions. Fed up with his '
#                               'nosiness, Jim and Pam pretend they are '
#                               'suffering from a variety of conditions '
#                               'including Ebola, Mad Cow Disease, spontaneous '
#                               'dentohydroplosion, hotdog fingers, nano-robot '
#                               'infection, inverted penis and anal fissures.',
#                   'production_code': '1006',
#                   'season_number': 1,
#                   'show_id': 2316,
#                   'still_path': '/oQd8zzPk64Sn2dsFMHFN8uCdRfc.jpg',
#                   'vote_average': 7.0,
#                   'vote_count': 1},
#                 { 'air_date': '2005-04-12',
#                   'crew': [ { 'credit_id': '5257307f760ee3776a3407d7',
#                               'department': 'Directing',
#                               'id': 122583,
#                               'job': 'Director',
#                               'name': 'Bryan Gordon',
#                               'profile_path': None},
#                             { 'credit_id': '5257307f760ee3776a3407a3',
#                               'department': 'Writing',
#                               'id': 1226308,
#                               'job': 'Writer',
#                               'name': 'Michael Schur',
#                               'profile_path': '/AdC7KViR7Chao97jY1heszmdfnx.jpg'}],
#                   'episode_number': 4,
#                   'guest_stars': [ { 'character': '',
#                                      'credit_id': '5257307a760ee3776a34004c',
#                                      'gender': 2,
#                                      'id': 62562,
#                                      'name': 'David Denman',
#                                      'order': 1,
#                                      'profile_path': '/7fjnNnXLDOYRlDlCVOuVb7hiF7h.jpg'},
#                                    { 'character': '',
#                                      'credit_id': '5257307a760ee3776a3400b0',
#                                      'gender': 1,
#                                      'id': 113867,
#                                      'name': 'Angela Kinsey',
#                                      'order': 3,
#                                      'profile_path': '/omLdRLdwMLliVeVIualEnWVhm1a.jpg'},
#                                    { 'character': '',
#                                      'credit_id': '5257307d760ee3776a3402e1',
#                                      'gender': 2,
#                                      'id': 64342,
#                                      'name': 'Craig Robinson',
#                                      'order': 3,
#                                      'profile_path': '/tVaRMkJXOEVhYxtnnFuhqW0Rjzz.jpg'},
#                                    { 'character': '',
#                                      'credit_id': '5257307a760ee3776a3400e2',
#                                      'gender': 1,
#                                      'id': 304282,
#                                      'name': 'Kate Flannery',
#                                      'order': 4,
#                                      'profile_path': '/h6rtBhGejDbPyWCKMSUT06fJOVt.jpg'},
#                                    { 'character': '',
#                                      'credit_id': '5257307b760ee3776a340114',
#                                      'gender': 2,
#                                      'id': 94622,
#                                      'name': 'Brian Baumgartner',
#                                      'order': 5,
#                                      'profile_path': '/vQU66gkfPae07VhTDySajDOXpHy.jpg'},
#                                    { 'character': '',
#                                      'credit_id': '5257307c760ee3776a340148',
#                                      'gender': 2,
#                                      'id': 1230842,
#                                      'name': 'Leslie David Baker',
#                                      'order': 6,
#                                      'profile_path': '/9h3xlV5IYqKinlQCW1ouU7sjwWF.jpg'},
#                                    { 'character': '',
#                                      'credit_id': '5257307d760ee3776a34017c',
#                                      'gender': 1,
#                                      'id': 169200,
#                                      'name': 'Phyllis Smith',
#                                      'order': 7,
#                                      'profile_path': '/jSheKnNOV5UJq4RNMbpFT3ONniy.jpg'}],
#                   'id': 170133,
#                   'name': 'The Alliance',
#                   'overview': 'Michael arranges a morale-boosting birthday '
#                               'party for Meredith and is determined to come up '
#                               'with the funniest message in her card. Dwight '
#                               'wants a pact with Jim to fight the downsizing, '
#                               'and Michael regrets showing off when Oscar asks '
#                               'for sponsorship for a charity walk being '
#                               'undertaken by his nephew, who has cerebral '
#                               'palsy.',
#                   'production_code': '1004',
#                   'season_number': 1,
#                   'show_id': 2316,
#                   'still_path': '/upKB46d5klri3jmOkZqjuRpqAOo.jpg',
#                   'vote_average': 8.0,
#                   'vote_count': 1},
#                 { 'air_date': '2005-04-19',
#                   'crew': [ { 'credit_id': '5257307d760ee3776a34036d',
#                               'department': 'Directing',
#                               'id': 1216630,
#                               'job': 'Director',
#                               'name': 'Greg Daniels',
#                               'profile_path': '/fkB49DuNjKknUpfCmqqGaN4U5NY.jpg'},
#                             { 'credit_id': '5257307d760ee3776a340339',
#                               'department': 'Writing',
#                               'id': 1216630,
#                               'job': 'Writer',
#                               'name': 'Greg Daniels',
#                               'profile_path': '/fkB49DuNjKknUpfCmqqGaN4U5NY.jpg'}],
#                   'episode_number': 5,
#                   'guest_stars': [ { 'character': '',
#                                      'credit_id': '5257307d760ee3776a34024b',
#                                      'gender': 2,
#                                      'id': 543256,
#                                      'name': "Patrice O'Neal",
#                                      'order': 0,
#                                      'profile_path': '/jvck3EQU2foaaEz7CdlaP3RaCNM.jpg'},
#                                    { 'character': '',
#                                      'credit_id': '5257307a760ee3776a34004c',
#                                      'gender': 2,
#                                      'id': 62562,
#                                      'name': 'David Denman',
#                                      'order': 1,
#                                      'profile_path': '/7fjnNnXLDOYRlDlCVOuVb7hiF7h.jpg'},
#                                    { 'character': '',
#                                      'credit_id': '5257307d760ee3776a34027d',
#                                      'gender': 1,
#                                      'id': 1219924,
#                                      'name': 'Karly Rothenberg',
#                                      'order': 1,
#                                      'profile_path': '/hJOemjP9oDP04qiIuATAMzdJejG.jpg'},
#                                    { 'character': '',
#                                      'credit_id': '5257307d760ee3776a3402af',
#                                      'gender': 2,
#                                      'id': 332803,
#                                      'name': 'Matt Decaro',
#                                      'order': 2,
#                                      'profile_path': '/vXl60Fcf1seqGkSrvCrFdkp6r7r.jpg'},
#                                    { 'character': '',
#                                      'credit_id': '5257307a760ee3776a3400b0',
#                                      'gender': 1,
#                                      'id': 113867,
#                                      'name': 'Angela Kinsey',
#                                      'order': 3,
#                                      'profile_path': '/omLdRLdwMLliVeVIualEnWVhm1a.jpg'},
#                                    { 'character': '',
#                                      'credit_id': '5257307d760ee3776a3402e1',
#                                      'gender': 2,
#                                      'id': 64342,
#                                      'name': 'Craig Robinson',
#                                      'order': 3,
#                                      'profile_path': '/tVaRMkJXOEVhYxtnnFuhqW0Rjzz.jpg'},
#                                    { 'character': '',
#                                      'credit_id': '5257307a760ee3776a3400e2',
#                                      'gender': 1,
#                                      'id': 304282,
#                                      'name': 'Kate Flannery',
#                                      'order': 4,
#                                      'profile_path': '/h6rtBhGejDbPyWCKMSUT06fJOVt.jpg'},
#                                    { 'character': '',
#                                      'credit_id': '5257307b760ee3776a340114',
#                                      'gender': 2,
#                                      'id': 94622,
#                                      'name': 'Brian Baumgartner',
#                                      'order': 5,
#                                      'profile_path': '/vQU66gkfPae07VhTDySajDOXpHy.jpg'},
#                                    { 'character': '',
#                                      'credit_id': '5257307c760ee3776a340148',
#                                      'gender': 2,
#                                      'id': 1230842,
#                                      'name': 'Leslie David Baker',
#                                      'order': 6,
#                                      'profile_path': '/9h3xlV5IYqKinlQCW1ouU7sjwWF.jpg'},
#                                    { 'character': '',
#                                      'credit_id': '5257307d760ee3776a34017c',
#                                      'gender': 1,
#                                      'id': 169200,
#                                      'name': 'Phyllis Smith',
#                                      'order': 7,
#                                      'profile_path': '/jSheKnNOV5UJq4RNMbpFT3ONniy.jpg'}],
#                   'id': 170131,
#                   'name': 'Basketball',
#                   'overview': 'The office staff play a basketball game against '
#                               'the warehouse workers in which Jim shows off to '
#                               'impress Pam and upstage her fiancee who is on '
#                               'the opposing team.',
#                   'production_code': '1005',
#                   'season_number': 1,
#                   'show_id': 2316,
#                   'still_path': '/1cvMeuQYpgvLQYre6FTkVHmlV3G.jpg',
#                   'vote_average': 7.0,
#                   'vote_count': 1},
#                 { 'air_date': '2005-04-26',
#                   'crew': [ { 'credit_id': '5257307d760ee3776a34020a',
#                               'department': 'Directing',
#                               'id': 57434,
#                               'job': 'Director',
#                               'name': 'Amy Heckerling',
#                               'profile_path': '/c68tZT9Be1triBbKmSOKCS3dsBI.jpg'},
#                             { 'credit_id': '5257307d760ee3776a3401b0',
#                               'department': 'Writing',
#                               'id': 125167,
#                               'job': 'Writer',
#                               'name': 'Mindy Kaling',
#                               'profile_path': '/O3d0uQDznAHS4uWobaP0WLR35n.jpg'}],
#                   'episode_number': 6,
#                   'guest_stars': [ { 'character': 'Katy',
#                                      'credit_id': '5257307a760ee3776a34001a',
#                                      'gender': 1,
#                                      'id': 9273,
#                                      'name': 'Amy Adams',
#                                      'order': 0,
#                                      'profile_path': '/1h2r2VTpoFb5QefAaBYYQgQzL9z.jpg'},
#                                    { 'character': '',
#                                      'credit_id': '5257307a760ee3776a34004c',
#                                      'gender': 2,
#                                      'id': 62562,
#                                      'name': 'David Denman',
#                                      'order': 1,
#                                      'profile_path': '/7fjnNnXLDOYRlDlCVOuVb7hiF7h.jpg'},
#                                    { 'character': '',
#                                      'credit_id': '5257307a760ee3776a34007e',
#                                      'gender': 1,
#                                      'id': 404,
#                                      'name': 'Melora Hardin',
#                                      'order': 2,
#                                      'profile_path': '/uecs9JKOqgYj3PrSGECaFzc3E2r.jpg'},
#                                    { 'character': '',
#                                      'credit_id': '5257307a760ee3776a3400b0',
#                                      'gender': 1,
#                                      'id': 113867,
#                                      'name': 'Angela Kinsey',
#                                      'order': 3,
#                                      'profile_path': '/omLdRLdwMLliVeVIualEnWVhm1a.jpg'},
#                                    { 'character': '',
#                                      'credit_id': '5257307a760ee3776a3400e2',
#                                      'gender': 1,
#                                      'id': 304282,
#                                      'name': 'Kate Flannery',
#                                      'order': 4,
#                                      'profile_path': '/h6rtBhGejDbPyWCKMSUT06fJOVt.jpg'},
#                                    { 'character': '',
#                                      'credit_id': '5257307b760ee3776a340114',
#                                      'gender': 2,
#                                      'id': 94622,
#                                      'name': 'Brian Baumgartner',
#                                      'order': 5,
#                                      'profile_path': '/vQU66gkfPae07VhTDySajDOXpHy.jpg'},
#                                    { 'character': '',
#                                      'credit_id': '5257307c760ee3776a340148',
#                                      'gender': 2,
#                                      'id': 1230842,
#                                      'name': 'Leslie David Baker',
#                                      'order': 6,
#                                      'profile_path': '/9h3xlV5IYqKinlQCW1ouU7sjwWF.jpg'},
#                                    { 'character': '',
#                                      'credit_id': '5257307d760ee3776a34017c',
#                                      'gender': 1,
#                                      'id': 169200,
#                                      'name': 'Phyllis Smith',
#                                      'order': 7,
#                                      'profile_path': '/jSheKnNOV5UJq4RNMbpFT3ONniy.jpg'}],
#                   'id': 170130,
#                   'name': 'Hot Girl',
#                   'overview': 'A woman who comes to the office to sell purses '
#                               'gets the male members of staff excited. She '
#                               "rejects Dwight's advances, but Michael reckons "
#                               "he's still in with a chance.",
#                   'production_code': '1003',
#                   'season_number': 1,
#                   'show_id': 2316,
#                   'still_path': '/aeKIJvE2EhW1kl1k0bpqrrzft54.jpg',
#                   'vote_average': 7.0,
#                   'vote_count': 1}],
#   'id': 7240,
#   'name': 'Season 1',
#   'overview': 'The first season of the American television comedy The Office '
#               'premiered in the United States on NBC on March 24, 2005, '
#               'concluded on April 26, 2005, and consists of six episodes. The '
#               'Office is an American adaptation of the British TV series of '
#               'the same name, and is presented in a mockumentary format, '
#               'portraying the daily lives of office employees in the Scranton, '
#               'Pennsylvania branch of the fictitious Dunder Mifflin Paper '
#               'Company.\n'
#               '\n'
#               'This season introduced the main characters, and established the '
#               'general plot, which revolves around Michael Scott, regional '
#               'manager of the Scranton branch office, trying to convince the '
#               'filmmakers of the documentary that he presides over a happy, '
#               'well-running office. Meanwhile, sales rep Jim Halpert finds '
#               'methods to undermine his cube-mate, Dwight Schrute; '
#               "receptionist Pam Beesly tries to deal with Michael's "
#               'insensitivities and flubs; and temporary employee Ryan Howard '
#               'is acting mostly as an observer of the insanity around him.\n'
#               '\n'
#               'Season one of The Office aired on Tuesdays in the United States '
#               'at 9:30 p.m. The season debuted to high numbers, and garnered '
#               'moderately positive reviews from critics aside from a '
#               'poorly-received pilot episode. While some enjoyed the pilot, '
#               'others opined that it was a mere copy of the original British '
#               'version. Universal Studios Home Entertainment released season '
#               'one in a single DVD on August 16, 2005. The DVD contained all '
#               'six episodes, as well as commentaries from creators, writers, '
#               'actors, and directors on most of the episodes, as well as '
#               'deleted scenes from all of the episodes.',
#   'poster_path': '/qiXAx87r7kyF3yvvlTOL9fL0sUg.jpg',
#   'season_number': 1}

# %%
ep = tmdb.TV_Episodes(series_id=2316, season_number=1, episode_number=1)

# %%
pp.pprint(ep.info())
# Out:
# { 'air_date': '2005-03-24',
#   'crew': [ { 'credit_id': '52573080760ee3776a340945',
#               'department': 'Writing',
#               'id': 17835,
#               'job': 'Writer',
#               'name': 'Ricky Gervais',
#               'profile_path': '/Ar8i0W8jOXYFiqUjWk10hjuNtxy.jpg'},
#             { 'credit_id': '52573080760ee3776a34097d',
#               'department': 'Writing',
#               'id': 39189,
#               'job': 'Writer',
#               'name': 'Stephen Merchant',
#               'profile_path': '/A70Gtg3kkTeCBgtFkSRPu9qfPQu.jpg'},
#             { 'credit_id': '5257307f760ee3776a340736',
#               'department': 'Directing',
#               'id': 29009,
#               'job': 'Director',
#               'name': 'Ken Kwapis',
#               'profile_path': '/oPjor2KnZcSXmtude62KT62yBsu.jpg'},
#             { 'credit_id': '5257307d760ee3776a340339',
#               'department': 'Writing',
#               'id': 1216630,
#               'job': 'Writer',
#               'name': 'Greg Daniels',
#               'profile_path': '/fkB49DuNjKknUpfCmqqGaN4U5NY.jpg'}],
#   'episode_number': 1,
#   'guest_stars': [ { 'character': '',
#                      'credit_id': '5257307a760ee3776a34004c',
#                      'gender': 2,
#                      'id': 62562,
#                      'name': 'David Denman',
#                      'order': 1,
#                      'profile_path': '/7fjnNnXLDOYRlDlCVOuVb7hiF7h.jpg'},
#                    { 'character': '',
#                      'credit_id': '5257307a760ee3776a34007e',
#                      'gender': 1,
#                      'id': 404,
#                      'name': 'Melora Hardin',
#                      'order': 2,
#                      'profile_path': '/uecs9JKOqgYj3PrSGECaFzc3E2r.jpg'},
#                    { 'character': '',
#                      'credit_id': '5257307a760ee3776a3400b0',
#                      'gender': 1,
#                      'id': 113867,
#                      'name': 'Angela Kinsey',
#                      'order': 3,
#                      'profile_path': '/omLdRLdwMLliVeVIualEnWVhm1a.jpg'},
#                    { 'character': '',
#                      'credit_id': '5257307b760ee3776a340114',
#                      'gender': 2,
#                      'id': 94622,
#                      'name': 'Brian Baumgartner',
#                      'order': 5,
#                      'profile_path': '/vQU66gkfPae07VhTDySajDOXpHy.jpg'},
#                    { 'character': '',
#                      'credit_id': '52573080760ee3776a340911',
#                      'gender': 0,
#                      'id': 1224522,
#                      'name': 'Henriette Mantel',
#                      'order': 6,
#                      'profile_path': '/b6R7YCtfOdGBfrlKfjQDgaQwZhA.jpg'},
#                    { 'character': '',
#                      'credit_id': '5257307c760ee3776a340148',
#                      'gender': 2,
#                      'id': 1230842,
#                      'name': 'Leslie David Baker',
#                      'order': 6,
#                      'profile_path': '/9h3xlV5IYqKinlQCW1ouU7sjwWF.jpg'},
#                    { 'character': '',
#                      'credit_id': '5257307d760ee3776a34017c',
#                      'gender': 1,
#                      'id': 169200,
#                      'name': 'Phyllis Smith',
#                      'order': 7,
#                      'profile_path': '/jSheKnNOV5UJq4RNMbpFT3ONniy.jpg'}],
#   'id': 170135,
#   'name': 'Pilot',
#   'overview': 'A documentary crew arrives at the offices of Dunder Mifflin to '
#               'observe the employees and learn about modern management. '
#               'Manager Michael Scott tries to paint a happy picture, while '
#               'sales rep Jim fights with his nemesis Dwight and flirts with '
#               'receptionist Pam.',
#   'production_code': '1001',
#   'season_number': 1,
#   'still_path': '/qSIPTlgutivKQOAXO5DlgUPtOIn.jpg',
#   'vote_average': 7.5,
#   'vote_count': 2}

# %%
search.tv(query='Breaking Bad')
# Out:
# {'page': 1,
#  'total_results': 1,
#  'total_pages': 1,
#  'results': [{'original_name': 'Breaking Bad',
#    'id': 1396,
#    'name': 'Breaking Bad',
#    'vote_count': 2805,
#    'vote_average': 8.32,
#    'poster_path': '/1yeVJox3rjo2jBKrrihIMj7uoS9.jpg',
#    'first_air_date': '2008-01-20',
#    'popularity': 49.626,
#    'genre_ids': [18],
#    'original_language': 'en',
#    'backdrop_path': '/eSzpy96DwBujGFj0xMbXBcGcfxX.jpg',
#    'overview': "When Walter White, a New Mexico chemistry teacher, is diagnosed with Stage III cancer and given a prognosis of only two years left to live, he becomes filled with a sense of fearlessness and an unrelenting desire to secure his family's financial future at any cost as he enters the dangerous world of drugs and crime.",
#    'origin_country': ['US']}]}

# %%
tv = tmdb.TV(1396)
pp.pprint(tv.info())
# Out:
# { 'backdrop_path': '/eSzpy96DwBujGFj0xMbXBcGcfxX.jpg',
#   'created_by': [ { 'credit_id': '52542286760ee31328001a7b',
#                     'id': 66633,
#                     'name': 'Vince Gilligan',
#                     'profile_path': '/rLSUjr725ez1cK7SKVxC9udO03Y.jpg'}],
#   'episode_run_time': [45, 47],
#   'first_air_date': '2008-01-20',
#   'genres': [{'id': 18, 'name': 'Drama'}],
#   'homepage': 'http://www.amc.com/shows/breaking-bad',
#   'id': 1396,
#   'in_production': False,
#   'languages': ['en'],
#   'last_air_date': '2013-09-29',
#   'last_episode_to_air': { 'air_date': '2013-09-29',
#                            'episode_number': 16,
#                            'id': 62161,
#                            'name': 'Felina',
#                            'overview': 'All bad things must come to an end.',
#                            'production_code': None,
#                            'season_number': 5,
#                            'show_id': 1396,
#                            'still_path': '/pA0YwyhvdDXP3BEGL2grrIhq8aM.jpg',
#                            'vote_average': 8.872,
#                            'vote_count': 47},
#   'name': 'Breaking Bad',
#   'networks': [ { 'id': 174,
#                   'logo_path': '/pmvRmATOCaDykE6JrVoeYxlFHw3.png',
#                   'name': 'AMC',
#                   'origin_country': 'US'}],
#   'next_episode_to_air': None,
#   'number_of_episodes': 62,
#   'number_of_seasons': 5,
#   'origin_country': ['US'],
#   'original_language': 'en',
#   'original_name': 'Breaking Bad',
#   'overview': 'When Walter White, a New Mexico chemistry teacher, is diagnosed '
#               'with Stage III cancer and given a prognosis of only two years '
#               'left to live, he becomes filled with a sense of fearlessness '
#               "and an unrelenting desire to secure his family's financial "
#               'future at any cost as he enters the dangerous world of drugs '
#               'and crime.',
#   'popularity': 49.626,
#   'poster_path': '/1yeVJox3rjo2jBKrrihIMj7uoS9.jpg',
#   'production_companies': [ { 'id': 11073,
#                               'logo_path': '/wHs44fktdoj6c378ZbSWfzKsM2Z.png',
#                               'name': 'Sony Pictures Television',
#                               'origin_country': 'US'},
#                             { 'id': 33742,
#                               'logo_path': None,
#                               'name': 'High Bridge Entertainment',
#                               'origin_country': ''},
#                             { 'id': 2605,
#                               'logo_path': None,
#                               'name': 'Gran Via Productions',
#                               'origin_country': ''}],
#   'seasons': [ { 'air_date': '2009-02-17',
#                  'episode_count': 6,
#                  'id': 3577,
#                  'name': 'Specials',
#                  'overview': '',
#                  'poster_path': '/AngNuUbXSciwLnUXtdOBHqphxNr.jpg',
#                  'season_number': 0},
#                { 'air_date': '2008-01-20',
#                  'episode_count': 7,
#                  'id': 3572,
#                  'name': 'Season 1',
#                  'overview': "High school chemistry teacher Walter White's "
#                              'life is suddenly transformed by a dire medical '
#                              'diagnosis. Street-savvy former student Jesse '
#                              'Pinkman "teaches" Walter a new trade.',
#                  'poster_path': '/1BP4xYv9ZG4ZVHkL7ocOziBbSYH.jpg',
#                  'season_number': 1},
#                { 'air_date': '2009-03-08',
#                  'episode_count': 13,
#                  'id': 3573,
#                  'name': 'Season 2',
#                  'overview': 'In the second season, Walt must deal with the '
#                              'chain reaction of his choice, as he and Jesse '
#                              'face new and severe consequences. When danger '
#                              'and suspicion around Walt escalate, he is pushed '
#                              'to new levels of desperation. Just how much '
#                              'higher will the stakes rise? How far is Walt '
#                              "willing to go to ensure his family's security? "
#                              'Will his grand plan spiral out of control?',
#                  'poster_path': '/gdzDWM65k0Mrw1O4PFQm4ickcLV.jpg',
#                  'season_number': 2},
#                { 'air_date': '2010-03-21',
#                  'episode_count': 13,
#                  'id': 3575,
#                  'name': 'Season 3',
#                  'overview': 'In the third season, Walt continues to battle '
#                              'dueling identities: a desperate husband and '
#                              'father trying to provide for his family, and a '
#                              'newly appointed key player in the Albuquerque '
#                              'drug trade. As the danger around him escalates, '
#                              'Walt is now entrenched in the complex worlds of '
#                              'an angst-ridden family on the verge of '
#                              'dissolution, and the ruthless and unrelenting '
#                              'drug cartel.',
#                  'poster_path': '/ffP8Q8ew048YofHRnFVM18B2fPG.jpg',
#                  'season_number': 3},
#                { 'air_date': '2011-07-17',
#                  'episode_count': 13,
#                  'id': 3576,
#                  'name': 'Season 4',
#                  'overview': 'This season, Walt and Jesse must cope with the '
#                              'fallout of their previous actions, both '
#                              'personally and professionally. Tension mounts as '
#                              'Walt faces a true standoff with his employer, '
#                              'Gus, with neither side willing or able to back '
#                              'down. Walt must also adjust to a new '
#                              'relationship with Skyler, whom while still '
#                              'reconciling her relationship with Walt, is '
#                              'committed to properly laundering Walt’s money '
#                              'and ensuring her sister Marie and an ailing Hank '
#                              'are financially stable.',
#                  'poster_path': '/hEOORc9661CRPpDa207w1GuEAMj.jpg',
#                  'season_number': 4},
#                { 'air_date': '2012-07-15',
#                  'episode_count': 16,
#                  'id': 3578,
#                  'name': 'Season 5',
#                  'overview': 'In season five, Walt is faced with the prospect '
#                              'of moving on in a world without his enemy. As '
#                              'the pressure of a criminal life starts to build, '
#                              'Skyler struggles to keep Walt’s terrible '
#                              'secrets. Facing resistance from sometime '
#                              'adversary and former Fring lieutenant Mike, Walt '
#                              'tries to keep his world from falling apart even '
#                              'as his DEA Agent brother in law, Hank, finds '
#                              'numerous leads that could blaze a path straight '
#                              'to Walt.\xa0\n'
#                              '\n'
#                              'All bad things must come to an end.',
#                  'poster_path': '/r3z70vunihrAkjILQKWHX0G2xzO.jpg',
#                  'season_number': 5}],
#   'status': 'Ended',
#   'type': 'Scripted',
#   'vote_average': 8.3,
#   'vote_count': 2831}

# %%
import pickle

with open ('show_list', 'rb') as fp:
    show_list = pickle.load(fp)

# %%
show_list[0]
# Out:
# ['Grey%27s_Anatomy']

# %%
show_list[10:20]
# Out:
# [['Black-ish'],
#  ['Fresh_Off_the_Boat'],
#  ['Speechless_(TV_series)'],
#  ['American_Housewife'],
#  ['Splitting_Up_Together'],
#  ['Single_Parents_(TV_series)'],
#  ['America%27s_Funniest_Home_Videos'],
#  ['The_Bachelor_(U.S._TV_series)'],
#  ['The_Bachelorette'],
#  ['Dancing_with_the_Stars_(U.S._TV_series)']]

# %%
# Replace underscore with asterisks
# Drop parentheses
# Drop special characters %27

# %%
test = 'Agents*of*S.H.I.E.L.D.'

# %%
search.tv(query=test)
# Out:
# {'page': 1,
#  'total_results': 2,
#  'total_pages': 1,
#  'results': [{'original_name': "Marvel's Agents of S.H.I.E.L.D.",
#    'id': 1403,
#    'name': "Marvel's Agents of S.H.I.E.L.D.",
#    'vote_count': 1164,
#    'vote_average': 6.72,
#    'poster_path': '/xjm6uVktPuKXNILwjLXwVG5d5BU.jpg',
#    'first_air_date': '2013-09-24',
#    'popularity': 64.896,
#    'genre_ids': [18, 10765, 10759],
#    'original_language': 'en',
#    'backdrop_path': '/qtr5i6hOm6oVzTYl3jOQAYP3oc7.jpg',
#    'overview': 'Agent Phil Coulson of S.H.I.E.L.D. (Strategic Homeland Intervention, Enforcement and Logistics Division) puts together a team of agents to investigate the new, the strange and the unknown around the globe, protecting the ordinary from the extraordinary.',
#    'origin_country': ['US']},
#   {'original_name': "Marvel's Agents of S.H.I.E.L.D.: Slingshot",
#    'id': 69088,
#    'name': "Marvel's Agents of S.H.I.E.L.D.: Slingshot",
#    'vote_count': 13,
#    'vote_average': 5.62,
#    'poster_path': '/jq2Uw8o8ROqyQLOMu8oBNxRCOat.jpg',
#    'first_air_date': '2016-12-13',
#    'popularity': 2.488,
#    'genre_ids': [10765],
#    'original_language': 'en',
#    'backdrop_path': '/nCYcjoDpRoOUQW7DUUp4v0HGWN3.jpg',
#    'overview': 'Marvel’s Agents of S.H.I.E.L.D.: Slingshot is set in the world of the hit television series Marvel’s Agents of S.H.I.E.L.D. Taking place shortly before the beginning of Season 4, this digital series features the character of Elena “Yo-Yo” Rodriguez, an Inhuman with the ability to move with super-speed. As a person with powers, she must sign the recently instituted Sokovia Accords, the worldwide agreement that regulates and tracks those with super powers. However, the restrictions of the Accords are in direct conflict with a personal mission she’s desperate to fulfill, a mission that will test her abilities, her allegiances, and will include some tense encounters with our most popular S.H.I.E.L.D. team members.',
#    'origin_country': ['US']}]}

# %%
# FUCK IT'S NOT SHOWING ANY RESULTS. I may need to replace characters and underscores with asterisks
# Otherwise, I'll have to search on another API and then search this one

# %%
show_list[0]
# Out:
# ['Grey%27s_Anatomy']
