# %% [markdown]
# # Feature Engineering & EDA

# %% [markdown]
# With the data centralized, I can take a closer look to see how my features will interact with my target variable, IMDB ratings. This will be a regression problem, so I will be using Linear Regression (including Ridge and Lasso), Random Forest Regression, and Gradient Boost as my models to try and predict with, so I will have to prepare my data accordingly. I plan on categorizing and dummying the features that aren't numerical, as well as categorize numerical data that shouldn't have a greater or worse weight based on the value (i.e. time or dates).

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression, LassoCV, RidgeCV, ElasticNetCV
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.feature_extraction.text import CountVectorizer

from nltk.tokenize import word_tokenize  
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.stem import PorterStemmer
from nltk.sentiment import vader, SentimentAnalyzer

import datetime, time
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pickle
import json

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline
# Out:
# /anaconda3/lib/python3.6/site-packages/nltk/twitter/__init__.py:20: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   warnings.warn("The twython library has not been installed. "

# %%
with open('../0_Assets_&_Data/series_df_full.pickle', 'rb') as handle:
    series_df = pickle.load(handle)

# %%
series_df.columns
# Out:
# Index(['airsDayOfWeek', 'airsTime', 'network', 'overview_x', 'rating',
#        'runtime_x', 'number_of_episodes', 'number_of_seasons', 'overview_y',
#        'status_y', 'type_x', 'actors', 'awards', 'genre_y', 'imdb_id',
#        'imdb_rating', 'imdb_votes', 'plot', 'released', 'writer'],
#       dtype='object')

# %%
clean_time = series_df[['airsTime']]

# %%
pm_slot = clean_time[clean_time['airsTime'].str.contains('PM')]

pm_slot_ = clean_time[clean_time['airsTime'].str.contains('pm')]

am_slot = clean_time[clean_time['airsTime'].str.contains('AM')]

am_slot_ = clean_time[clean_time['airsTime'].str.contains('am')]

# %%
missing_time = clean_time[clean_time['airsTime'] == '']

# %%
remaining_time = clean_time[clean_time['airsTime'] != '']

remaining_time = remaining_time[~remaining_time['airsTime'].str.contains('PM')]

remaining_time = remaining_time[~remaining_time['airsTime'].str.contains('pm')]

remaining_time = remaining_time[~remaining_time['airsTime'].str.contains('AM')]

remaining_time = remaining_time[~remaining_time['airsTime'].str.contains('am')]

# %%
for i in reversed(range(1, 25)):
    if i >= 22:
        remaining_time[remaining_time['airsTime'].str.contains(str(i))] = 'latenight'
    elif i >= 18:
        remaining_time[remaining_time['airsTime'].str.contains(str(i))] = 'evening'
    elif i >= 12:
        remaining_time[remaining_time['airsTime'].str.contains(str(i))] = 'afternoon'
    elif i >=5:
        remaining_time[remaining_time['airsTime'].str.contains(str(i))] = 'morning'
    else: 
        remaining_time[remaining_time['airsTime'].str.contains(str(i))] = 'latenight'

# %%
remaining_time
# Out:
#                                            airsTime
# Veep                                      latenight
# Crashing                                  latenight
# Animals.                                  latenight
# Wyatt Cenac's Problem Areas               latenight
# HBO                                         morning
# Tales from the Crypt                      latenight
# Crashbox                                  afternoon
# Any Given Wednesday with Bill Simmons     latenight
# Vinyl                                       evening
# Elizabeth I                                 evening
# House of Saddam                             evening
# Olive Kitteridge                            evening
# Parade's End                                evening
# Tanner '88                                  evening
# New Amsterdam                               evening
# The Voice                                   evening
# Today                                       morning
# Sunday Night with Megyn Kelly               evening
# NHL Winter Classic                        latenight
# Premier League                            latenight
# McMafia                                     evening
# James Cameron's Story of Science Fiction  latenight
# The Prisoner                              latenight
# The Making of the Mob                     latenight
# Cybill                                      evening
# Daniel Boone                                evening
# Aqua Teen Hunger Force                    latenight
# Delocated                                   morning
# Titan Maximum                               morning
# Brad Neely's Harg Nallin' Sclopio Peepio  latenight
# ...                                             ...
# Wagon Train                                 evening
# 101 Ways to Leave a Game Show               evening
# The Thorn Birds                             evening
# North and South                             evening
# When We Rise                                evening
# Top Cat                                     evening
# The Mole                                  latenight
# Extreme Makeover: Home Edition              evening
# Flash Forward                               evening
# Hong Kong Phooey                            morning
# Ocean Mysteries with Jeff Corwin            evening
# Phil of the Future                          evening
# Sonic the Hedgehog                          morning
# The Emperor's New School                  afternoon
# The Lost Saucer                             morning
# The New Adventures of Winnie the Pooh       morning
# Turbo Teen                                latenight
# Just the Ten of Us                          evening
# Less than Perfect                           evening
# Life with Lucy                              evening
# Manhattan Love Story                      latenight
# The Geena Davis Show                        evening
# The Jackie Thomas Show                      evening
# The Nancy Walker Show                       evening
# The New Odd Couple                          morning
# The Real O'Neals                            evening
# The Second Hundred Years                    evening
# What About Joan?                            evening
# When Things Were Rotten                     evening
# The Hollywood Palace                        evening
#
# [196 rows x 1 columns]

# %%
# Categorizing PM slots
for i in range(1, 13):
    if i < 6:
        pm_slot[pm_slot['airsTime'].str.contains(str(i))] = 'afternoon'
        pm_slot_[pm_slot_['airsTime'].str.contains(str(i))] = 'afternoon'
    elif i >= 6 & i < 10:
        pm_slot[pm_slot['airsTime'].str.contains(str(i))] = 'evening'
        pm_slot_[pm_slot_['airsTime'].str.contains(str(i))] = 'evening'
    else: 
        pm_slot[pm_slot['airsTime'].str.contains(str(i))] = 'latenight'
        pm_slot_[pm_slot_['airsTime'].str.contains(str(i))] = 'latenight'

#pm_slot[pm_slot['airsTime'].str.contains('8', '9')]

# %%
# Categorizing PM slots
for i in range(1, 13):
    if i < 5:
        am_slot[am_slot['airsTime'].str.contains(str(i))] = 'latenight'
        am_slot_[am_slot_['airsTime'].str.contains(str(i))] = 'latenight'
    else: 
        am_slot[am_slot['airsTime'].str.contains(str(i))] = 'morning'
        am_slot_[am_slot_['airsTime'].str.contains(str(i))] = 'morning'

#pm_slot[pm_slot['airsTime'].str.contains('8', '9')]

# %%
missing_time['airsTime'] = 'unknown'

# %%
timeslot = pd.concat((am_slot, am_slot_, pm_slot, pm_slot_, remaining_time, missing_time))

# %%
plot_df = pd.merge(series_df, timeslot, left_index=True, right_index=True)

# %%
series_df['released'] = pd.to_datetime(series_df['released'])

# %%
week_day = series_df[['released']]

# %%
week_day['weekday'] = week_day['released'].dt.dayofweek

# %%
week_day['month'] = week_day['released'].dt.month

# %%
plot_df['month'] = week_day['month']
plot_df['weekday'] = week_day['weekday']

# %% [markdown]
# # Categorizing runtime
#
# I will be categorizing this data as well. Although the runtimes that I've gathered have a lot of different values, in reality/practice, tv shows are usually in 30 minute and 1 hour increments (longer than 1 hour would generally be specials or movies). For this reason, I chose relatively arbitrary runtimes to group group the shows by.

# %%
series_df = series_df[(series_df[['runtime_x']] != ('')).all(axis=1)]

# %%
series_df[['runtime_x']] = series_df[['runtime_x']].astype(int)

# %%
series_df['runtime_x'].value_counts()
# Out:
# 30     692
# 60     425
# 45     315
# 25     241
# 15      35
# 20      33
# 50      24
# 11      23
# 55      16
# 10      16
# 120     13
# 40      13
# 85      10
# 1        9
# 90       8
# 12       8
# 35       4
# 13       4
# 65       3
# 70       3
# 180      2
# 80       2
# 7        2
# 75       1
# 95       1
# 125      1
# 140      1
# 6        1
# 3        1
# 240      1
# Name: runtime_x, dtype: int64

# %%
series_df['runtime_x'].head(10)
# Out:
# Game of Thrones         55
# Westworld               60
# Big Little Lies         50
# The Deuce               60
# Succession              60
# Curb Your Enthusiasm    30
# Veep                    30
# Silicon Valley          30
# Ballers                 30
# High Maintenance        10
# Name: runtime_x, dtype: int64

# %%
series_df['runtime_cat'] = np.where(series_df['runtime_x'] < 30, 'half', 'full')

# %%
series_df['runtime_cat'].loc[series_df.runtime_x < 30] = 'half'
series_df['runtime_cat'].loc[series_df.runtime_x > 70] = 'special'

# %%
series_df['runtime_cat'].value_counts()
# Out:
# full       1495
# half        373
# special      40
# Name: runtime_cat, dtype: int64

# %%
series_df['runtime_cat'].head(10)
# Out:
# Game of Thrones         full
# Westworld               full
# Big Little Lies         full
# The Deuce               full
# Succession              full
# Curb Your Enthusiasm    full
# Veep                    full
# Silicon Valley          full
# Ballers                 full
# High Maintenance        half
# Name: runtime_cat, dtype: object

# %%
series_df.head(3)
# Out:
#                 airsDayOfWeek airsTime network  \
# Game of Thrones        Sunday  9:00 PM     HBO
# Westworld              Sunday  9:00 PM     HBO
# Big Little Lies        Sunday  9:00 PM     HBO
#
#                                                         overview_x rating  \
# Game of Thrones  Seven noble families fight for control of the ...  TV-MA
# Westworld        Westworld is a dark odyssey about the dawn of ...  TV-MA
# Big Little Lies  Subversive, darkly comedic drama Big Little Li...  TV-MA
#
#                  runtime_x  number_of_episodes  number_of_seasons  \
# Game of Thrones         55                73.0                  8
# Westworld               60                20.0                  2
# Big Little Lies         50                 7.0                  2
#
#                                                         overview_y  \
# Game of Thrones  Seven noble families fight for control of the ...
# Westworld        A dark odyssey about the dawn of artificial co...
# Big Little Lies  Subversive, darkly comedic drama Big Little Li...
#
#                          status_y     ...      \
# Game of Thrones  Returning Series     ...
# Westworld        Returning Series     ...
# Big Little Lies  Returning Series     ...
#
#                                                             actors awards  \
# Game of Thrones  Peter Dinklage, Lena Headey, Emilia Clarke, Ki...      1
# Westworld        Evan Rachel Wood, Thandie Newton, Jeffrey Wrig...      1
# Big Little Lies  Reese Witherspoon, Nicole Kidman, Shailene Woo...      1
#
#                                                     genre_y    imdb_id  \
# Game of Thrones  Action, Adventure, Drama, Fantasy, Romance  tt0944947
# Westworld                            Drama, Mystery, Sci-Fi  tt0475784
# Big Little Lies                       Crime, Drama, Mystery  tt3920596
#
#                 imdb_rating imdb_votes  \
# Game of Thrones         9.5  1,361,235
# Westworld               8.9    307,642
# Big Little Lies         8.6     86,060
#
#                                                               plot   released  \
# Game of Thrones  In the mythical continent of Westeros, several... 2011-04-17
# Westworld        Westworld isn't your typical amusement park. I... 2016-10-02
# Big Little Lies  While Madeline and Celeste take new in town si... 2017-02-19
#
#                                     writer runtime_cat
# Game of Thrones  David Benioff, D.B. Weiss        full
# Westworld                                0        full
# Big Little Lies            David E. Kelley        full
#
# [3 rows x 21 columns]

# %% [markdown]
# # Separate genre_y values into additional columns

# %%
df = pd.Series(series_df['genre_y'].str.split(','))

# %%
genre_dummies = pd.get_dummies(df.apply(pd.Series).stack()).sum(level=0)

# %% [markdown]
# # Dummies

# %%
status_dummies = pd.get_dummies(series_df['status_y'], prefix='status')

# %%
type_dummies = pd.get_dummies(series_df['type_x'], prefix='type')

# %%
timeslot_dum = pd.get_dummies(timeslot, prefix='timeslot')

# %%
week_day_ = week_day.drop('released', axis=1)
week_day_dum1 = pd.get_dummies(week_day_['weekday'], prefix='day')
week_day_dum2 = pd.get_dummies(week_day_['month'], prefix='month')

# %% [markdown]
# # Combining all the dataframes

# %% [markdown]
# ### To drop:
# - airsDayOfWeek
# - airsTime
# - network
# - overview_x
# - runtime_x
# - overview_y
# - actors (dummy)
# - genre_y (dummy)
# - imdb_id
# - imdb_rating
# - plot
# - released
# - writer (dummy)

# %%
series_df.head(1)
# Out:
#                 airsDayOfWeek airsTime network  \
# Game of Thrones        Sunday  9:00 PM     HBO
#
#                                                         overview_x rating  \
# Game of Thrones  Seven noble families fight for control of the ...  TV-MA
#
#                  runtime_x  number_of_episodes  number_of_seasons  \
# Game of Thrones         55                73.0                  8
#
#                                                         overview_y  \
# Game of Thrones  Seven noble families fight for control of the ...
#
#                          status_y     ...      \
# Game of Thrones  Returning Series     ...
#
#                                                             actors awards  \
# Game of Thrones  Peter Dinklage, Lena Headey, Emilia Clarke, Ki...      1
#
#                                                     genre_y    imdb_id  \
# Game of Thrones  Action, Adventure, Drama, Fantasy, Romance  tt0944947
#
#                 imdb_rating imdb_votes  \
# Game of Thrones         9.5  1,361,235
#
#                                                               plot   released  \
# Game of Thrones  In the mythical continent of Westeros, several... 2011-04-17
#
#                                     writer runtime_cat
# Game of Thrones  David Benioff, D.B. Weiss        full
#
# [1 rows x 21 columns]

# %%
timeslot_dum.head(1)
# Out:
#                         timeslot_00:00  timeslot_afternoon  timeslot_evening  \
# Random Acts of Flyness               0                   0                 0
#
#                         timeslot_latenight  timeslot_morning  timeslot_unknown
# Random Acts of Flyness                   1                 0                 0

# %%
week_day_dum1.head(1)
# Out:
#                  day_0  day_1  day_2  day_3  day_4  day_5  day_6
# Game of Thrones      0      0      0      0      0      0      1

# %%
week_day_dum2.head(1)
# Out:
#                  month_1  month_2  month_3  month_4  month_5  month_6  \
# Game of Thrones        0        0        0        1        0        0
#
#                  month_7  month_8  month_9  month_10  month_11  month_12
# Game of Thrones        0        0        0         0         0         0

# %%
series_df['runtime_cat'].head(1)
# Out:
# Game of Thrones    full
# Name: runtime_cat, dtype: object

# %%
genre_dummies.head(1)
# Out:
#                   Action   Adventure   Animation   Comedy   Crime   Drama  \
# Game of Thrones        0           1           0        0       0       1
#
#                   Family   Fantasy   Game-Show   History   ...     Horror  \
# Game of Thrones        0         1           0         0   ...          0
#
#                  Music  Mystery  News  Reality-TV  Romance  Sci-Fi  Sport  \
# Game of Thrones      0        0     0           0        0       0      0
#
#                  Talk-Show  Western
# Game of Thrones          0        0
#
# [1 rows x 46 columns]

# %%
series_df = series_df.merge(timeslot_dum, left_index=True, right_index=True)

# %%
series_df = series_df.merge(week_day_dum1, left_index=True, right_index=True)
series_df = series_df.merge(week_day_dum2, left_index=True, right_index=True)
series_df = series_df.merge(genre_dummies, left_index=True, right_index=True)

# %%
model_df = series_df.drop(['network', 
                           'imdb_id', 
#                           'released', 
#                           'airsDayOfWeek', 
#                           'airsTime', 
#                           'overview_x', 
                           'overview_y', 
                           'plot', 
                           'genre_y', 
                           'status_y', 
                           'type_x', 
                           'runtime_x', 
                           'runtime_cat'], 
                          axis=1)

# %%
model_df.drop(['actors', 'writer'], axis=1, inplace=True)

# %%
series_df['imdb_votes'] = series_df['imdb_votes'].str.replace(',', '').astype(float)

# %%
model_df[['awards']] = model_df[['awards']].astype(float)

# %%
model_df[['imdb_rating']] = model_df[['imdb_rating']].astype(float)

# %%
model_df.drop('rating', axis=1, inplace=True)

# %% [markdown]
# # Final cleanup steps

# %% [markdown]
# Now that the data is useable in the proper format, I can see how the chosen features predicts on IMDB rating without additional feature engineering so far.

# %%
type(model_df['imdb_votes'][0])
# Out:
# str

# %%
model_df['imdb_votes'] = model_df['imdb_votes'].str.replace(',', '').astype(float)

# %%
series_df[['runtime_x', 'awards']] = series_df[['runtime_x', 'awards']].astype(float)

# %%
series_df.isnull().sum()
# Out:
# airsDayOfWeek          0
# airsTime               0
# network                0
# overview_x            79
# rating                 0
# runtime_x              0
# number_of_episodes     1
# number_of_seasons      0
# overview_y             0
# status_y               0
# type_x                 0
# actors                 0
# awards                 0
# genre_y                0
# imdb_id                0
# imdb_rating            0
# imdb_votes             0
# plot                   0
# released               0
# writer                 0
# runtime_cat            0
# timeslot_00:00         0
# timeslot_afternoon     0
# timeslot_evening       0
# timeslot_latenight     0
# timeslot_morning       0
# timeslot_unknown       0
# day_0                  0
# day_1                  0
# day_2                  0
#                       ..
#  Romance               0
#  Sci-Fi                0
#  Short                 0
#  Sport                 0
#  Talk-Show             0
#  Thriller              0
#  War                   0
#  Western               0
# Action                 0
# Adventure              0
# Animation              0
# Biography              0
# Comedy                 0
# Crime                  0
# Documentary            0
# Drama                  0
# Family                 0
# Fantasy                0
# Game-Show              0
# History                0
# Horror                 0
# Music                  0
# Mystery                0
# News                   0
# Reality-TV             0
# Romance                0
# Sci-Fi                 0
# Sport                  0
# Talk-Show              0
# Western                0
# Length: 92, dtype: int64

# %%
series_df['runtime_x'].value_counts()
# Out:
# 30.0     685
# 60.0     416
# 45.0     315
# 25.0     241
# 15.0      35
# 20.0      32
# 50.0      24
# 11.0      23
# 55.0      16
# 10.0      16
# 40.0      13
# 120.0     13
# 85.0      10
# 1.0        9
# 12.0       8
# 90.0       8
# 35.0       4
# 13.0       4
# 70.0       3
# 65.0       2
# 180.0      2
# 7.0        2
# 80.0       2
# 140.0      1
# 240.0      1
# 3.0        1
# 6.0        1
# 95.0       1
# 125.0      1
# 75.0       1
# Name: runtime_x, dtype: int64

# %%
model_df.dropna(inplace=True)

# %%
model_df.head()
# Out:
#                 airsDayOfWeek  airsTime  \
# Game of Thrones        Sunday   9:00 PM
# Westworld              Sunday   9:00 PM
# Big Little Lies        Sunday   9:00 PM
# The Deuce              Sunday   9:00 PM
# Succession             Sunday  10:00 PM
#
#                                                         overview_x  \
# Game of Thrones  Seven noble families fight for control of the ...
# Westworld        Westworld is a dark odyssey about the dawn of ...
# Big Little Lies  Subversive, darkly comedic drama Big Little Li...
# The Deuce        This drama series follows the legalization and...
# Succession       A drama about a dysfunctional media family dyn...
#
#                  number_of_episodes  number_of_seasons  awards  imdb_rating  \
# Game of Thrones                73.0                  8     1.0          9.5
# Westworld                      20.0                  2     1.0          8.9
# Big Little Lies                 7.0                  2     1.0          8.6
# The Deuce                      16.0                  2     1.0          8.1
# Succession                     10.0                  1     0.0          7.6
#
#                  imdb_votes   released  timeslot_00:00   ...     Horror  \
# Game of Thrones   1361235.0 2011-04-17               0   ...          0
# Westworld          307642.0 2016-10-02               0   ...          0
# Big Little Lies     86060.0 2017-02-19               0   ...          0
# The Deuce           14113.0 2017-08-25               0   ...          0
# Succession           3927.0 2018-06-03               0   ...          0
#
#                  Music  Mystery  News  Reality-TV  Romance  Sci-Fi  Sport  \
# Game of Thrones      0        0     0           0        0       0      0
# Westworld            0        0     0           0        0       0      0
# Big Little Lies      0        0     0           0        0       0      0
# The Deuce            0        0     0           0        0       0      0
# Succession           0        0     0           0        0       0      0
#
#                  Talk-Show  Western
# Game of Thrones          0        0
# Westworld                0        0
# Big Little Lies          0        0
# The Deuce                0        0
# Succession               0        0
#
# [5 rows x 80 columns]

# %% [markdown]
# # Plotting

# %%
plot_df.columns
# Out:
# Index(['airsDayOfWeek', 'airsTime_x', 'network', 'overview_x', 'rating',
#        'runtime_x', 'number_of_episodes', 'number_of_seasons', 'overview_y',
#        'status_y', 'type_x', 'actors', 'awards', 'genre_y', 'imdb_id',
#        'imdb_rating', 'imdb_votes', 'plot', 'released', 'writer', 'airsTime_y',
#        'month', 'weekday'],
#       dtype='object')

# %%
plt.figure(figsize=(17,8))
plt.bar(model_df['awards'], model_df['imdb_votes'])
# Out:
# <BarContainer object of 1890 artists>

# %%
plt.figure(figsize=(17,8))
plt.scatter(model_df['number_of_seasons'], model_df['imdb_votes'])
plt.xlabel('Number of Seasons')
plt.ylabel('Number of IMDB Votes')
plt.title('IMDB Votes vs. Number of Seasons');

# %%
plt.figure(figsize=(17,8))
plt.scatter(model_df['number_of_seasons'], model_df['imdb_rating'])
plt.xlabel('Number of Seasons')
plt.ylabel('Number of IMDB Rating')
plt.title('IMDB Rating vs. Number of Seasons');

# %%
plt.figure(figsize=(17,8))
plt.scatter(model_df['number_of_episodes'], model_df['imdb_votes'])
plt.xlabel('Number of Episodes')
plt.ylabel('Number of IMDB Votes')
plt.title('IMDB Votes vs. Number of Episodes');

# %%
plt.figure(figsize=(17,8))
plt.scatter(model_df['number_of_episodes'], model_df['imdb_rating'])
plt.xlabel('Number of Episodes')
plt.ylabel('Number of IMDB Rating')
plt.title('IMDB Rating vs. Number of Episodes');

# %%
plt.figure(figsize=(17,8))
plt.scatter(model_df['imdb_rating'], model_df['imdb_votes'])
plt.xlabel('IMDB Rating')
plt.ylabel('Number of IMDB Votes')
plt.title('IMDB Rating vs. Votes');

# %%
plt.figure(figsize=(17,8))
ax = sns.distplot(model_df['imdb_rating'], bins=20, kde_kws={"bw": 0.25}, 
                  axlabel='Movie Ratings (0-10 scale)')
ax.set(xlim=(0, 10))
ax.set_title("Distribution of IMDB TV Ratings")
# Out:
# Text(0.5,1,'Distribution of IMDB TV Ratings')

# %%
tv_ratings = model_df[['imdb_rating', 'imdb_votes', 'airsTime', 
                            'airsDayOfWeek']]
tv_ratings = tv_ratings.merge(week_day_, left_index=True, right_index=True)

tv_ratings = tv_ratings.dropna()

# %%
sns.pairplot(tv_ratings)

# %%
sns.jointplot(x='imdb_rating', y='imdb_votes', data=tv_ratings, kind='reg', size=9)
plt.xlabel('IMDB Rating')
plt.ylabel("IMDB Votes")
plt.title('IMDB Ratings vs. Votes')
# Out:
# Text(0.5,1,'IMDB Ratings vs. Votes')

# %%
tv_ratings.sort_values('imdb_votes', ascending=False).head(15)
# Out:
#                        imdb_rating  imdb_votes  airsTime airsDayOfWeek  \
# Game of Thrones                9.5   1361235.0   9:00 PM        Sunday
# Breaking Bad                   9.5   1116726.0   9:00 PM        Sunday
# The Walking Dead               8.4    752951.0   9:00 PM        Sunday
# The Big Bang Theory            8.2    612766.0   8:00 PM      Thursday
# How I Met Your Mother          8.3    519151.0   8:00 PM        Monday
# Lost                           8.4    436190.0   9:00 PM       Tuesday
# Prison Break                   8.4    414538.0   9:00 PM       Tuesday
# True Detective                 9.0    406538.0  10:00 PM        Sunday
# Arrow                          7.7    363370.0   8:00 PM        Monday
# House                          8.8    359726.0
# Supernatural                   8.5    335284.0   8:00 PM      Thursday
# The Simpsons                   8.7    315953.0   8:00 PM        Sunday
# Westworld                      8.9    307642.0   9:00 PM        Sunday
# Family                         8.5    296449.0   9:00 PM        Monday
# Modern Family                  8.5    296449.0   9:00 PM     Wednesday
#
#                        weekday  month
# Game of Thrones              6      4
# Breaking Bad                 6      1
# The Walking Dead             6     10
# The Big Bang Theory          0      5
# How I Met Your Mother        0      9
# Lost                         2      9
# Prison Break                 0      8
# True Detective               6      1
# Arrow                        2     10
# House                        1     11
# Supernatural                 1      9
# The Simpsons                 6     12
# Westworld                    6     10
# Family                       1      9
# Modern Family                1      9

# %%
tv_ratings_adj = tv_ratings[tv_ratings['imdb_votes'] >= 1000]
tv_ratings_adj = tv_ratings[tv_ratings['imdb_votes'] <= 1000000]

# %%
sns.jointplot(x='imdb_rating', y='imdb_votes', data=tv_ratings_adj, kind='reg', size=9)
plt.xlabel('IMDB Rating')
plt.ylabel("IMDB Votes")
plt.title('IMDB Ratings vs. Votes')
# Out:
# Text(0.5,1,'IMDB Ratings vs. Votes')

# %%
genre_array = [genre_list.split(",") for genre_list in series_df['genre_y']]
unique_genres = {genre.strip() for genres in genre_array for genre in genres}
unique_genres.discard('')

# %%
for genre in sorted(unique_genres):
    model_df[genre] = np.zeros(len(model_df), dtype=int)

# %%
for idx, row in series_df.iterrows():
    for genre in row['genre_y'].split(", "):
        if genre != '':
            model_df.ix[idx, genre] = 1

# %%
genre_counts = pd.Series(index=unique_genres, dtype=int)

for genre in unique_genres:
    genre_counts[genre] = len(model_df[model_df[genre] == 1])

genre_counts.sort_values(ascending=False, inplace=True)

# %%
plt.figure(figsize=(17,8))
sns.barplot(x="Genre", y="Median_rating", data=genre_rating)
plt.title("Median rating per Genre")
plt.ylabel("Median rating")
plt.xticks(rotation="vertical");

# %%
genre_counts.plot.bar(figsize=(17, 10), title="Number of tv shows by genre")

# %%
unique_genres = list(unique_genres)

# %%
genre_df = pd.DataFrame(model_df[unique_genres].sum()).reset_index()

# %%
genre_df.columns = ["Genre", "Count"]

# %%
genre_df.head()
genre_df.sort_values(by="Count", ascending=False, inplace=True)

# %%
plt.figure(figsize=(17,8))
sns.barplot(x="Genre", y="Count", data=genre_df)
plt.title("Number of Ratings per Genre")
plt.ylabel("Rating")
plt.xticks(rotation="vertical");

# %%
genre_rating = []
for i in unique_genres:
    genre_rating.append([i, model_df["imdb_rating"][model_df[i]==1].median()])

genre_rating = pd.DataFrame(genre_rating, columns=["Genre", "Median_rating"])

plt.figure(figsize=(17,8))
sns.barplot(x="Genre", y="Median_rating", data=genre_rating)
plt.title("Median rating per Genre")
plt.ylabel("Median rating")
plt.xticks(rotation="vertical");

# %%
import sklearn.preprocessing as preprocessing

genre_scaler = preprocessing.MinMaxScaler()
genre_rating["Scaled_rating"] = genre_scaler.fit_transform(genre_rating["Median_rating"].values.reshape(-1,1))

plt.figure(figsize=(17,8))
sns.barplot(x="Genre", y="Scaled_rating", data=genre_rating)
plt.title("Scaled median rating per Genre")
plt.ylabel("Scaled median rating")
plt.xticks(rotation="vertical");

# %%
model_df.columns
# Out:
# Index(['airsDayOfWeek', 'airsTime', 'overview_x', 'number_of_episodes',
#        'number_of_seasons', 'awards', 'imdb_rating', 'imdb_votes', 'released',
#        'timeslot_00:00', 'timeslot_afternoon', 'timeslot_evening',
#        'timeslot_latenight', 'timeslot_morning', 'timeslot_unknown', 'day_0',
#        'day_1', 'day_2', 'day_3', 'day_4', 'day_5', 'day_6', 'month_1',
#        'month_2', 'month_3', 'month_4', 'month_5', 'month_6', 'month_7',
#        'month_8', 'month_9', 'month_10', 'month_11', 'month_12', ' Action',
#        ' Adventure', ' Animation', ' Comedy', ' Crime', ' Drama', ' Family',
#        ' Fantasy', ' Game-Show', ' History', ' Horror', ' Music', ' Musical',
#        ' Mystery', ' News', ' Reality-TV', ' Romance', ' Sci-Fi', ' Short',
#        ' Sport', ' Talk-Show', ' Thriller', ' War', ' Western', 'Action',
#        'Adventure', 'Animation', 'Biography', 'Comedy', 'Crime', 'Documentary',
#        'Drama', 'Family', 'Fantasy', 'Game-Show', 'History', 'Horror', 'Music',
#        'Mystery', 'News', 'Reality-TV', 'Romance', 'Sci-Fi', 'Sport',
#        'Talk-Show', 'Western', 'Musical', 'Short', 'Thriller', 'War'],
#       dtype='object')

# %%
model_df.corr()
# Out:
#                     number_of_episodes  number_of_seasons    awards  \
# number_of_episodes            1.000000           0.596127  0.108906
# number_of_seasons             0.596127           1.000000  0.267985
# awards                        0.108906           0.267985  1.000000
# imdb_rating                  -0.041578           0.045578  0.224792
# imdb_votes                    0.023587           0.175112  0.197164
# timeslot_00:00               -0.007607          -0.020950  0.006836
# timeslot_afternoon            0.013997           0.007490  0.040137
# timeslot_evening             -0.028513           0.036877  0.122356
# timeslot_latenight            0.014867           0.008857 -0.080712
# timeslot_morning              0.133404           0.073892 -0.056592
# timeslot_unknown             -0.042483          -0.071350 -0.084212
# day_0                         0.141708           0.078515  0.028615
# day_1                        -0.016271           0.011384  0.015338
# day_2                        -0.032273          -0.031997 -0.010067
# day_3                        -0.010340           0.021783 -0.034523
# day_4                        -0.026345          -0.032514  0.028041
# day_5                        -0.029620          -0.050197 -0.103233
# day_6                        -0.025945           0.000180  0.077257
# month_1                       0.049690           0.043275  0.025185
# month_2                      -0.019764          -0.033544 -0.040322
# month_3                      -0.015114           0.003968 -0.014026
# month_4                      -0.016354          -0.038233 -0.005061
# month_5                      -0.018549          -0.012861 -0.042723
# month_6                      -0.018154          -0.026196 -0.027197
# month_7                       0.034419           0.025587 -0.057154
# month_8                       0.030962           0.032811 -0.011728
# month_9                      -0.026017          -0.045832  0.027983
# month_10                     -0.003760           0.021398  0.047416
# month_11                      0.008392           0.039558  0.013501
# month_12                     -0.008745           0.014194  0.028624
# ...                                ...                ...       ...
#  Romance                      0.053962           0.079449  0.107830
#  Sci-Fi                      -0.036444          -0.075473  0.023623
#  Short                       -0.005180           0.019277  0.034391
#  Sport                       -0.006973           0.019767  0.032248
#  Talk-Show                    0.246686           0.160186  0.009498
#  Thriller                    -0.017224          -0.020776  0.029419
#  War                         -0.005075          -0.005210  0.017545
#  Western                     -0.004580          -0.010319  0.041329
# Action                       -0.015251          -0.005157  0.097824
# Adventure                    -0.021170          -0.035939  0.012383
# Animation                    -0.026953          -0.038291 -0.137883
# Biography                    -0.012060          -0.023054  0.043730
# Comedy                       -0.022666          -0.020857  0.036860
# Crime                        -0.007062          -0.008920  0.044632
# Documentary                   0.009286           0.069076 -0.011154
# Drama                        -0.003924          -0.034401  0.113980
# Family                        0.017686           0.020222  0.004220
# Fantasy                      -0.005572          -0.018154  0.001711
# Game-Show                     0.013241           0.104069 -0.066798
# History                      -0.005921          -0.017101 -0.005667
# Horror                       -0.011195          -0.031183  0.008311
# Music                         0.000300           0.019151  0.029176
# Mystery                      -0.006286          -0.009457 -0.020720
# News                          0.304652           0.274688  0.024082
# Reality-TV                   -0.021667          -0.030718 -0.141855
# Romance                      -0.003664          -0.010065  0.028072
# Sci-Fi                       -0.003779           0.012725 -0.041543
# Sport                        -0.009114          -0.017452 -0.068328
# Talk-Show                     0.074843           0.024462  0.008311
# Western                      -0.006269          -0.000824 -0.007854
#
#                     imdb_rating  imdb_votes  timeslot_00:00  \
# number_of_episodes    -0.041578    0.023587       -0.007607
# number_of_seasons      0.045578    0.175112       -0.020950
# awards                 0.224792    0.197164        0.006836
# imdb_rating            1.000000    0.254105       -0.006957
# imdb_votes             0.254105    1.000000       -0.009859
# timeslot_00:00        -0.006957   -0.009859        1.000000
# timeslot_afternoon     0.027690   -0.015063       -0.022259
# timeslot_evening       0.010081    0.170792       -0.025695
# timeslot_latenight    -0.029016   -0.043685       -0.011752
# timeslot_morning      -0.059660   -0.042325       -0.007545
# timeslot_unknown       0.005149   -0.105632       -0.031496
# day_0                 -0.051145    0.008824        0.022846
# day_1                 -0.030411    0.003610       -0.016838
# day_2                 -0.062243   -0.025411       -0.016838
# day_3                  0.001597   -0.026532       -0.016949
# day_4                  0.015659   -0.021767        0.031999
# day_5                 -0.019496   -0.087678       -0.017209
# day_6                  0.138438    0.137951        0.017527
# month_1               -0.024025   -0.000787       -0.017761
# month_2                0.012832   -0.030331       -0.009643
# month_3               -0.036918   -0.016606       -0.012159
# month_4                0.004214    0.020553        0.047075
# month_5               -0.042657    0.005818       -0.007008
# month_6                0.007332   -0.017377       -0.010415
# month_7               -0.017139   -0.018777       -0.009375
# month_8               -0.021946    0.011268       -0.009483
# month_9                0.058887    0.005516       -0.026464
# month_10               0.020276    0.028702       -0.013076
# month_11              -0.015207   -0.000611        0.060683
# month_12              -0.005307    0.005450        0.082828
# ...                         ...         ...             ...
#  Romance              -0.039164    0.123941       -0.009749
#  Sci-Fi                0.059631    0.044850        0.037806
#  Short                 0.006487   -0.009769       -0.001660
#  Sport                 0.019776   -0.013579       -0.004520
#  Talk-Show            -0.059660   -0.025507       -0.006432
#  Thriller              0.043697    0.092823       -0.007145
#  War                   0.066638   -0.005011       -0.003037
#  Western               0.037509   -0.013907       -0.003329
# Action                 0.063478    0.109276       -0.012204
# Adventure              0.064529    0.022770       -0.008472
# Animation              0.004275   -0.063369       -0.020162
# Biography              0.027510   -0.011359       -0.002880
# Comedy                -0.006887   -0.033603        0.028593
# Crime                  0.111796    0.106952        0.048302
# Documentary            0.042382   -0.035092       -0.006797
# Drama                  0.065131    0.055825       -0.015235
# Family                 0.001977   -0.029959       -0.005290
# Fantasy                0.016272   -0.002123       -0.002145
# Game-Show             -0.154336   -0.034624       -0.006506
# History                0.025246   -0.008280       -0.001355
# Horror                 0.019058   -0.015763       -0.003186
# Music                 -0.027144   -0.013784       -0.002350
# Mystery               -0.009401   -0.009629       -0.001660
# News                  -0.083797   -0.024346       -0.003967
# Reality-TV            -0.239161   -0.051700       -0.008530
# Romance                0.002801   -0.008078       -0.001355
# Sci-Fi                -0.018236   -0.015593       -0.003329
# Sport                 -0.015901   -0.014262       -0.002350
# Talk-Show             -0.109511   -0.018532       -0.003186
# Western                0.052788   -0.020190       -0.003466
#
#                     timeslot_afternoon  timeslot_evening  timeslot_latenight  \
# number_of_episodes            0.013997         -0.028513            0.014867
# number_of_seasons             0.007490          0.036877            0.008857
# awards                        0.040137          0.122356           -0.080712
# imdb_rating                   0.027690          0.010081           -0.029016
# imdb_votes                   -0.015063          0.170792           -0.043685
# timeslot_00:00               -0.022259         -0.025695           -0.011752
# timeslot_afternoon            1.000000         -0.344496           -0.157556
# timeslot_evening             -0.344496          1.000000           -0.181881
# timeslot_latenight           -0.157556         -0.181881            1.000000
# timeslot_morning             -0.101151         -0.116768           -0.053404
# timeslot_unknown             -0.422274         -0.487470           -0.222945
# day_0                         0.000310          0.008130            0.021862
# day_1                        -0.006236          0.072451           -0.013368
# day_2                         0.038409          0.096736           -0.078033
# day_3                         0.024567          0.020823           -0.008803
# day_4                         0.047771         -0.012022           -0.005188
# day_5                        -0.135467         -0.184354            0.080805
# day_6                         0.037475         -0.000664            0.001065
# month_1                      -0.019438          0.022634            0.021560
# month_2                       0.005484          0.025599           -0.021965
# month_3                       0.028680         -0.009431           -0.055777
# month_4                       0.078600         -0.019279            0.006185
# month_5                       0.023966          0.045481           -0.012339
# month_6                       0.073825          0.027647           -0.030479
# month_7                       0.030559          0.023019            0.028597
# month_8                      -0.020072         -0.008105            0.036259
# month_9                      -0.093202         -0.047696           -0.019256
# month_10                      0.009740         -0.008778           -0.014109
# month_11                      0.001482         -0.017245            0.046342
# month_12                     -0.033481          0.022234            0.064006
# ...                                ...               ...                 ...
#  Romance                      0.049186          0.098025           -0.069005
#  Sci-Fi                      -0.094302          0.047028            0.066960
#  Short                        0.010023         -0.025695           -0.011752
#  Sport                       -0.000675         -0.025252            0.043752
#  Talk-Show                    0.058726         -0.067737            0.089204
#  Thriller                     0.004546          0.033363           -0.013989
#  War                         -0.005285          0.035595           -0.021497
#  Western                     -0.012266          0.039014           -0.023562
# Action                       -0.072838          0.087343           -0.033538
# Adventure                    -0.080633          0.040921           -0.007909
# Animation                    -0.095214         -0.262752            0.175711
# Biography                    -0.019948          0.042463           -0.020388
# Comedy                        0.179378         -0.079651           -0.051047
# Crime                         0.000549          0.081078           -0.062295
# Documentary                   0.062612         -0.007107            0.003030
# Drama                        -0.000093          0.130030           -0.063561
# Family                       -0.060634          0.014042            0.060070
# Fantasy                       0.021287         -0.009861           -0.015180
# Game-Show                    -0.061925          0.143100           -0.046052
# History                       0.021357          0.015883           -0.009593
# Horror                        0.007972         -0.002046            0.004145
# Music                        -0.031505          0.027541           -0.016633
# Mystery                       0.010023          0.034510           -0.011752
# News                          0.001264         -0.048710            0.057962
# Reality-TV                   -0.016155          0.124400           -0.018999
# Romance                      -0.018169          0.052741           -0.009593
# Sci-Fi                       -0.012266         -0.006252            0.002006
# Sport                        -0.031505          0.006238            0.055564
# Talk-Show                     0.075557         -0.017801            0.004145
# Western                      -0.030913         -0.010135           -0.024531
#
#                     timeslot_morning    ...       Horror     Music   Mystery  \
# number_of_episodes          0.133404    ...    -0.011195  0.000300 -0.006286
# number_of_seasons           0.073892    ...    -0.031183  0.019151 -0.009457
# awards                     -0.056592    ...     0.008311  0.029176 -0.020720
# imdb_rating                -0.059660    ...     0.019058 -0.027144 -0.009401
# imdb_votes                 -0.042325    ...    -0.015763 -0.013784 -0.009629
# timeslot_00:00             -0.007545    ...    -0.003186 -0.002350 -0.001660
# timeslot_afternoon         -0.101151    ...     0.007972 -0.031505  0.010023
# timeslot_evening           -0.116768    ...    -0.002046  0.027541  0.034510
# timeslot_latenight         -0.053404    ...     0.004145 -0.016633 -0.011752
# timeslot_morning            1.000000    ...    -0.014479 -0.010679 -0.007545
# timeslot_unknown           -0.143132    ...    -0.001680  0.015014 -0.031496
# day_0                       0.014677    ...    -0.010914  0.004571  0.022846
# day_1                      -0.050286    ...    -0.032313 -0.023832  0.021642
# day_2                      -0.059030    ...     0.007967 -0.023832 -0.016838
# day_3                      -0.016107    ...    -0.012482  0.030220 -0.016949
# day_4                      -0.019990    ...     0.069347  0.045291 -0.013498
# day_5                       0.145660    ...    -0.013193  0.002459 -0.017209
# day_6                      -0.018646    ...     0.002189 -0.026218  0.017527
# month_1                     0.003538    ...     0.062949 -0.025139 -0.017761
# month_2                     0.025030    ...    -0.018506 -0.013649  0.050961
# month_3                     0.012320    ...    -0.023334  0.052947 -0.012159
# month_4                    -0.033615    ...     0.010313 -0.014527 -0.010264
# month_5                    -0.031846    ...     0.029107 -0.009919  0.074299
# month_6                    -0.008741    ...    -0.019987  0.065382 -0.010415
# month_7                    -0.000234    ...    -0.017991 -0.013269 -0.009375
# month_8                    -0.029115    ...    -0.018199 -0.013422  0.052037
# month_9                     0.055391    ...    -0.004101 -0.016415 -0.026464
# month_10                   -0.016994    ...    -0.000661  0.014529 -0.013076
# month_11                   -0.022273    ...    -0.016030 -0.011823 -0.008353
# month_12                   -0.028885    ...    -0.012198 -0.008996 -0.006356
# ...                              ...    ...          ...       ...       ...
#  Romance                   -0.044301    ...    -0.018709 -0.013798 -0.009749
#  Sci-Fi                    -0.020850    ...     0.107360 -0.017083  0.037806
#  Short                      0.068321    ...    -0.003186 -0.002350 -0.001660
#  Sport                     -0.020539    ...    -0.008674 -0.006397 -0.004520
#  Talk-Show                  0.050926    ...    -0.012343  0.053308 -0.006432
#  Thriller                  -0.032471    ...     0.069855 -0.010113  0.072687
#  War                       -0.013801    ...    -0.005828 -0.004299 -0.003037
#  Western                   -0.015127    ...    -0.006388 -0.004711 -0.003329
# Action                     -0.044230    ...    -0.023420 -0.017273 -0.012204
# Adventure                  -0.007528    ...    -0.016258 -0.011991 -0.008472
# Animation                   0.195640    ...    -0.038692 -0.028536 -0.020162
# Biography                  -0.013089    ...    -0.005528 -0.004077 -0.002880
# Comedy                     -0.066161    ...    -0.055545 -0.040966 -0.028943
# Crime                      -0.045718    ...    -0.019307 -0.014239 -0.010060
# Documentary                -0.011872    ...    -0.013044 -0.009620 -0.006797
# Drama                      -0.059824    ...    -0.029237 -0.021563 -0.015235
# Family                      0.000134    ...    -0.010152 -0.007487 -0.005290
# Fantasy                    -0.009745    ...    -0.004116 -0.003035 -0.002145
# Game-Show                  -0.029566    ...    -0.012486 -0.009209 -0.006506
# History                    -0.006158    ...    -0.002601 -0.001918 -0.001355
# Horror                     -0.014479    ...     1.000000 -0.004510 -0.003186
# Music                      -0.010679    ...    -0.004510  1.000000 -0.002350
# Mystery                    -0.007545    ...    -0.003186 -0.002350  1.000000
# News                        0.141940    ...    -0.007614 -0.005616 -0.003967
# Reality-TV                 -0.007991    ...    -0.016371 -0.012074 -0.008530
# Romance                    -0.006158    ...    -0.002601 -0.001918 -0.001355
# Sci-Fi                     -0.015127    ...    -0.006388 -0.004711 -0.003329
# Sport                      -0.010679    ...    -0.004510 -0.003326 -0.002350
# Talk-Show                  -0.014479    ...    -0.006115 -0.004510 -0.003186
# Western                    -0.015749    ...    -0.006651 -0.004905 -0.003466
#
#                         News  Reality-TV   Romance    Sci-Fi     Sport  \
# number_of_episodes  0.304652   -0.021667 -0.003664 -0.003779 -0.009114
# number_of_seasons   0.274688   -0.030718 -0.010065  0.012725 -0.017452
# awards              0.024082   -0.141855  0.028072 -0.041543 -0.068328
# imdb_rating        -0.083797   -0.239161  0.002801 -0.018236 -0.015901
# imdb_votes         -0.024346   -0.051700 -0.008078 -0.015593 -0.014262
# timeslot_00:00     -0.003967   -0.008530 -0.001355 -0.003329 -0.002350
# timeslot_afternoon  0.001264   -0.016155 -0.018169 -0.012266 -0.031505
# timeslot_evening   -0.048710    0.124400  0.052741 -0.006252  0.006238
# timeslot_latenight  0.057962   -0.018999 -0.009593  0.002006  0.055564
# timeslot_morning    0.141940   -0.007991 -0.006158 -0.015127 -0.010679
# timeslot_unknown   -0.039757   -0.087823 -0.025710  0.021268 -0.004851
# day_0               0.060112    0.019247 -0.013376  0.006476  0.004571
# day_1              -0.040238    0.046162  0.033371 -0.033759 -0.023832
# day_2              -0.040238    0.061771  0.033371  0.004817  0.003400
# day_3               0.040255   -0.017175 -0.013835 -0.033984 -0.023990
# day_4              -0.032258   -0.004762 -0.011018 -0.004259  0.045291
# day_5              -0.025145   -0.065366 -0.014047  0.022478 -0.024358
# day_6               0.031751   -0.036680 -0.015120  0.035142  0.024808
# month_1             0.067014    0.006506 -0.014498  0.001561 -0.025139
# month_2            -0.023044    0.036494 -0.007871  0.011043 -0.013649
# month_3            -0.029057    0.028004 -0.009925 -0.024379 -0.017210
# month_4             0.023834   -0.029478 -0.008378  0.008162  0.026051
# month_5             0.017542    0.046447 -0.005720 -0.014050  0.047622
# month_6            -0.024889    0.061301 -0.008501 -0.020881  0.105443
# month_7            -0.022404    0.052682 -0.007652  0.043514 -0.013269
# month_8             0.003282    0.038618 -0.007741 -0.019013 -0.013422
# month_9            -0.038164   -0.093761  0.014803 -0.008349 -0.037457
# month_10           -0.011562   -0.038781 -0.010673  0.020581 -0.018507
# month_11            0.067381   -0.014915  0.077710  0.017857  0.037034
# month_12           -0.015190    0.021606 -0.005188 -0.012744 -0.008996
# ...                      ...         ...       ...       ...       ...
#  Romance           -0.023297    0.022946 -0.007958 -0.019546 -0.013798
#  Sci-Fi            -0.028843   -0.062013 -0.009852 -0.024199 -0.017083
#  Short             -0.003967   -0.008530 -0.001355 -0.003329 -0.002350
#  Sport              0.146015    0.001917 -0.003689 -0.009062 -0.006397
#  Talk-Show          0.319353   -0.033046 -0.005250 -0.012895  0.115719
#  Thriller          -0.017075   -0.036713 -0.005832  0.065706 -0.010113
#  War               -0.007258   -0.015604 -0.002479 -0.006089 -0.004299
#  Western           -0.007955   -0.017103  0.202200 -0.006674 -0.004711
# Action             -0.029164   -0.062703 -0.009961 -0.024468 -0.017273
# Adventure          -0.020245   -0.043527 -0.006915 -0.016985 -0.011991
# Animation          -0.048181   -0.103592 -0.016457 -0.040424 -0.028536
# Biography          -0.006883   -0.014799 -0.002351 -0.005775 -0.004077
# Comedy             -0.069167   -0.148711 -0.023625 -0.058031 -0.040966
# Crime              -0.024041   -0.051690 -0.008212 -0.020171 -0.014239
# Documentary        -0.016242   -0.034922 -0.005548 -0.013627 -0.009620
# Drama              -0.036407   -0.078277 -0.012436 -0.030545 -0.021563
# Family             -0.012641   -0.027179 -0.004318 -0.010606 -0.007487
# Fantasy            -0.005125   -0.011019 -0.001751 -0.004300 -0.003035
# Game-Show          -0.015548   -0.033428 -0.005311 -0.013045 -0.009209
# History            -0.003239   -0.006963 -0.001106 -0.002717 -0.001918
# Horror             -0.007614   -0.016371 -0.002601 -0.006388 -0.004510
# Music              -0.005616   -0.012074 -0.001918 -0.004711 -0.003326
# Mystery            -0.003967   -0.008530 -0.001355 -0.003329 -0.002350
# News                1.000000   -0.020385 -0.003239 -0.007955 -0.005616
# Reality-TV         -0.020385    1.000000 -0.006963 -0.017103 -0.012074
# Romance            -0.003239   -0.006963  1.000000 -0.002717 -0.001918
# Sci-Fi             -0.007955   -0.017103 -0.002717  1.000000 -0.004711
# Sport              -0.005616   -0.012074 -0.001918 -0.004711  1.000000
# Talk-Show          -0.007614   -0.016371 -0.002601 -0.006388 -0.004510
# Western            -0.008282   -0.017807 -0.002829 -0.006949 -0.004905
#
#                     Talk-Show   Western
# number_of_episodes   0.074843 -0.006269
# number_of_seasons    0.024462 -0.000824
# awards               0.008311 -0.007854
# imdb_rating         -0.109511  0.052788
# imdb_votes          -0.018532 -0.020190
# timeslot_00:00      -0.003186 -0.003466
# timeslot_afternoon   0.075557 -0.030913
# timeslot_evening    -0.017801 -0.010135
# timeslot_latenight   0.004145 -0.024531
# timeslot_morning    -0.014479 -0.015749
# timeslot_unknown    -0.045754  0.055946
# day_0                0.071224  0.003592
# day_1               -0.032313  0.038998
# day_2               -0.032313  0.038998
# day_3                0.007564 -0.035381
# day_4               -0.025905  0.015657
# day_5               -0.033026 -0.017669
# day_6                0.039926 -0.038666
# month_1              0.004728 -0.001352
# month_2             -0.018506 -0.020129
# month_3             -0.023334 -0.001504
# month_4              0.010313 -0.021425
# month_5             -0.013448 -0.014628
# month_6              0.009642  0.005529
# month_7             -0.017991 -0.019570
# month_8              0.046199 -0.019795
# month_9             -0.019663  0.073664
# month_10             0.048204 -0.027295
# month_11            -0.016030 -0.017436
# month_12            -0.012198 -0.013268
# ...                       ...       ...
#  Romance            -0.018709 -0.020350
#  Sci-Fi             -0.023162 -0.025194
#  Short              -0.003186 -0.003466
#  Sport              -0.008674 -0.009435
#  Talk-Show          -0.012343 -0.013425
#  Thriller           -0.013712 -0.014915
#  War                -0.005828 -0.006340
#  Western            -0.006388 -0.006949
# Action              -0.023420 -0.025475
# Adventure           -0.016258 -0.017684
# Animation           -0.038692 -0.042086
# Biography           -0.005528 -0.006013
# Comedy              -0.055545 -0.060417
# Crime               -0.019307 -0.021000
# Documentary         -0.013044 -0.014188
# Drama               -0.029237 -0.031802
# Family              -0.010152 -0.011042
# Fantasy             -0.004116 -0.004477
# Game-Show           -0.012486 -0.013581
# History             -0.002601 -0.002829
# Horror              -0.006115 -0.006651
# Music               -0.004510 -0.004905
# Mystery             -0.003186 -0.003466
# News                -0.007614 -0.008282
# Reality-TV          -0.016371 -0.017807
# Romance             -0.002601 -0.002829
# Sci-Fi              -0.006388 -0.006949
# Sport               -0.004510 -0.004905
# Talk-Show            1.000000 -0.006651
# Western             -0.006651  1.000000
#
# [76 rows x 76 columns]

# %% [markdown]
# # Next Steps
#
# Now that I know how badly my model is performing, I'd like to take a second look at my features to see if they can be modified to be better predictors.
