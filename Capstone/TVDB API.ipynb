# %%
import requests
import time
import pandas as pd
import pprint

pp = pprint.PrettyPrinter(indent=2)

# %% [markdown]
# # Creating an API Token

# %%
url = "https://api.thetvdb.com"

# %%
headers = {
  "apikey": "I4NH1SXHARPKRI2P",
  "userkey": "J3E04YJ3CJ2KT7UO",
  "username": "ericyyoo0016tf"
}

# %%
x = requests.get(url)

# %%
x.text
# Out:
# '{"Error":"Not authorized"}'

# %%
login_url = url + "/login"
y = requests.post(login_url, json=headers)

# %%
y.status_code
# Out:
# 200

# %%
token = y.text
token
# Out:
# '{"token":"eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCJ9.eyJleHAiOjE1MzgwODA0MDEsImlkIjoiIiwib3JpZ19pYXQiOjE1Mzc5OTQwMDEsInVzZXJpZCI6NTEyMTc1LCJ1c2VybmFtZSI6ImVyaWN5eW9vMDAxNnRmIn0.FTrQDmhv6rwygF5Nj0wZybUOyQ6RHqgsLF38AkXQUWyo3qaIAdZoTrxoCs2zeQX1haeeo7jEZx8pRLO6w_x6nU0aI3shxnTCAEWVmhgchKLahzGeR8RJvDf9kNUVeqxrD50dS-l-vYINOaRy9nRxs4US8rkXyWoIPd3SfWFLzn3h_-nLaELhkjpH4oLzzOJg23UcIVJx-S3l9l01TFtgotLX4AaIaZmDuEDLEUEjgsMKHqxBspA2jpcw7EXtdcKaorFihncK5XnMJSVHQtB-juLmeiDFEY83cCfZ5Ld4RgzOaQzsngBsIPWXUEnOT4N-s01GzNYCpRYDkonw0_eIZw"}'

# %%
headers2 = {"Authorization":"Bearer eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCJ9.eyJleHAiOjE1MzgwNzQ5NTEsImlkIjoiIiwib3JpZ19pYXQiOjE1Mzc5ODg1NTEsInVzZXJpZCI6NTEyMTc1LCJ1c2VybmFtZSI6ImVyaWN5eW9vMDAxNnRmIn0.bTq4ZeS3LSu90-Mak1J8pH3SFiuVW-39At7_HJIY8ZKExXdPhaAYqwbSzfNsY2XOZxmpx4NTHnjtkgQI3xD1Z-w_UZB9M-cgm-CGDxRIb5PUrdUvoGwCJjzWMLNW-fjB6S6ZnW_ZU8bQO_cPj-Ji-wZevQEl3MOumEwvRiOazVbiNaBJHv9sd-BX-E2xDtbXwd74kPIOiVqpRhZKulW-hjD_O6Ke9miekJkhbkc2b4YQLZC_4MPWeARFxsH_NwtTOovMcQYRLOtowhvTgmSAA_LwTH4kDeFNJ86doQjIb1XeOfHfR2k0Pem9b2hyIeTZ9ZW99utrIg3yBzgu6oGtiA"}

# %% [markdown]
# # Import the list of terms to search

# %%
import json
with open('abc_names.json') as f:
    data = json.load(f)

# %%
data[0]
# Out:
# 'Grey%27s_Anatomy'

# %% [markdown]
# # Searching the titles using the token

# %%
search_url = url + "/search/series"

# %%
params = {"name":["Grey%27s_Anatomy"]}

# %%
res = requests.get(search_url, params=params, headers=headers2)

# %%
res.text
# Out:
# '{"data":[{"aliases":["Greys Anatomy"],"banner":"graphical/73762-g35.jpg","firstAired":"2005-03-27","id":73762,"network":"ABC (US)","overview":"A drama centered on the personal and professional lives of five surgical interns and their supervisors.","seriesName":"Grey\'s Anatomy","slug":"greys-anatomy","status":"Continuing"}]}'

# %%
ga = res.json()
pp.pprint(ga)
# Out:
# { 'data': [ { 'aliases': ['Greys Anatomy'],
#               'banner': 'graphical/73762-g35.jpg',
#               'firstAired': '2005-03-27',
#               'id': 73762,
#               'network': 'ABC (US)',
#               'overview': 'A drama centered on the personal and professional '
#                           'lives of five surgical interns and their '
#                           'supervisors.',
#               'seriesName': "Grey's Anatomy",
#               'slug': 'greys-anatomy',
#               'status': 'Continuing'}]}

# %%
ga_id = ga['data'][0]['id']
ga_id
# Out:
# 73762

# %% [markdown]
# # Searching Series using ID

# %%
series_url = url + "/series/" + str(ga_id)
series_url
# Out:
# 'https://api.thetvdb.com/series/73762'

# %%
res2 = requests.get(series_url, headers=headers2)

# %%
res2.text
# Out:
# '{"data":{"id":73762,"seriesName":"Grey\'s Anatomy","aliases":["Greys Anatomy"],"banner":"graphical/5ba6a8e00bd69.jpg","seriesId":"","status":"Continuing","firstAired":"2005-03-27","network":"ABC (US)","networkId":"","runtime":"45","genre":["Drama","Romance","Soap"],"overview":"A drama centered on the personal and professional lives of five surgical interns and their supervisors.","lastUpdated":1537920209,"airsDayOfWeek":"Thursday","airsTime":"8:00 PM","rating":"TV-14","imdbId":"tt0413573","zap2itId":"","added":"","addedBy":null,"siteRating":8.2,"siteRatingCount":250,"slug":"greys-anatomy"}}'

# %%
ga_series = res2.json()
pp.pprint(ga_series)
# Out:
# { 'data': { 'added': '',
#             'addedBy': None,
#             'airsDayOfWeek': 'Thursday',
#             'airsTime': '8:00 PM',
#             'aliases': ['Greys Anatomy'],
#             'banner': 'graphical/5ba6a8e00bd69.jpg',
#             'firstAired': '2005-03-27',
#             'genre': ['Drama', 'Romance', 'Soap'],
#             'id': 73762,
#             'imdbId': 'tt0413573',
#             'lastUpdated': 1537920209,
#             'network': 'ABC (US)',
#             'networkId': '',
#             'overview': 'A drama centered on the personal and professional '
#                         'lives of five surgical interns and their supervisors.',
#             'rating': 'TV-14',
#             'runtime': '45',
#             'seriesId': '',
#             'seriesName': "Grey's Anatomy",
#             'siteRating': 8.2,
#             'siteRatingCount': 250,
#             'slug': 'greys-anatomy',
#             'status': 'Continuing',
#             'zap2itId': ''}}

# %%
ga_series['data']
# Out:
# {'id': 73762,
#  'seriesName': "Grey's Anatomy",
#  'aliases': ['Greys Anatomy'],
#  'banner': 'graphical/5ba6a8e00bd69.jpg',
#  'seriesId': '',
#  'status': 'Continuing',
#  'firstAired': '2005-03-27',
#  'network': 'ABC (US)',
#  'networkId': '',
#  'runtime': '45',
#  'genre': ['Drama', 'Romance', 'Soap'],
#  'overview': 'A drama centered on the personal and professional lives of five surgical interns and their supervisors.',
#  'lastUpdated': 1537920209,
#  'airsDayOfWeek': 'Thursday',
#  'airsTime': '8:00 PM',
#  'rating': 'TV-14',
#  'imdbId': 'tt0413573',
#  'zap2itId': '',
#  'added': '',
#  'addedBy': None,
#  'siteRating': 8.2,
#  'siteRatingCount': 250,
#  'slug': 'greys-anatomy'}

# %%
series_ep_url = url + '/series/' + str(ga_id) + '/episodes'

# %%
series_ep_url
# Out:
# 'https://api.thetvdb.com/series/73762/episodes'

# %%
params = {'page': '2'}

# Will need to count up on pages until a 404 is returned

# %%
res_test = requests.get(series_ep_url, params=params, headers=headers2)

# %%
pp.pprint(res_test.json())
# Out:
# { 'data': [ { 'absoluteNumber': 96,
#               'airedEpisodeNumber': 18,
#               'airedSeason': 5,
#               'airedSeasonID': 33904,
#               'airsAfterSeason': None,
#               'airsBeforeEpisode': None,
#               'airsBeforeSeason': None,
#               'director': 'Jessica Yu',
#               'directors': ['Jessica Yu'],
#               'dvdChapter': None,
#               'dvdDiscid': '5',
#               'dvdEpisodeNumber': 18,
#               'dvdSeason': 5,
#               'episodeName': 'Stand by Me',
#               'filename': 'episodes/73762/440644.jpg',
#               'firstAired': '2009-03-19',
#               'guestStars': [],
#               'id': 440644,
#               'imdbId': '',
#               'language': {'episodeName': 'en', 'overview': 'en'},
#               'lastUpdated': 1407432854,
#               'lastUpdatedBy': 415277,
#               'overview': 'After his fellow surgeons try and fail to bring '
#                           'Derek back to work, Meredith must summon the '
#                           'strength to convince him. Meanwhile the hospital is '
#                           'abuzz as Mark attempts a rare face transplant '
#                           'surgery. Cristina, at last awarded her first solo '
#                           'surgery, is more focused on the needs of her '
#                           'friends, and Izzie does her best to keep her '
#                           'medical condition a secret.',
#               'productionCode': '518',
#               'seriesId': 73762,
#               'showUrl': '',
#               'siteRating': 7.5,
#               'siteRatingCount': 35,
#               'thumbAdded': '',
#               'thumbAuthor': 5572,
#               'thumbHeight': '225',
#               'thumbWidth': '400',
#               'writers': ['Zoanne Clack']},
#             { 'absoluteNumber': 97,
#               'airedEpisodeNumber': 19,
#               'airedSeason': 5,
#               'airedSeasonID': 33904,
#               'airsAfterSeason': None,
#               'airsBeforeEpisode': None,
#               'airsBeforeSeason': None,
#               'director': 'Ed Ornelas',
#               'directors': ['Ed Ornelas'],
#               'dvdChapter': None,
#               'dvdDiscid': '5',
#               'dvdEpisodeNumber': 19,
#               'dvdSeason': 5,
#               'episodeName': 'Elevator Love Letter',
#               'filename': 'episodes/73762/440645.jpg',
#               'firstAired': '2009-03-26',
#               'guestStars': [],
#               'id': 440645,
#               'imdbId': '',
#               'language': {'episodeName': 'en', 'overview': 'en'},
#               'lastUpdated': 1428007693,
#               'lastUpdatedBy': 395827,
#               'overview': 'All eyes are on Derek as he is set to perform his '
#                           'first surgery after his breakdown; attention is '
#                           'also set on Izzie, whose medical condition requires '
#                           'her to undergo a difficult surgery; and Owen has '
#                           'another PTSD episode that injures Cristina and '
#                           'traumatizes both of them, throwing the future of '
#                           'their relationship into question.',
#               'productionCode': '519',
#               'seriesId': 73762,
#               'showUrl': '',
#               'siteRating': 7.4,
#               'siteRatingCount': 37,
#               'thumbAdded': '',
#               'thumbAuthor': 5572,
#               'thumbHeight': '225',
#               'thumbWidth': '400',
#               'writers': ['Stacy McKee']},
#             { 'absoluteNumber': 98,
#               'airedEpisodeNumber': 20,
#               'airedSeason': 5,
#               'airedSeasonID': 33904,
#               'airsAfterSeason': None,
#               'airsBeforeEpisode': None,
#               'airsBeforeSeason': None,
#               'director': 'Tony Phelan',
#               'directors': ['Tony Phelan'],
#               'dvdChapter': None,
#               'dvdDiscid': '6',
#               'dvdEpisodeNumber': 20,
#               'dvdSeason': 5,
#               'episodeName': 'Sweet Surrender',
#               'filename': 'episodes/73762/552401.jpg',
#               'firstAired': '2009-04-23',
#               'guestStars': [],
#               'id': 552401,
#               'imdbId': '',
#               'language': {'episodeName': 'en', 'overview': 'en'},
#               'lastUpdated': 1407432895,
#               'lastUpdatedBy': 415277,
#               'overview': 'As she endures aggressive treatment for her cancer, '
#                           'Izzie throws herself into planning Derek and '
#                           "Meredith's wedding.",
#               'productionCode': '520',
#               'seriesId': 73762,
#               'showUrl': '',
#               'siteRating': 7.1,
#               'siteRatingCount': 39,
#               'thumbAdded': '',
#               'thumbAuthor': 5572,
#               'thumbHeight': '225',
#               'thumbWidth': '400',
#               'writers': ['Sonay Washington']},
#             { 'absoluteNumber': 99,
#               'airedEpisodeNumber': 21,
#               'airedSeason': 5,
#               'airedSeasonID': 33904,
#               'airsAfterSeason': None,
#               'airsBeforeEpisode': None,
#               'airsBeforeSeason': None,
#               'director': 'Tom Verica',
#               'directors': ['Tom Verica'],
#               'dvdChapter': None,
#               'dvdDiscid': '6',
#               'dvdEpisodeNumber': 21,
#               'dvdSeason': 5,
#               'episodeName': 'No Good at Saying Sorry (One More Chance)',
#               'filename': 'episodes/73762/552411.jpg',
#               'firstAired': '2009-04-30',
#               'guestStars': [],
#               'id': 552411,
#               'imdbId': '',
#               'language': {'episodeName': 'en', 'overview': 'en'},
#               'lastUpdated': 1418840041,
#               'lastUpdatedBy': 370917,
#               'overview': "As preparations continue for Meredith and Derek's "
#                           'wedding, Izzie receives a surprise hospital visit '
#                           'from her handful-of-a-mother, Robbie. Meanwhile, a '
#                           'newly sober Thatcher visits his daughters, Meredith '
#                           'and Lexie, in order to make amends, and the Chief '
#                           'and Meredith bitterly fight over a controversial '
#                           'medical case.',
#               'productionCode': '521',
#               'seriesId': 73762,
#               'showUrl': '',
#               'siteRating': 7.3,
#               'siteRatingCount': 42,
#               'thumbAdded': '',
#               'thumbAuthor': 1576,
#               'thumbHeight': '225',
#               'thumbWidth': '400',
#               'writers': ['Krista Vernoff']},
#             { 'absoluteNumber': 100,
#               'airedEpisodeNumber': 22,
#               'airedSeason': 5,
#               'airedSeasonID': 33904,
#               'airsAfterSeason': None,
#               'airsBeforeEpisode': None,
#               'airsBeforeSeason': None,
#               'director': 'Rob Corn',
#               'directors': ['Rob Corn'],
#               'dvdChapter': None,
#               'dvdDiscid': '6',
#               'dvdEpisodeNumber': 22,
#               'dvdSeason': 5,
#               'episodeName': 'What a Difference a Day Makes',
#               'filename': 'episodes/73762/552421.jpg',
#               'firstAired': '2009-05-07',
#               'guestStars': [],
#               'id': 552421,
#               'imdbId': '',
#               'language': {'episodeName': 'en', 'overview': 'en'},
#               'lastUpdated': 1418840062,
#               'lastUpdatedBy': 370917,
#               'overview': 'As Meredith, Derek and all of their friends prepare '
#                           'for the big wedding, a group of college students, '
#                           'injured in a car crash as they were heading to '
#                           'their graduation ceremony, is admitted to the ER. '
#                           'Meanwhile, Izzie fears the worst when she begins '
#                           'experiencing familiar symptoms.',
#               'productionCode': '522',
#               'seriesId': 73762,
#               'showUrl': '',
#               'siteRating': 7.4,
#               'siteRatingCount': 46,
#               'thumbAdded': '',
#               'thumbAuthor': 23981,
#               'thumbHeight': '225',
#               'thumbWidth': '400',
#               'writers': ['Shonda Rhimes']},
#             { 'absoluteNumber': 101,
#               'airedEpisodeNumber': 23,
#               'airedSeason': 5,
#               'airedSeasonID': 33904,
#               'airsAfterSeason': None,
#               'airsBeforeEpisode': None,
#               'airsBeforeSeason': None,
#               'director': 'Bill D’Elia',
#               'directors': ['Bill D’Elia'],
#               'dvdChapter': None,
#               'dvdDiscid': '6',
#               'dvdEpisodeNumber': 23,
#               'dvdSeason': 5,
#               'episodeName': "Here's to Future Days",
#               'filename': 'episodes/73762/552431.jpg',
#               'firstAired': '2009-05-14',
#               'guestStars': [],
#               'id': 552431,
#               'imdbId': '',
#               'language': {'episodeName': 'en', 'overview': 'en'},
#               'lastUpdated': 1418840118,
#               'lastUpdatedBy': 370917,
#               'overview': 'In the first part of the two hour season finale, '
#                           'Izzie spends time with a fellow cancer patient and '
#                           'contemplates whether or not to undergo a risky '
#                           'surgery, as Mark is ready to take his relationship '
#                           'with Lexie to the next level and a patient makes '
#                           'Owen reassess his place at Seattle Grace. ',
#               'productionCode': '523',
#               'seriesId': 73762,
#               'showUrl': '',
#               'siteRating': 7.4,
#               'siteRatingCount': 46,
#               'thumbAdded': '',
#               'thumbAuthor': 23981,
#               'thumbHeight': '225',
#               'thumbWidth': '400',
#               'writers': ['Allan Heinberg']},
#             { 'absoluteNumber': 102,
#               'airedEpisodeNumber': 24,
#               'airedSeason': 5,
#               'airedSeasonID': 33904,
#               'airsAfterSeason': None,
#               'airsBeforeEpisode': None,
#               'airsBeforeSeason': None,
#               'director': 'Rob Corn',
#               'directors': ['Rob Corn'],
#               'dvdChapter': None,
#               'dvdDiscid': '7',
#               'dvdEpisodeNumber': 24,
#               'dvdSeason': 5,
#               'episodeName': 'Now or Never',
#               'filename': 'episodes/73762/552441.jpg',
#               'firstAired': '2009-05-14',
#               'guestStars': [],
#               'id': 552441,
#               'imdbId': '',
#               'language': {'episodeName': 'en', 'overview': 'en'},
#               'lastUpdated': 1407432937,
#               'lastUpdatedBy': 415277,
#               'overview': 'In the second part of the two hour season finale, '
#                           'George delivers stunning news to Bailey, sending '
#                           "shockwaves throughout the hospital, and Izzie's "
#                           'friends anxiously await her recovery from surgery. '
#                           'Meanwhile Bailey is surprisingly displeased after '
#                           'being accepted into the pediatric fellowship '
#                           'program, and the victim of a near-fatal traffic '
#                           "accident brings the talents of Seattle Grace's "
#                           'doctors together. This is the second hour of a '
#                           '2-hour season finale.',
#               'productionCode': '524',
#               'seriesId': 73762,
#               'showUrl': '',
#               'siteRating': 7.7,
#               'siteRatingCount': 29,
#               'thumbAdded': '',
#               'thumbAuthor': 23981,
#               'thumbHeight': '225',
#               'thumbWidth': '400',
#               'writers': ['Debora Cahn']},
#             { 'absoluteNumber': 103,
#               'airedEpisodeNumber': 1,
#               'airedSeason': 6,
#               'airedSeasonID': 79611,
#               'airsAfterSeason': None,
#               'airsBeforeEpisode': None,
#               'airsBeforeSeason': None,
#               'director': 'Ed Ornelas',
#               'directors': ['Ed Ornelas'],
#               'dvdChapter': None,
#               'dvdDiscid': '1',
#               'dvdEpisodeNumber': 1,
#               'dvdSeason': 6,
#               'episodeName': 'Good Mourning',
#               'filename': 'episodes/73762/766271.jpg',
#               'firstAired': '2009-09-24',
#               'guestStars': [ 'Matha Plimpton (Pam)',
#                               'Debra Monk (Mrs. OMalley)',
#                               'Shannon Lucio (Amanda)',
#                               'Mitch Pileggi (Larry Jennings)',
#                               'Zoe Boyle (Clara)',
#                               'Zack Shada (Andy).'],
#               'id': 766271,
#               'imdbId': 'tt1457924',
#               'language': {'episodeName': 'en', 'overview': 'en'},
#               'lastUpdated': 1431177367,
#               'lastUpdatedBy': 413789,
#               'overview': 'The hospital staff is left to deal with the '
#                           "aftermath of George's passing. Hitting the staff "
#                           'hard, they all find unique ways to get through the '
#                           "various stages of grief. George's mom returns, "
#                           'faced with the difficult task of deciding what to '
#                           'do with his organs.',
#               'productionCode': '601',
#               'seriesId': 73762,
#               'showUrl': '',
#               'siteRating': 7.1,
#               'siteRatingCount': 50,
#               'thumbAdded': '',
#               'thumbAuthor': 40751,
#               'thumbHeight': '225',
#               'thumbWidth': '400',
#               'writers': ['Krista Vernoff']},
#             { 'absoluteNumber': 104,
#               'airedEpisodeNumber': 2,
#               'airedSeason': 6,
#               'airedSeasonID': 79611,
#               'airsAfterSeason': None,
#               'airsBeforeEpisode': None,
#               'airsBeforeSeason': None,
#               'director': "Bill D'Elia",
#               'directors': ["Bill D'Elia"],
#               'dvdChapter': None,
#               'dvdDiscid': '1',
#               'dvdEpisodeNumber': 2,
#               'dvdSeason': 6,
#               'episodeName': 'Goodbye',
#               'filename': 'episodes/73762/1062081.jpg',
#               'firstAired': '2009-09-24',
#               'guestStars': [],
#               'id': 1062081,
#               'imdbId': 'tt1497728',
#               'language': {'episodeName': 'en', 'overview': 'en'},
#               'lastUpdated': 1418840183,
#               'lastUpdatedBy': 370917,
#               'overview': 'Everyone is struggling after losing one of their '
#                           'own and are turning to any distraction they can '
#                           'find. Meredith and Derek seem to be consummating '
#                           'their marriage anywhere and everywhere, while '
#                           'Cristina and Owen have been instructed to abstain '
#                           'from sex by Dr. Wyatt.',
#               'productionCode': '602',
#               'seriesId': 73762,
#               'showUrl': '',
#               'siteRating': 7.1,
#               'siteRatingCount': 27,
#               'thumbAdded': '',
#               'thumbAuthor': 40751,
#               'thumbHeight': '225',
#               'thumbWidth': '400',
#               'writers': ['Krista Vernoff']},
#             { 'absoluteNumber': 105,
#               'airedEpisodeNumber': 3,
#               'airedSeason': 6,
#               'airedSeasonID': 79611,
#               'airsAfterSeason': None,
#               'airsBeforeEpisode': None,
#               'airsBeforeSeason': None,
#               'director': 'Michael Pressman',
#               'directors': ['Michael Pressman'],
#               'dvdChapter': None,
#               'dvdDiscid': '1',
#               'dvdEpisodeNumber': 3,
#               'dvdSeason': 6,
#               'episodeName': "I Always Feel Like Somebody's Watchin' Me",
#               'filename': 'episodes/73762/1120551.jpg',
#               'firstAired': '2009-10-01',
#               'guestStars': [],
#               'id': 1120551,
#               'imdbId': '',
#               'language': {'episodeName': 'en', 'overview': 'en'},
#               'lastUpdated': 1431177424,
#               'lastUpdatedBy': 413789,
#               'overview': 'Several weeks after her near-death experience, a '
#                           'recovering Izzie returns to work. Meanwhile, '
#                           'nervous that there will be layoffs in the hospital '
#                           'in the wake of an announcement from the Chief, the '
#                           'Seattle Grace residents compete to survive the '
#                           'cuts, including Cristina, who attempts to work '
#                           'alongside Arizona in pediatrics. And Bailey and '
#                           "Alex's patient's already complex case is further "
#                           'complicated by her schizophrenic son.',
#               'productionCode': '603',
#               'seriesId': 73762,
#               'showUrl': '',
#               'siteRating': 7.3,
#               'siteRatingCount': 43,
#               'thumbAdded': '',
#               'thumbAuthor': 40751,
#               'thumbHeight': '225',
#               'thumbWidth': '400',
#               'writers': ['Tony Phelan', 'Joan Rater']},
#             { 'absoluteNumber': 106,
#               'airedEpisodeNumber': 4,
#               'airedSeason': 6,
#               'airedSeasonID': 79611,
#               'airsAfterSeason': None,
#               'airsBeforeEpisode': None,
#               'airsBeforeSeason': None,
#               'director': 'Tom Verica',
#               'directors': ['Tom Verica'],
#               'dvdChapter': None,
#               'dvdDiscid': '1',
#               'dvdEpisodeNumber': 4,
#               'dvdSeason': 6,
#               'episodeName': 'Tainted Obligation',
#               'filename': 'episodes/73762/1120561.jpg',
#               'firstAired': '2009-10-08',
#               'guestStars': [],
#               'id': 1120561,
#               'imdbId': '',
#               'language': {'episodeName': 'en', 'overview': 'en'},
#               'lastUpdated': 1419075096,
#               'lastUpdatedBy': 370917,
#               'overview': "When Meredith and Lexie's father, Thatcher, returns "
#                           "to the hospital with a failed liver, it's up to "
#                           'Meredith to save his life. Meanwhile, Izzie '
#                           'empathizes with a patient riddled with tumors, as '
#                           "Mark, annoyed with Cristina's competitive zeal, "
#                           'tricks her into assisting on an unusual surgery.',
#               'productionCode': '604',
#               'seriesId': 73762,
#               'showUrl': '',
#               'siteRating': 7.6,
#               'siteRatingCount': 50,
#               'thumbAdded': '',
#               'thumbAuthor': 40751,
#               'thumbHeight': '225',
#               'thumbWidth': '400',
#               'writers': ['Jenna Bans']},
#             { 'absoluteNumber': 107,
#               'airedEpisodeNumber': 5,
#               'airedSeason': 6,
#               'airedSeasonID': 79611,
#               'airsAfterSeason': None,
#               'airsBeforeEpisode': None,
#               'airsBeforeSeason': None,
#               'director': 'Tony Phelan',
#               'directors': ['Tony Phelan'],
#               'dvdChapter': None,
#               'dvdDiscid': '2',
#               'dvdEpisodeNumber': 5,
#               'dvdSeason': 6,
#               'episodeName': 'Invasion',
#               'filename': 'episodes/73762/1154931.jpg',
#               'firstAired': '2009-10-15',
#               'guestStars': [],
#               'id': 1154931,
#               'imdbId': '',
#               'language': {'episodeName': 'en', 'overview': 'en'},
#               'lastUpdated': 1415522788,
#               'lastUpdatedBy': 370917,
#               'overview': 'The residents of Seattle Grace and Mercy West vie '
#                           'for surgeries and their careers as day one of the '
#                           'hospital merger begins. Meanwhile, Arizona stands '
#                           'by an enraged Callie when her father, Mr. Torres, '
#                           'employs a priest to help convince her to date men, '
#                           'and Izzie experiences the brunt of her new surgical '
#                           'competition.',
#               'productionCode': '605',
#               'seriesId': 73762,
#               'showUrl': '',
#               'siteRating': 7.3,
#               'siteRatingCount': 50,
#               'thumbAdded': '',
#               'thumbAuthor': 40751,
#               'thumbHeight': '225',
#               'thumbWidth': '400',
#               'writers': ['Mark Wilding']},
#             { 'absoluteNumber': 108,
#               'airedEpisodeNumber': 6,
#               'airedSeason': 6,
#               'airedSeasonID': 79611,
#               'airsAfterSeason': None,
#               'airsBeforeEpisode': None,
#               'airsBeforeSeason': None,
#               'director': 'Allison Liddi-Brown',
#               'directors': ['Allison Liddi-Brown'],
#               'dvdChapter': None,
#               'dvdDiscid': '2',
#               'dvdEpisodeNumber': 6,
#               'dvdSeason': 6,
#               'episodeName': 'I Saw What I Saw',
#               'filename': 'episodes/73762/1154941.jpg',
#               'firstAired': '2009-10-22',
#               'guestStars': [],
#               'id': 1154941,
#               'imdbId': '',
#               'language': {'episodeName': 'en', 'overview': 'en'},
#               'lastUpdated': 1407431843,
#               'lastUpdatedBy': 415277,
#               'overview': 'After a burn victim unexpectedly dies in the midst '
#                           'of a chaotic ER, the Chief and board member '
#                           'Jennings interrogate the residents to find the '
#                           'culprit, as all the Mercy West and Seattle Grace '
#                           'resident defends their actions in an effort to save '
#                           'their jobs.',
#               'productionCode': '606',
#               'seriesId': 73762,
#               'showUrl': '',
#               'siteRating': 7.4,
#               'siteRatingCount': 46,
#               'thumbAdded': '',
#               'thumbAuthor': 71111,
#               'thumbHeight': '225',
#               'thumbWidth': '400',
#               'writers': ['William Harper']},
#             { 'absoluteNumber': 109,
#               'airedEpisodeNumber': 7,
#               'airedSeason': 6,
#               'airedSeasonID': 79611,
#               'airsAfterSeason': None,
#               'airsBeforeEpisode': None,
#               'airsBeforeSeason': None,
#               'director': 'Chandra Wilson',
#               'directors': ['Chandra Wilson'],
#               'dvdChapter': None,
#               'dvdDiscid': '2',
#               'dvdEpisodeNumber': 7,
#               'dvdSeason': 6,
#               'episodeName': 'Give Peace a Chance',
#               'filename': 'episodes/73762/1230581.jpg',
#               'firstAired': '2009-10-29',
#               'guestStars': [],
#               'id': 1230581,
#               'imdbId': '',
#               'language': {'episodeName': 'en', 'overview': 'en'},
#               'lastUpdated': 1419590761,
#               'lastUpdatedBy': 370917,
#               'overview': 'When Isaac has an inoperable tumor wrapped around '
#                           'his spine, he wants Derek to do the impossible. '
#                           "Derek tests the Chief's authority when Richard "
#                           'objects to moving forward with the risky surgery.',
#               'productionCode': '607',
#               'seriesId': 73762,
#               'showUrl': '',
#               'siteRating': 7.5,
#               'siteRatingCount': 51,
#               'thumbAdded': '',
#               'thumbAuthor': 79661,
#               'thumbHeight': '225',
#               'thumbWidth': '400',
#               'writers': ['Peter Nowalk']},
#             { 'absoluteNumber': 110,
#               'airedEpisodeNumber': 8,
#               'airedSeason': 6,
#               'airedSeasonID': 79611,
#               'airsAfterSeason': None,
#               'airsBeforeEpisode': None,
#               'airsBeforeSeason': None,
#               'director': 'Jessica Yu',
#               'directors': ['Jessica Yu'],
#               'dvdChapter': None,
#               'dvdDiscid': '2',
#               'dvdEpisodeNumber': 8,
#               'dvdSeason': 6,
#               'episodeName': 'Invest In Love',
#               'filename': 'episodes/73762/1230591.jpg',
#               'firstAired': '2009-11-05',
#               'guestStars': ['Caroline Choi', 'Khamani Griffin'],
#               'id': 1230591,
#               'imdbId': '',
#               'language': {'episodeName': 'en', 'overview': 'en'},
#               'lastUpdated': 1431176915,
#               'lastUpdatedBy': 413789,
#               'overview': 'A generous 25 million donation is offered to '
#                           'Seattle Grace by the parents of Arizonas '
#                           '10-year-old patient, she finds herself in a '
#                           'conflict of interest when his condition worsens. '
#                           'Cristina tests her boundaries with Owen at the '
#                           'hospital. Alex is left with all of Izzies hospital '
#                           'bills to contend with.',
#               'productionCode': '608',
#               'seriesId': 73762,
#               'showUrl': '',
#               'siteRating': 7.6,
#               'siteRatingCount': 51,
#               'thumbAdded': '',
#               'thumbAuthor': 1576,
#               'thumbHeight': '225',
#               'thumbWidth': '400',
#               'writers': ['Shonda Rhimes', 'Stacy McKee']},
#             { 'absoluteNumber': 111,
#               'airedEpisodeNumber': 9,
#               'airedSeason': 6,
#               'airedSeasonID': 79611,
#               'airsAfterSeason': None,
#               'airsBeforeEpisode': None,
#               'airsBeforeSeason': None,
#               'director': 'Rob Corn',
#               'directors': ['Rob Corn'],
#               'dvdChapter': None,
#               'dvdDiscid': '3',
#               'dvdEpisodeNumber': 9,
#               'dvdSeason': 6,
#               'episodeName': 'New History',
#               'filename': 'episodes/73762/1270721.jpg',
#               'firstAired': '2009-11-12',
#               'guestStars': ['Joel Grey', 'Kim Raver'],
#               'id': 1270721,
#               'imdbId': '',
#               'language': {'episodeName': 'en', 'overview': 'en'},
#               'lastUpdated': 1431177289,
#               'lastUpdatedBy': 413789,
#               'overview': 'Owen recruits Dr. Teddy Altman, a former Iraqi '
#                           'veteran, as the new cardiothoracic surgeon.  '
#                           'Cristina questions her abilities in the E.R. and '
#                           'relationship with Owen.  Izzie returns to Seattle '
#                           'Grace with her high school mentor seeking treatment '
#                           "for his dementia.  Richard's responsibilities, "
#                           'post-merger, are taking a toll on him.',
#               'productionCode': '609',
#               'seriesId': 73762,
#               'showUrl': '',
#               'siteRating': 7.3,
#               'siteRatingCount': 47,
#               'thumbAdded': '',
#               'thumbAuthor': 89351,
#               'thumbHeight': '225',
#               'thumbWidth': '400',
#               'writers': ['Allan Heinberg']},
#             { 'absoluteNumber': 112,
#               'airedEpisodeNumber': 10,
#               'airedSeason': 6,
#               'airedSeasonID': 79611,
#               'airsAfterSeason': None,
#               'airsBeforeEpisode': None,
#               'airsBeforeSeason': None,
#               'director': 'Robert Berlinger',
#               'directors': ['Robert Berlinger'],
#               'dvdChapter': None,
#               'dvdDiscid': '3',
#               'dvdEpisodeNumber': 10,
#               'dvdSeason': 6,
#               'episodeName': 'Holidaze',
#               'filename': 'episodes/73762/1270731.jpg',
#               'firstAired': '2009-11-19',
#               'guestStars': ['Kim Raver', 'Frankie Faison'],
#               'id': 1270731,
#               'imdbId': '',
#               'language': {'episodeName': 'en', 'overview': 'en'},
#               'lastUpdated': 1431177117,
#               'lastUpdatedBy': 413789,
#               'overview': "As Thanksgiving, Christmas and New Year's pass, "
#                           'Miranda gets a visit from her father, William who '
#                           'disapproves of her choices in life. Mark and Lexie '
#                           'cope with an arrival of a woman from his past. '
#                           "Thatcher questions the Chief's recent behavior as "
#                           'Meredith comes to his defense.',
#               'productionCode': '610',
#               'seriesId': 73762,
#               'showUrl': '',
#               'siteRating': 7.2,
#               'siteRatingCount': 48,
#               'thumbAdded': '',
#               'thumbAuthor': 6498,
#               'thumbHeight': '225',
#               'thumbWidth': '400',
#               'writers': ['Krista Vernoff']},
#             { 'absoluteNumber': 113,
#               'airedEpisodeNumber': 11,
#               'airedSeason': 6,
#               'airedSeasonID': 79611,
#               'airsAfterSeason': None,
#               'airsBeforeEpisode': None,
#               'airsBeforeSeason': None,
#               'director': 'Randy Zisk',
#               'directors': ['Randy Zisk'],
#               'dvdChapter': None,
#               'dvdDiscid': '3',
#               'dvdEpisodeNumber': 11,
#               'dvdSeason': 6,
#               'episodeName': 'Blink',
#               'filename': 'episodes/73762/1387531.jpg',
#               'firstAired': '2010-01-14',
#               'guestStars': ['Kate Walsh', 'Kim Raver'],
#               'id': 1387531,
#               'imdbId': '',
#               'language': {'episodeName': 'en', 'overview': 'en'},
#               'lastUpdated': 1420294907,
#               'lastUpdatedBy': 370917,
#               'overview': 'Mark flies Addison to Seattle to help with a '
#                           'difficult procedure on his pregnant daughter, '
#                           "Sloan, Owen questions Teddy's motives when she "
#                           'assigns Cristina the lead on a complicated surgery, '
#                           "and Derek's suspicions are raised when the Chief "
#                           'recruits Meredith to assist with a high profile '
#                           'operation on.',
#               'productionCode': '611',
#               'seriesId': 73762,
#               'showUrl': '',
#               'siteRating': 7.3,
#               'siteRatingCount': 60,
#               'thumbAdded': '',
#               'thumbAuthor': 534,
#               'thumbHeight': '225',
#               'thumbWidth': '400',
#               'writers': ['Debora Cahn']},
#             { 'absoluteNumber': 114,
#               'airedEpisodeNumber': 12,
#               'airedSeason': 6,
#               'airedSeasonID': 79611,
#               'airsAfterSeason': None,
#               'airsBeforeEpisode': None,
#               'airsBeforeSeason': None,
#               'director': 'Donna Deitch',
#               'directors': ['Donna Deitch'],
#               'dvdChapter': None,
#               'dvdDiscid': '3',
#               'dvdEpisodeNumber': 12,
#               'dvdSeason': 6,
#               'episodeName': "I Like You So Much Better When You're Naked",
#               'filename': 'episodes/73762/1391341.jpg',
#               'firstAired': '2010-01-21',
#               'guestStars': ['Kim Raver'],
#               'id': 1391341,
#               'imdbId': '',
#               'language': {'episodeName': 'en', 'overview': 'en'},
#               'lastUpdated': 1420294920,
#               'lastUpdatedBy': 370917,
#               'overview': "After learning of Richard's drinking problem, Derek "
#                           'confronts him for the sake of his friend and the '
#                           'hospital, Izzie returns, hoping to reconcile with '
#                           'Alex, and tensions run high between Teddy, Cristina '
#                           "and Owen in the aftermath of Cristina's startling "
#                           'confession.',
#               'productionCode': '612',
#               'seriesId': 73762,
#               'showUrl': '',
#               'siteRating': 7.2,
#               'siteRatingCount': 61,
#               'thumbAdded': '',
#               'thumbAuthor': 534,
#               'thumbHeight': '225',
#               'thumbWidth': '400',
#               'writers': ['Tony Phelan', 'Joan Rater']},
#             { 'absoluteNumber': 115,
#               'airedEpisodeNumber': 13,
#               'airedSeason': 6,
#               'airedSeasonID': 79611,
#               'airsAfterSeason': None,
#               'airsBeforeEpisode': None,
#               'airsBeforeSeason': None,
#               'director': 'Jeannot Szwarc',
#               'directors': ['Jeannot Szwarc'],
#               'dvdChapter': None,
#               'dvdDiscid': '4',
#               'dvdEpisodeNumber': 13,
#               'dvdSeason': 6,
#               'episodeName': 'State of Love and Trust',
#               'filename': 'episodes/73762/1558901.jpg',
#               'firstAired': '2010-02-04',
#               'guestStars': [],
#               'id': 1558901,
#               'imdbId': '',
#               'language': {'episodeName': 'en', 'overview': 'en'},
#               'lastUpdated': 1407431894,
#               'lastUpdatedBy': 415277,
#               'overview': 'As Derek begins his role as interim chief, he faces '
#                           "a potential lawsuit when Bailey and Meredith's "
#                           'patient awakens from anesthesia mid-surgery. '
#                           'Meanwhile, Teddy refuses to place Cristina on her '
#                           'service, as Arizona tests Alex out in Pediatrics, '
#                           'and Mark refuses to speak to a heartbroken Lexie.',
#               'productionCode': '613',
#               'seriesId': 73762,
#               'showUrl': '',
#               'siteRating': 7.2,
#               'siteRatingCount': 63,
#               'thumbAdded': '',
#               'thumbAuthor': 534,
#               'thumbHeight': '225',
#               'thumbWidth': '400',
#               'writers': ['Stacy McKee']},
#             { 'absoluteNumber': 117,
#               'airedEpisodeNumber': 15,
#               'airedSeason': 6,
#               'airedSeasonID': 79611,
#               'airsAfterSeason': None,
#               'airsBeforeEpisode': None,
#               'airsBeforeSeason': None,
#               'director': 'Rob Corn',
#               'directors': ['Rob Corn'],
#               'dvdChapter': None,
#               'dvdDiscid': '4',
#               'dvdEpisodeNumber': 15,
#               'dvdSeason': 6,
#               'episodeName': 'The Time Warp',
#               'filename': 'episodes/73762/1597441.jpg',
#               'firstAired': '2010-02-18',
#               'guestStars': [ 'Sarah Paulson',
#                               'J. August Richards',
#                               'Missi Pyle'],
#               'id': 1597441,
#               'imdbId': '',
#               'language': {'episodeName': 'en', 'overview': 'en'},
#               'lastUpdated': 1421350236,
#               'lastUpdatedBy': 370917,
#               'overview': 'In his new role as Chief, Derek restores the '
#                           'hospital lecture series, and Richard, Bailey and '
#                           'Callie present to the group pivotal surgical cases '
#                           'from their pasts Bailey reflects on her first days '
#                           'as a shy resident, Callie looks back on a polio '
#                           'case, and Richard recalls a case in which he and '
#                           'Ellis worked on a patient diagnosed with GRID, a '
#                           'virus later called AIDS.',
#               'productionCode': '615',
#               'seriesId': 73762,
#               'showUrl': '',
#               'siteRating': 7.7,
#               'siteRatingCount': 75,
#               'thumbAdded': '',
#               'thumbAuthor': 534,
#               'thumbHeight': '225',
#               'thumbWidth': '400',
#               'writers': ['Zoanne Clack']},
#             { 'absoluteNumber': 116,
#               'airedEpisodeNumber': 14,
#               'airedSeason': 6,
#               'airedSeasonID': 79611,
#               'airsAfterSeason': None,
#               'airsBeforeEpisode': None,
#               'airsBeforeSeason': None,
#               'director': 'Stephen Cragg',
#               'directors': ['Stephen Cragg'],
#               'dvdChapter': None,
#               'dvdDiscid': '4',
#               'dvdEpisodeNumber': 14,
#               'dvdSeason': 6,
#               'episodeName': "Valentine's Day Massacre",
#               'filename': 'episodes/73762/1597451.jpg',
#               'firstAired': '2010-02-11',
#               'guestStars': [],
#               'id': 1597451,
#               'imdbId': '',
#               'language': {'episodeName': 'en', 'overview': 'en'},
#               'lastUpdated': 1420294943,
#               'lastUpdatedBy': 370917,
#               'overview': "It's Valentine's Day, and the doctors must treat "
#                           'dozens of injured people after the roof collapses '
#                           'at a popular romantic restaurant; Derek tries to '
#                           'manage his busy schedule as Chief of Surgery; '
#                           'Meredith wrestles with her new duties as the '
#                           "Chief's wife; and Mark and Callie team up to "
#                           'convince Sloan to do the right thing for her baby.',
#               'productionCode': '614',
#               'seriesId': 73762,
#               'showUrl': '',
#               'siteRating': 7.4,
#               'siteRatingCount': 68,
#               'thumbAdded': '',
#               'thumbAuthor': 534,
#               'thumbHeight': '225',
#               'thumbWidth': '400',
#               'writers': ['William Harper']},
#             { 'absoluteNumber': 118,
#               'airedEpisodeNumber': 16,
#               'airedSeason': 6,
#               'airedSeasonID': 79611,
#               'airsAfterSeason': None,
#               'airsBeforeEpisode': None,
#               'airsBeforeSeason': None,
#               'director': "Bill D'Elia",
#               'directors': ["Bill D'Elia"],
#               'dvdChapter': None,
#               'dvdDiscid': '4',
#               'dvdEpisodeNumber': 16,
#               'dvdSeason': 6,
#               'episodeName': 'Perfect Little Accident',
#               'filename': 'episodes/73762/1724491.jpg',
#               'firstAired': '2010-03-04',
#               'guestStars': [],
#               'id': 1724491,
#               'imdbId': '',
#               'language': {'episodeName': 'en', 'overview': 'en'},
#               'lastUpdated': 1421350246,
#               'lastUpdatedBy': 370917,
#               'overview': 'When famous surgeon Dr. Harper Avery is rushed to '
#                           'Seattle Grace-Mercy West, the staff is surprised to '
#                           'discover that one of their own is related to this '
#                           'legend, and his unorthodox request for his surgery '
#                           'causes tensions t between Derek and Richard. '
#                           'Meanwhile Callie and Arizona try to help Teddy and '
#                           'Sloan move on from their pasts and find greener '
#                           'pastures.',
#               'productionCode': '616',
#               'seriesId': 73762,
#               'showUrl': '',
#               'siteRating': 7.3,
#               'siteRatingCount': 79,
#               'thumbAdded': '',
#               'thumbAuthor': 534,
#               'thumbHeight': '225',
#               'thumbWidth': '400',
#               'writers': ['Peter Nowalk']},
#             { 'absoluteNumber': 119,
#               'airedEpisodeNumber': 17,
#               'airedSeason': 6,
#               'airedSeasonID': 79611,
#               'airsAfterSeason': None,
#               'airsBeforeEpisode': None,
#               'airsBeforeSeason': None,
#               'director': 'Chandra Wilson',
#               'directors': ['Chandra Wilson'],
#               'dvdChapter': None,
#               'dvdDiscid': '5',
#               'dvdEpisodeNumber': 17,
#               'dvdSeason': 6,
#               'episodeName': 'Push',
#               'filename': 'episodes/73762/1733391.jpg',
#               'firstAired': '2010-03-11',
#               'guestStars': [],
#               'id': 1733391,
#               'imdbId': '',
#               'language': {'episodeName': 'en', 'overview': 'en'},
#               'lastUpdated': 1421350167,
#               'lastUpdatedBy': 370917,
#               'overview': 'A patient who needs an extremely difficult surgery '
#                           "comes to Seattle Grace, and it's Richard and Owen "
#                           'who vie for the opportunity to tackle it. But the '
#                           'decision lies in the hands of Derek, who deems that '
#                           'Owen should take on the surgery, leaving Richard '
#                           'bitter. Meanwhile, Bailey deals with her own '
#                           'personal struggles when she nervously prepares for '
#                           'another date with Ben.\r\n',
#               'productionCode': '617',
#               'seriesId': 73762,
#               'showUrl': '',
#               'siteRating': 7.4,
#               'siteRatingCount': 82,
#               'thumbAdded': '',
#               'thumbAuthor': 534,
#               'thumbHeight': '225',
#               'thumbWidth': '400',
#               'writers': ['Deborah Cahn']},
#             { 'absoluteNumber': 120,
#               'airedEpisodeNumber': 18,
#               'airedSeason': 6,
#               'airedSeasonID': 79611,
#               'airsAfterSeason': None,
#               'airsBeforeEpisode': None,
#               'airsBeforeSeason': None,
#               'director': 'Jeannot Szwarc',
#               'directors': ['Jeannot Szwarc'],
#               'dvdChapter': None,
#               'dvdDiscid': '5',
#               'dvdEpisodeNumber': 18,
#               'dvdSeason': 6,
#               'episodeName': 'Suicide Is Painless',
#               'filename': 'episodes/73762/1748211.jpg',
#               'firstAired': '2010-03-25',
#               'guestStars': [],
#               'id': 1748211,
#               'imdbId': '',
#               'language': {'episodeName': 'en', 'overview': 'en'},
#               'lastUpdated': 1421350129,
#               'lastUpdatedBy': 370917,
#               'overview': "When Teddy's patient seeks to end treatment and her "
#                           'life, she turns to Hunt for help. The situation '
#                           "triggers Hunt's memories of his life at war and his "
#                           'past relationship with Teddy. Meanwhile, Callie and '
#                           'Arizona have a difference in opinion on what their '
#                           'future holds, and Richard tries to adjust to his '
#                           'role as a surgeon.',
#               'productionCode': '618',
#               'seriesId': 73762,
#               'showUrl': '',
#               'siteRating': 7.4,
#               'siteRatingCount': 88,
#               'thumbAdded': '',
#               'thumbAuthor': 15491,
#               'thumbHeight': '225',
#               'thumbWidth': '400',
#               'writers': ['Tony Phelan', 'Joan Rater']},
#             { 'absoluteNumber': 121,
#               'airedEpisodeNumber': 19,
#               'airedSeason': 6,
#               'airedSeasonID': 79611,
#               'airsAfterSeason': None,
#               'airsBeforeEpisode': None,
#               'airsBeforeSeason': None,
#               'director': 'Debbie Allen',
#               'directors': ['Debbie Allen'],
#               'dvdChapter': None,
#               'dvdDiscid': '5',
#               'dvdEpisodeNumber': 19,
#               'dvdSeason': 6,
#               'episodeName': 'Sympathy for the Parents',
#               'filename': 'episodes/73762/1837171.jpg',
#               'firstAired': '2010-04-01',
#               'guestStars': ['Sarah Drew', 'Jake McLaughlin', 'Jesse Williams'],
#               'id': 1837171,
#               'imdbId': '',
#               'language': {'episodeName': 'en', 'overview': 'en'},
#               'lastUpdated': 1431177417,
#               'lastUpdatedBy': 413789,
#               'overview': "When Alex's younger brother, Aaron, shows up at "
#                           "Seattle Grace-Mercy West with a hernia, it's up to "
#                           "Alex to get Bailey's approval for his pro bono "
#                           'surgery. Matters are further complicated when Aaron '
#                           'discloses that his family has not heard from Alex '
#                           "since he arrived in Seattle, and parts of Alex's "
#                           'past long kept secret are revealed to his friends '
#                           'and fellow doctors.',
#               'productionCode': '619',
#               'seriesId': 73762,
#               'showUrl': '',
#               'siteRating': 7.2,
#               'siteRatingCount': 86,
#               'thumbAdded': '',
#               'thumbAuthor': 534,
#               'thumbHeight': '225',
#               'thumbWidth': '400',
#               'writers': ['Allan Heinberg']},
#             { 'absoluteNumber': 122,
#               'airedEpisodeNumber': 20,
#               'airedSeason': 6,
#               'airedSeasonID': 79611,
#               'airsAfterSeason': None,
#               'airsBeforeEpisode': None,
#               'airsBeforeSeason': None,
#               'director': 'Tony Phelan',
#               'directors': ['Tony Phelan'],
#               'dvdChapter': None,
#               'dvdDiscid': '5',
#               'dvdEpisodeNumber': 20,
#               'dvdSeason': 6,
#               'episodeName': 'Hook, Line and Sinner',
#               'filename': 'episodes/73762/1837181.jpg',
#               'firstAired': '2010-04-29',
#               'guestStars': [],
#               'id': 1837181,
#               'imdbId': '',
#               'language': {'episodeName': 'en', 'overview': 'en'},
#               'lastUpdated': 1421350102,
#               'lastUpdatedBy': 370917,
#               'overview': "Sloan returns to Mark's apartment, just as she's "
#                           'going into labor, and Teddy, Mark and the '
#                           'still-fighting Callie and Arizona are there to help '
#                           'with the birth and to get Mark through his '
#                           "grandson's pending adoption. Meanwhile Teddy sees "
#                           "Derek's invitation to illustrious cardiothoracic "
#                           "surgeon Tom Evans' as a threat to her future "
#                           'employment at the hospital, and the team work on a '
#                           'crab boat captain who has been stabbed with a giant '
#                           'shark hook.',
#               'productionCode': '620',
#               'seriesId': 73762,
#               'showUrl': '',
#               'siteRating': 7.3,
#               'siteRatingCount': 84,
#               'thumbAdded': '',
#               'thumbAuthor': 534,
#               'thumbHeight': '225',
#               'thumbWidth': '400',
#               'writers': ['Meg Marinis']},
#             { 'absoluteNumber': 123,
#               'airedEpisodeNumber': 21,
#               'airedSeason': 6,
#               'airedSeasonID': 79611,
#               'airsAfterSeason': None,
#               'airsBeforeEpisode': None,
#               'airsBeforeSeason': None,
#               'director': 'Tom Verica',
#               'directors': ['Tom Verica'],
# ...
#               'director': 'Tony Phelan',
#               'directors': ['Tony Phelan'],
#               'dvdChapter': None,
#               'dvdDiscid': '',
#               'dvdEpisodeNumber': None,
#               'dvdSeason': None,
#               'episodeName': 'Hard Bargain',
#               'filename': 'episodes/73762/4457899.jpg',
#               'firstAired': '2013-02-14',
#               'guestStars': ['Constance Zimmer', 'Teresa Huang'],
#               'id': 4457899,
#               'imdbId': 'tt2622548',
#               'language': {'episodeName': 'en', 'overview': 'en'},
#               'lastUpdated': 1438958193,
#               'lastUpdatedBy': 384674,
#               'overview': 'As the hospital spirals closer to financial ruin, '
#                           'Owen must make some tough decisions, which includes '
#                           'foregoing an expensive surgery that could save the '
#                           'life of a child. Meanwhile, Alex and Jo work '
#                           'together to save the life of an infant, and April '
#                           'asks Jackson for dating advice.',
#               'productionCode': '',
#               'seriesId': 73762,
#               'showUrl': '',
#               'siteRating': 7.4,
#               'siteRatingCount': 53,
#               'thumbAdded': '',
#               'thumbAuthor': 378781,
#               'thumbHeight': '225',
#               'thumbWidth': '400',
#               'writers': ['William Harper']},
#             { 'absoluteNumber': 188,
#               'airedEpisodeNumber': 16,
#               'airedSeason': 9,
#               'airedSeasonID': 492751,
#               'airsAfterSeason': None,
#               'airsBeforeEpisode': None,
#               'airsBeforeSeason': None,
#               'director': 'Jeanott Szwarc',
#               'directors': ['Jeanott Szwarc'],
#               'dvdChapter': None,
#               'dvdDiscid': '',
#               'dvdEpisodeNumber': None,
#               'dvdSeason': None,
#               'episodeName': 'This is Why We Fight',
#               'filename': 'episodes/73762/4457900.jpg',
#               'firstAired': '2013-02-21',
#               'guestStars': ['Debbie Allen', 'Constance Zimmer'],
#               'id': 4457900,
#               'imdbId': 'tt2634948',
#               'language': {'episodeName': 'en', 'overview': 'en'},
#               'lastUpdated': 1438958153,
#               'lastUpdatedBy': 384674,
#               'overview': "As word of Seattle Grace's financial trouble "
#                           'spreads, Catherine encourages Jackson to move to '
#                           'Boston, and the interns fear they might lose their '
#                           'jobs. Meanwhile, the doctors meet with a potential '
#                           'investor in a last-ditch effort to save the '
#                           'hospital, and Alex impresses Jo while caring for a '
#                           'patient.',
#               'productionCode': '',
#               'seriesId': 73762,
#               'showUrl': '',
#               'siteRating': 7.4,
#               'siteRatingCount': 58,
#               'thumbAdded': '',
#               'thumbAuthor': 363643,
#               'thumbHeight': '225',
#               'thumbWidth': '400',
#               'writers': ['Austin Guzman']},
#             { 'absoluteNumber': 189,
#               'airedEpisodeNumber': 17,
#               'airedSeason': 9,
#               'airedSeasonID': 492751,
#               'airsAfterSeason': None,
#               'airsBeforeEpisode': None,
#               'airsBeforeSeason': None,
#               'director': 'Chandra Wilson',
#               'directors': ['Chandra Wilson'],
#               'dvdChapter': None,
#               'dvdDiscid': '',
#               'dvdEpisodeNumber': None,
#               'dvdSeason': None,
#               'episodeName': 'Transplant Wasteland',
#               'filename': 'episodes/73762/4457901.jpg',
#               'firstAired': '2013-03-14',
#               'guestStars': [],
#               'id': 4457901,
#               'imdbId': '',
#               'language': {'episodeName': 'en', 'overview': 'en'},
#               'lastUpdated': 1438958165,
#               'lastUpdatedBy': 384674,
#               'overview': "The discord and chaos created by the hospital's new "
#                           'management team causes one physician to question '
#                           'his future at Seattle Grace. Meanwhile, the doctors '
#                           'and the interns must juggle several transplant '
#                           'surgeries at once, each coming with its own set of '
#                           'obstacles.',
#               'productionCode': '',
#               'seriesId': 73762,
#               'showUrl': '',
#               'siteRating': 7.5,
#               'siteRatingCount': 59,
#               'thumbAdded': '',
#               'thumbAuthor': 362852,
#               'thumbHeight': '225',
#               'thumbWidth': '400',
#               'writers': ['Zoanne Clack']},
#             { 'absoluteNumber': 190,
#               'airedEpisodeNumber': 18,
#               'airedSeason': 9,
#               'airedSeasonID': 492751,
#               'airsAfterSeason': None,
#               'airsBeforeEpisode': None,
#               'airsBeforeSeason': None,
#               'director': 'David Greenspan',
#               'directors': ['David Greenspan'],
#               'dvdChapter': None,
#               'dvdDiscid': '',
#               'dvdEpisodeNumber': None,
#               'dvdSeason': None,
#               'episodeName': 'Idle Hands',
#               'filename': 'episodes/73762/4457902.jpg',
#               'firstAired': '2013-03-21',
#               'guestStars': [],
#               'id': 4457902,
#               'imdbId': '',
#               'language': {'episodeName': 'en', 'overview': 'en'},
#               'lastUpdated': 1438958178,
#               'lastUpdatedBy': 384674,
#               'overview': 'As the hospital continues to make positive changes '
#                           'under the new management, the doctors begin to '
#                           'realize that owning a hospital comes with its own '
#                           'set of problems and responsibilities. Meanwhile, '
#                           'Meredith worries about the wellbeing of her unborn '
#                           'baby, Callie and Arizona try to get the spark back '
#                           'in their relationship, and Alex gives Jo‘s new '
#                           'boyfriend a run for his money.',
#               'productionCode': '',
#               'seriesId': 73762,
#               'showUrl': '',
#               'siteRating': 7.4,
#               'siteRatingCount': 58,
#               'thumbAdded': '',
#               'thumbAuthor': 1576,
#               'thumbHeight': '225',
#               'thumbWidth': '400',
#               'writers': ['Gabriel Llanas']},
#             { 'absoluteNumber': 191,
#               'airedEpisodeNumber': 19,
#               'airedSeason': 9,
#               'airedSeasonID': 492751,
#               'airsAfterSeason': None,
#               'airsBeforeEpisode': None,
#               'airsBeforeSeason': None,
#               'director': 'Mark Jackson',
#               'directors': ['Mark Jackson'],
#               'dvdChapter': None,
#               'dvdDiscid': '',
#               'dvdEpisodeNumber': None,
#               'dvdSeason': None,
#               'episodeName': "Can't Fight This Feeling",
#               'filename': 'episodes/73762/4457903.jpg',
#               'firstAired': '2013-03-28',
#               'guestStars': [],
#               'id': 4457903,
#               'imdbId': '',
#               'language': {'episodeName': 'en', 'overview': 'en'},
#               'lastUpdated': 1438958237,
#               'lastUpdatedBy': 384674,
#               'overview': 'A gas tanker explodes on a Seattle highway, causing '
#                           'multiple injuries, including paramedic Matthew. '
#                           'Meredith and Jo help a frantic mother whose child '
#                           'is suffering from a mysterious illness. Owen bonds '
#                           'with a young boy whose parents are in critical '
#                           'condition. Meanwhile true colors are revealed when '
#                           "Alex is forced to work with Jo's boyfriend on an "
#                           'ailing patient.',
#               'productionCode': '',
#               'seriesId': 73762,
#               'showUrl': '',
#               'siteRating': 7.2,
#               'siteRatingCount': 52,
#               'thumbAdded': '',
#               'thumbAuthor': 1576,
#               'thumbHeight': '225',
#               'thumbWidth': '400',
#               'writers': ['Meg Marinis']},
#             { 'absoluteNumber': 192,
#               'airedEpisodeNumber': 20,
#               'airedSeason': 9,
#               'airedSeasonID': 492751,
#               'airsAfterSeason': None,
#               'airsBeforeEpisode': None,
#               'airsBeforeSeason': None,
#               'director': 'Nicole Rubio',
#               'directors': ['Nicole Rubio'],
#               'dvdChapter': None,
#               'dvdDiscid': '',
#               'dvdEpisodeNumber': None,
#               'dvdSeason': None,
#               'episodeName': "She's Killing Me",
#               'filename': 'episodes/73762/4457904.jpg',
#               'firstAired': '2013-04-04',
#               'guestStars': [],
#               'id': 4457904,
#               'imdbId': '',
#               'language': {'episodeName': 'en', 'overview': 'en'},
#               'lastUpdated': 1438958199,
#               'lastUpdatedBy': 384674,
#               'overview': 'Upon receiving some unsettling news, Meredith and '
#                           'Derek take preventative steps for their children’s '
#                           'future; a group of Syrian doctors arrive at Grey '
#                           'Sloan Memorial Hospital for a crash course in basic '
#                           'surgical skills that they plan to apply in the '
#                           'field; and April decides to come clean to Matthew '
#                           'regarding the truth about her virginity. Meanwhile, '
#                           'multiple pre-op patients develop infections, '
#                           'causing one doctor to wonder if she is at fault.',
#               'productionCode': '',
#               'seriesId': 73762,
#               'showUrl': '',
#               'siteRating': 7.3,
#               'siteRatingCount': 49,
#               'thumbAdded': '',
#               'thumbAuthor': 1576,
#               'thumbHeight': '225',
#               'thumbWidth': '400',
#               'writers': ['Debora Cahn']},
#             { 'absoluteNumber': 193,
#               'airedEpisodeNumber': 21,
#               'airedSeason': 9,
#               'airedSeasonID': 492751,
#               'airsAfterSeason': None,
#               'airsBeforeEpisode': None,
#               'airsBeforeSeason': None,
#               'director': 'Bobby Roth',
#               'directors': ['Bobby Roth'],
#               'dvdChapter': None,
#               'dvdDiscid': '',
#               'dvdEpisodeNumber': None,
#               'dvdSeason': None,
#               'episodeName': 'Sleeping Monster',
#               'filename': 'episodes/73762/4488821.jpg',
#               'firstAired': '2013-04-25',
#               'guestStars': [],
#               'id': 4488821,
#               'imdbId': '',
#               'language': {'episodeName': 'en', 'overview': 'en'},
#               'lastUpdated': 1438958258,
#               'lastUpdatedBy': 384674,
#               'overview': 'Bailey finds herself at the center of a CDC '
#                           'investigation surrounding the death of several of '
#                           'her patients, as Jackson and the rest of the board '
#                           'members argue over how to address the crisis with '
#                           'the public. Meanwhile, Cristina teases Alex about '
#                           'his unspoken feelings for Jo, and Owen continues to '
#                           'take special care of Ethan as the condition of his '
#                           'parents remains uncertain.',
#               'productionCode': '',
#               'seriesId': 73762,
#               'showUrl': '',
#               'siteRating': 7.4,
#               'siteRatingCount': 49,
#               'thumbAdded': '',
#               'thumbAuthor': 362852,
#               'thumbHeight': '225',
#               'thumbWidth': '400',
#               'writers': ['Browyn Garrity']},
#             { 'absoluteNumber': 194,
#               'airedEpisodeNumber': 22,
#               'airedSeason': 9,
#               'airedSeasonID': 492751,
#               'airsAfterSeason': None,
#               'airsBeforeEpisode': None,
#               'airsBeforeSeason': None,
#               'director': 'Kevin Mckidd',
#               'directors': ['Kevin Mckidd'],
#               'dvdChapter': None,
#               'dvdDiscid': '',
#               'dvdEpisodeNumber': None,
#               'dvdSeason': None,
#               'episodeName': 'Do You Believe in Magic?',
#               'filename': 'episodes/73762/4488822.jpg',
#               'firstAired': '2013-05-02',
#               'guestStars': [],
#               'id': 4488822,
#               'imdbId': '',
#               'language': {'episodeName': 'en', 'overview': 'en'},
#               'lastUpdated': 1438958268,
#               'lastUpdatedBy': 384674,
#               'overview': 'The doctors reach out to Bailey but she continues '
#                           'to shut everyone out; after an incident with '
#                           "Ethan's grandmother, Owen fears the child could end "
#                           'up in foster care. A new craniofacial specialist '
#                           'arrives at Grey Sloan Memorial Hospital to work on '
#                           "a young patient. Meanwhile, a magician's assistant "
#                           'is rushed into the ER after a magic trick goes '
#                           'terribly wrong.',
#               'productionCode': '',
#               'seriesId': 73762,
#               'showUrl': '',
#               'siteRating': 7.4,
#               'siteRatingCount': 48,
#               'thumbAdded': '',
#               'thumbAuthor': 1576,
#               'thumbHeight': '225',
#               'thumbWidth': '400',
#               'writers': ['Dan Bucatinsky']},
#             { 'absoluteNumber': 195,
#               'airedEpisodeNumber': 23,
#               'airedSeason': 9,
#               'airedSeasonID': 492751,
#               'airsAfterSeason': None,
#               'airsBeforeEpisode': None,
#               'airsBeforeSeason': None,
#               'director': 'Tony Phelan',
#               'directors': ['Tony Phelan'],
#               'dvdChapter': None,
#               'dvdDiscid': '',
#               'dvdEpisodeNumber': None,
#               'dvdSeason': None,
#               'episodeName': 'Readiness is All',
#               'filename': 'episodes/73762/4488823.jpg',
#               'firstAired': '2013-05-09',
#               'guestStars': [],
#               'id': 4488823,
#               'imdbId': '',
#               'language': {'episodeName': 'en', 'overview': 'en'},
#               'lastUpdated': 1438958277,
#               'lastUpdatedBy': 384674,
#               'overview': 'The doctors of Grey Sloan Memorial Hospital prepare '
#                           "for a super storm heading towards Seattle. Owen's "
#                           'desire to be a parent gets stronger as he becomes '
#                           'closer to Ethan. One wrong move puts the lives of '
#                           'Meredith and her baby in jeopardy. Meanwhile, Jo '
#                           'looks to Alex for help in a moment of crisis, and '
#                           'one doctor gets the shock of her life.',
#               'productionCode': '',
#               'seriesId': 73762,
#               'showUrl': '',
#               'siteRating': 7.5,
#               'siteRatingCount': 54,
#               'thumbAdded': '',
#               'thumbAuthor': 369555,
#               'thumbHeight': '225',
#               'thumbWidth': '400',
#               'writers': ['William Harper']}],
#   'links': {'first': 1, 'last': 4, 'next': 3, 'prev': 1}}

# %% [markdown]
# # Searching Episodes using ID

# %%
# This is relatively pointless in lieu of what is being found above.

# %%
ep_url = url + '/episodes/' + str(ga_id)
ep_url
# Out:
# 'https://api.thetvdb.com/episodes/73762'

# %%
res3 = requests.get(ep_url, headers=headers2)

# %%
res3.text
# Out:
# '{"data":{"id":73762,"airedSeason":7,"airedSeasonID":3508,"airedEpisodeNumber":105,"episodeName":"Grammer/Kuharski","firstAired":"2004-02-03","guestStars":[],"director":"","directors":[],"writers":[],"overview":null,"language":{"episodeName":"en","overview":"en"},"productionCode":"","showUrl":"","lastUpdated":1163101692,"dvdDiscid":"","dvdSeason":null,"dvdEpisodeNumber":null,"dvdChapter":null,"absoluteNumber":null,"filename":"","seriesId":72104,"lastUpdatedBy":0,"airsAfterSeason":null,"airsBeforeSeason":null,"airsBeforeEpisode":null,"thumbAuthor":1,"thumbAdded":"","thumbWidth":null,"thumbHeight":null,"imdbId":"","siteRating":0,"siteRatingCount":0},"errors":{"invalidLanguage":"Some translations were not available in the specified language"}}'

# %%
ep_ga = res3.json()
pp.pprint(ep_ga)
# Out:
# { 'data': { 'absoluteNumber': None,
#             'airedEpisodeNumber': 105,
#             'airedSeason': 7,
#             'airedSeasonID': 3508,
#             'airsAfterSeason': None,
#             'airsBeforeEpisode': None,
#             'airsBeforeSeason': None,
#             'director': '',
#             'directors': [],
#             'dvdChapter': None,
#             'dvdDiscid': '',
#             'dvdEpisodeNumber': None,
#             'dvdSeason': None,
#             'episodeName': 'Grammer/Kuharski',
#             'filename': '',
#             'firstAired': '2004-02-03',
#             'guestStars': [],
#             'id': 73762,
#             'imdbId': '',
#             'language': {'episodeName': 'en', 'overview': 'en'},
#             'lastUpdated': 1163101692,
#             'lastUpdatedBy': 0,
#             'overview': None,
#             'productionCode': '',
#             'seriesId': 72104,
#             'showUrl': '',
#             'siteRating': 0,
#             'siteRatingCount': 0,
#             'thumbAdded': '',
#             'thumbAuthor': 1,
#             'thumbHeight': None,
#             'thumbWidth': None,
#             'writers': []},
#   'errors': { 'invalidLanguage': 'Some translations were not available in the '
#                                  'specified language'}}

# %%
posts = []
after = None

for i in range(40):
    print(i)
    if after == None:
        params = {}
    else:
        params = {'after': after}
    url = "https://www.reddit.com/r/UpliftingNews/.json"
    res = requests.get(url, params = params, headers = headers)
    if res.status_code == 200:
        upnews = res.json()
        posts.extend(upnews['data']['children'])
        after = upnews['data']['after']
    else:
        print(res.status_code)
        break
    time.sleep(1)
